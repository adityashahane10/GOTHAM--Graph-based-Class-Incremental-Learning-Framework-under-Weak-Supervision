# %%
# !pip install dgl
# Out:
# Requirement already satisfied: dgl in /opt/conda/lib/python3.10/site-packages (2.1.0)
# Requirement already satisfied: numpy>=1.14.0 in /opt/conda/lib/python3.10/site-packages (from dgl) (1.26.4)
# Requirement already satisfied: scipy>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from dgl) (1.11.4)
# Requirement already satisfied: networkx>=2.1 in /opt/conda/lib/python3.10/site-packages (from dgl) (3.2.1)
# Requirement already satisfied: requests>=2.19.0 in /opt/conda/lib/python3.10/site-packages (from dgl) (2.31.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from dgl) (4.66.1)
# Requirement already satisfied: psutil>=5.8.0 in /opt/conda/lib/python3.10/site-packages (from dgl) (5.9.3)
# Requirement already satisfied: torchdata>=0.5.0 in /opt/conda/lib/python3.10/site-packages (from dgl) (0.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->dgl) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->dgl) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->dgl) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->dgl) (2024.2.2)
# Requirement already satisfied: torch>=2 in /opt/conda/lib/python3.10/site-packages (from torchdata>=0.5.0->dgl) (2.1.2+cpu)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=2->torchdata>=0.5.0->dgl) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=2->torchdata>=0.5.0->dgl) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=2->torchdata>=0.5.0->dgl) (1.12)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=2->torchdata>=0.5.0->dgl) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=2->torchdata>=0.5.0->dgl) (2024.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=2->torchdata>=0.5.0->dgl) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=2->torchdata>=0.5.0->dgl) (1.3.0)

# %%
# !pip install geoopt
# !pip install geomstats
# !pip install dgl
# !pip install torch
# Out:
# Requirement already satisfied: geoopt in /opt/conda/lib/python3.10/site-packages (0.5.0)
# Requirement already satisfied: torch>=1.9.0 in /opt/conda/lib/python3.10/site-packages (from geoopt) (2.1.2+cpu)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from geoopt) (1.26.4)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from geoopt) (1.11.4)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.9.0->geoopt) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=1.9.0->geoopt) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.9.0->geoopt) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.9.0->geoopt) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.9.0->geoopt) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.9.0->geoopt) (2024.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.9.0->geoopt) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.9.0->geoopt) (1.3.0)
# Requirement already satisfied: geomstats in /opt/conda/lib/python3.10/site-packages (2.7.0)
# Requirement already satisfied: joblib>=0.17.0 in /opt/conda/lib/python3.10/site-packages (from geomstats) (1.3.2)
# Requirement already satisfied: matplotlib>=3.3.4 in /opt/conda/lib/python3.10/site-packages (from geomstats) (3.7.5)
# Requirement already satisfied: numpy>=1.18.1 in /opt/conda/lib/python3.10/site-packages (from geomstats) (1.26.4)
# Requirement already satisfied: pandas>=1.1.5 in /opt/conda/lib/python3.10/site-packages (from geomstats) (2.2.0)
# Requirement already satisfied: scikit-learn>=0.22.1 in /opt/conda/lib/python3.10/site-packages (from geomstats) (1.2.2)
# Requirement already satisfied: scipy>=1.9 in /opt/conda/lib/python3.10/site-packages (from geomstats) (1.11.4)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.4->geomstats) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.4->geomstats) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.4->geomstats) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.4->geomstats) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.4->geomstats) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.4->geomstats) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.4->geomstats) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.4->geomstats) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.5->geomstats) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.5->geomstats) (2023.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.22.1->geomstats) (3.2.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.4->geomstats) (1.16.0)
# Requirement already satisfied: dgl in /opt/conda/lib/python3.10/site-packages (2.1.0)
# Requirement already satisfied: numpy>=1.14.0 in /opt/conda/lib/python3.10/site-packages (from dgl) (1.26.4)
# Requirement already satisfied: scipy>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from dgl) (1.11.4)
# Requirement already satisfied: networkx>=2.1 in /opt/conda/lib/python3.10/site-packages (from dgl) (3.2.1)
# Requirement already satisfied: requests>=2.19.0 in /opt/conda/lib/python3.10/site-packages (from dgl) (2.31.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from dgl) (4.66.1)
# Requirement already satisfied: psutil>=5.8.0 in /opt/conda/lib/python3.10/site-packages (from dgl) (5.9.3)
# Requirement already satisfied: torchdata>=0.5.0 in /opt/conda/lib/python3.10/site-packages (from dgl) (0.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->dgl) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->dgl) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->dgl) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->dgl) (2024.2.2)
# Requirement already satisfied: torch>=2 in /opt/conda/lib/python3.10/site-packages (from torchdata>=0.5.0->dgl) (2.1.2+cpu)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=2->torchdata>=0.5.0->dgl) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=2->torchdata>=0.5.0->dgl) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=2->torchdata>=0.5.0->dgl) (1.12)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=2->torchdata>=0.5.0->dgl) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=2->torchdata>=0.5.0->dgl) (2024.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=2->torchdata>=0.5.0->dgl) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=2->torchdata>=0.5.0->dgl) (1.3.0)
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (2.1.2+cpu)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch) (2024.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch) (1.3.0)

# %%
import logging
import matplotlib.pyplot as plt

import geomstats.backend as gs
import geomstats.visualization as visualization

from geomstats.datasets.utils import load_karate_graph
from geomstats.geometry.poincare_ball import PoincareBall

# %%
import random
import numpy as np
import torch
import dgl.data

# %% [markdown]
# ### Load the Dataset

# %%
import dgl
from dgl.data import CoraGraphDataset
cora_dataset = CoraGraphDataset()
cora_ml = cora_dataset[0]
# Out:
#   NumNodes: 2708
#   NumEdges: 10556
#   NumFeats: 1433
#   NumClasses: 7
#   NumTrainingSamples: 140
#   NumValidationSamples: 500
#   NumTestSamples: 1000
# Done loading data from cached files.

# %%
import dgl
from dgl.data import CoraFull

# Load the Cora-Full dataset
cora_full_dataset = CoraFull()
cora_full = cora_full_dataset[0]
# Out:
# /opt/conda/lib/python3.10/site-packages/dgl/data/utils.py:377: UserWarning: Class CoraFull will be deprecated, please use CoraFullDataset instead.
#   warnings.warn(

# %% [markdown]
# ### The framework starts here:
# 1. First sample the base graph
# 2. the problem encounter is a n-way, k-shot. Thus, we enact the same for the base graph
# 3. Perform base-training: Episodic learning
# 4. Save the best model
# 5. Perform Fine-tuning for new-streams of data

# %% [markdown]
# Load the necessary values for the framework

# %%
Original_graph = cora_ml   #DGL object
base_classes_graph = 2
num_support_base = 5
num_query_base = 10
start_seed_base = 100
num_episodes_base = 200
n_seed = 42
graph_feats_size = Original_graph.ndata['feat'].shape[1]



fixed_list = [52, 46, 11, 24, 52, 70, 66, 41, 162, 1110]
starting_seeds = [425, 310, 20,180, 535, 110, 195, 233, 541, 945]
n_way = 1
num_support_finetune = 5
num_episodes_finetune = 200
"""
meta_lr = 0.00001
"""
# Out:
# '\nmeta_lr = 0.00001\n'

# %% [markdown]
# ### Sample the graph with only required number of classes: For Cora, we have started with 5 classes. The classes are chosen randomly

# %%
import dgl
import numpy as np

def process_graph(graph, num_classes_to_keep, random_seed=None, remaining_classes=None):
    # Fix the random seed
    if random_seed is not None:
        np.random.seed(random_seed)

    # Step 1: Identify the number of classes in the graph
    num_classes = len(np.unique(graph.ndata['label'].numpy()))

    # Step 2: Validate the given number of classes to keep
    if not 0 < num_classes_to_keep <= num_classes:
        raise ValueError("Invalid number of classes to keep.")

    # Step 3: Initialize remaining classes if not provided
    if remaining_classes is None:
        remaining_classes = set(range(num_classes))

    # Step 4: Sample classes without replacement until all classes are exhausted
    if len(remaining_classes) < num_classes_to_keep:
        raise ValueError("Not enough remaining classes to sample.")

    p_classes = np.random.choice(list(remaining_classes), size=num_classes_to_keep, replace=False)
    remaining_classes -= set(p_classes)

    # Step 5: Sample nodes corresponding to the specified classes without replacement
    p_nodes = [i for i in range(graph.number_of_nodes()) if graph.ndata['label'][i].item() in p_classes]
    sampled_graph = dgl.node_subgraph(graph, p_nodes)

    # Step 6: Extract node labels and features corresponding to sampled nodes
    sampled_labels = sampled_graph.ndata['label']
    sampled_features = graph.ndata['feat'][p_nodes]  # Replace 'feat' with the actual feature name

    # Step 7: Set the features for the sampled graph
    sampled_graph.ndata['feat'] = sampled_features

    # Step 8: Create a new DGL graph object with sampled features and labels
    new_graph = dgl.graph((sampled_graph.edges()[0], sampled_graph.edges()[1]), num_nodes=sampled_graph.number_of_nodes())
    new_graph.ndata['label'] = sampled_labels
    new_graph.ndata['feat'] = sampled_features  # Replace 'feat' with the actual feature name

    return new_graph, remaining_classes

# %%
def get_unique_classes(graph):
    """
    Extracts unique class labels from the 'label' attribute of a graph's node data.

    Parameters:
    - graph: The input graph.

    Returns:
    - list_of_classes: A list of unique class labels.
    """
    try:
        # Assuming 'label' is a tensor or NumPy array
        class_labels = graph.ndata['label'].numpy()
    except KeyError:
        # Adjust the key if the attribute name is different
        print("Error: 'label' attribute not found in node data.")
        return []

    # Extract unique class labels
    unique_classes = set(class_labels)

    # Convert the set to a list (order not guaranteed)
    list_of_classes = list(unique_classes)

    return list_of_classes

# %%
# Example usage:
base_remaining_classes = set(range(len(np.unique(Original_graph.ndata['label'].numpy()))))  # Start with all classes

# Sample a subgraph with 20 classes from the base graph
sampled_graph_base, _ = process_graph(
    Original_graph,
    num_classes_to_keep= base_classes_graph,
    random_seed = n_seed,
    remaining_classes=base_remaining_classes
)
print(f'Base graph classes: {get_unique_classes(sampled_graph_base)}')
# Out:
# Base graph classes: [0, 1]

# %% [markdown]
# ### Meta-Data generator: we divide the graph into tasks; Each task is further divided into train and test set

# %%
import random
import numpy as np
import torch
import dgl.data

class MetaDataGenerator:
    def __init__(self, dataset, num_tasks, num_classes, num_support, num_query, task_random_seeds, random_seeds, num_walks, walk_length):
        self.dataset = dataset
        self.num_tasks = num_tasks
        self.num_classes = num_classes
        self.num_support = num_support
        self.num_query = num_query
        self.task_random_seeds = task_random_seeds
        self.random_seeds = random_seeds
        self.num_walks = num_walks
        self.walk_length = walk_length
        self.task_data = []

    def set_random_seed(self, seed):
        random.seed(seed)
        np.random.seed(seed)
        torch.manual_seed(seed)

    def create_task(self, seed, task_random_seeds):
        tasks = []
        edge_indices_train_list = []
        edge_indices_test_list = []
        support_random_walks_list = []
        query_random_walks_list = []

        for task_seed in task_random_seeds:
            self.set_random_seed(task_seed)
            task = {}
            support_set = []
            query_set = []

            unique_classes = np.unique(self.dataset.ndata['label'].numpy())
            class_group = np.random.choice(unique_classes, self.num_classes, replace=False)

            for c in class_group:
                indices = np.where(self.dataset.ndata['label'].numpy() == c)[0]
                support_indices = np.random.choice(indices, size=self.num_support, replace=False)
                query_indices = np.random.choice(indices, size=self.num_query, replace=False)

                support_set.extend(support_indices)
                query_set.extend(query_indices)

            support_random_walks = self.generate_random_walks(support_set)
            support_random_walks_list.append(support_random_walks)

            query_random_walks = self.generate_random_walks(query_set)
            query_random_walks_list.append(query_random_walks)

            # Include query nodes and nodes from query random walks in the 'test' set
            test_set = list(set(query_set + [node for walk in query_random_walks for node in walk]))
            task['test'] = test_set

            train_set = list(set(support_set + [node for walk in support_random_walks for node in walk]))
            task['train'] = train_set
            task['query_set'] = query_set
            task['support_set'] = support_set
            task['seed'] = task_seed

            tasks.append(task)

            # Generate edge indices for the combined set of query nodes and nodes from query random walks
            edge_indices_test = self.get_edges_from_nodes(test_set)
            edge_indices_train = self.get_edges_from_nodes(train_set)

            edge_indices_test_list.append(edge_indices_test)
            edge_indices_train_list.append(edge_indices_train)

        return tasks, edge_indices_train_list, edge_indices_test_list, support_random_walks_list, query_random_walks_list

    def generate_random_walks(self, nodes):
        random_walks = []

        for node in nodes:
            for _ in range(self.num_walks):
                current_node = node
                walk = [current_node]
                for _ in range(self.walk_length - 1):
                    neighbors = list(self.dataset.successors(current_node).numpy())
                    if len(neighbors) > 0:
                        current_node = random.choice(neighbors)
                        walk.append(current_node)
                    else:
                        break
                random_walks.append(walk)

        return random_walks

    def get_edges_from_nodes(self, nodes):
        src, dst = [], []
        for node in nodes:
            successors = list(self.dataset.successors(node).numpy())
            for successor in successors:
                src.append(node)
                dst.append(successor)

        edge_index = torch.stack([torch.tensor(src), torch.tensor(dst)], dim=0).long()
        return edge_index

    def generate_tasks(self):
        tasks = []
        edge_indices_train_list = []
        edge_indices_test_list = []
        support_random_walks_list = []
        query_random_walks_list = []


        for seed in self.random_seeds:
            tasks_data, edges_train, edges_test, support_walks, query_walks = self.create_task(seed, self.task_random_seeds)
            tasks.extend(tasks_data)
            edge_indices_train_list.extend(edges_train)
            edge_indices_test_list.extend(edges_test)
            support_random_walks_list.extend(support_walks)
            query_random_walks_list.extend(query_walks)



        return tasks, edge_indices_train_list, edge_indices_test_list, support_random_walks_list, query_random_walks_list

# %% [markdown]
# ### Once the tasks are generated and nodes are assigned to respective tasks we extract the features and labels accordingly

# %%
import torch
import dgl

def create_feature_label_extractor(graph, tasks):
    def feature_label_extractor(task_id, seed):
        task = tasks[task_id]

        train_set = task['train']
        test_set = task['test']
        support_set = task['support_set']  # Include support set
        query_set = task['query_set']  # Include query set

        # Extract features and labels for the entire graph
        all_features = graph.ndata['feat']
        all_labels = graph.ndata['label']

        # Extract features and labels for the train set
        train_features = all_features[train_set]
        train_labels = all_labels[train_set]

        # Extract features and labels for the test set
        test_features = all_features[test_set]
        test_labels = all_labels[test_set]

        # Extract features and labels for the support set
        support_features = all_features[support_set]
        support_labels = all_labels[support_set]

        # Extract features and labels for the query set
        query_features = all_features[query_set]
        query_labels = all_labels[query_set]

        # Calculate the degrees of nodes
        train_degrees = graph.in_degrees(train_set)
        test_degrees = graph.in_degrees(test_set)
        support_degrees = graph.in_degrees(support_set)
        query_degrees = graph.in_degrees(query_set)

        return (
            torch.tensor(train_features), torch.tensor(train_labels),
            torch.tensor(test_features), torch.tensor(test_labels),
            torch.tensor(support_features), torch.tensor(support_labels),
            torch.tensor(query_features), torch.tensor(query_labels),
            torch.tensor(train_degrees), torch.tensor(test_degrees),
            torch.tensor(support_degrees), torch.tensor(query_degrees)
        )

    return feature_label_extractor

# %%
import torch

def reindex_nodes(task_id, train_set_list, edge_indices_list, random_walks_list):
    # Extracting task-specific data
    train_set = train_set_list[task_id]
    src_train, dst_train = edge_indices_list[task_id]  # Assuming edge_indices_list is a list of tensors
    random_walks_train = random_walks_list[task_id]

    # Reindexing nodes in train_set
    node_mapping = {old_node: new_node for new_node, old_node in enumerate(train_set)}
    reindexed_train_set = [node_mapping[node] for node in train_set]

    # Reindexing nodes in edge_indices
    reindexed_edge_indices = torch.stack([
        torch.tensor([node_mapping.get(int(source), -1) for source in src_train], dtype=torch.long),
        torch.tensor([node_mapping.get(int(destination), -1) for destination in dst_train], dtype=torch.long)
    ], dim=0)

    # Filter out rows with missing nodes
    mask = (reindexed_edge_indices != -1).all(dim=0)
    reindexed_edge_indices = reindexed_edge_indices[:, mask]

    # Reindexing nodes in random_walks
    reindexed_random_walks = [
        [node_mapping.get(int(node), -1) for node in walk]
        for walk in random_walks_train
    ]

    # Filter out walks with missing nodes
    reindexed_random_walks = [walk for walk in reindexed_random_walks if -1 not in walk]

    # Create a dictionary for old to new node indices
    old_to_new_mapping = {old_node: new_node for old_node, new_node in node_mapping.items()}

    return reindexed_train_set, reindexed_edge_indices, reindexed_random_walks, old_to_new_mapping

# %%
def dict_for_custom_loss_function(reindexed_random_walks, old_to_new_mapping_train, graph):
    original_first_node_list = []
    remaining_nodes = []
    all_firsts = []

    for walks in reindexed_random_walks:
        reindexed_first_node = walks[0]
        all_firsts.append(reindexed_first_node)
        reindexed_remaining_nodes = walks[1:]
        #print(reindexed_remaining_nodes)

        # Find the corresponding original node index using the original-to-reindexed mapping
        original_first_node = next((old_node for old_node, new_node in old_to_new_mapping_train.items() if reindexed_first_node == new_node), None)
        original_first_node_list.append(original_first_node)
        remaining_nodes.append(reindexed_remaining_nodes)


    # Assuming original_labels is a dictionary with node indices as keys and labels as values
    labels_for_nodes = [graph.ndata['label'][node] for node in original_first_node_list if node is not None]

    return labels_for_nodes, remaining_nodes, original_first_node_list, all_firsts

# %%
def create_label_dict(labels_for_nodes, remaining_nodes, all_firsts):
    final_list = []
    for i in range(len(labels_for_nodes)):
        final = [labels_for_nodes[i], remaining_nodes[i]]
        final_list.append(final)

    label_dict = {}
    for item in final_list:
        label = item[0].item()  # Convert tensor label to integer
        nodes_list = item[1]


        if label not in label_dict:
            label_dict[label] = nodes_list
        else:
            label_dict[label].extend(nodes_list)



    # Perform set operation to remove duplicates within each list
    for key in label_dict:
        label_dict[key] = list(set(label_dict[key]))

    return label_dict

# %%
# !pip install torch_geometric
# Out:
# Requirement already satisfied: torch_geometric in /opt/conda/lib/python3.10/site-packages (2.5.1)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (4.66.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (1.26.4)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (1.11.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (2024.2.0)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (3.1.2)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (3.9.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (2.31.0)
# Requirement already satisfied: pyparsing in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (3.1.1)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (1.2.2)
# Requirement already satisfied: psutil>=5.8.0 in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (5.9.3)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (1.9.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch_geometric) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->torch_geometric) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->torch_geometric) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->torch_geometric) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->torch_geometric) (2024.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->torch_geometric) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->torch_geometric) (3.2.0)

# %% [markdown]
# ### ( Main code starting now)Prepare the data for learning the embeddings: the  steps are :
#
# for each task
# *   Get the (train, test)- nodes, features, labels, edge index
# *   pass it through the hyperbolic generator to get the corresponding eucledian embeddings

# %%
import torch

def calculate_euclidean_prototype(features, degree_tensor, class_dict):
    # Initialize a dictionary to store prototypes for each class
    class_prototypes = {}

    for class_label, nodes in class_dict.items():
        # Extract features for the nodes in the current class
        class_features = features[nodes]

        # Extract degrees for the nodes in the current class
        class_degrees = degree_tensor[nodes]

        # Calculate the weighted sum of features
        weighted_sum = torch.sum(class_degrees.unsqueeze(1) * class_features, dim=0)

        # Calculate the sum of degrees
        sum_degrees = torch.sum(class_degrees)

        # Calculate the prototype (weighted average)
        prototype = weighted_sum / sum_degrees

        # Store the prototype in the dictionary
        class_prototypes[class_label] = prototype

    return class_prototypes

# %%
def get_unique_elements_in_order(input_list):
    unique_elements_set = set()
    unique_elements_list = []

    for element in input_list:
        if element not in unique_elements_set:
            unique_elements_set.add(element)
            unique_elements_list.append(element)

    return unique_elements_list

# %%
def add_elements_to_dictionary_list(reformulated_dict, unique_elements_result):
    for i, class_label in enumerate(reformulated_dict.keys()):
        # Get the row corresponding to the class label
        row_elements = unique_elements_result[i]

        # Add each element to the list in the dictionary
        for element in row_elements:
            reformulated_dict[class_label].append(element)

# %%
def create_C_dictionary(Reform_dict, proto_dict):
    # Ensure both dictionaries have the same keys
    common_keys = set(Reform_dict.keys()).intersection(proto_dict.keys())

    # Create a new dictionary with values from both dictionaries for common keys
    C_dict = {key: (Reform_dict[key], proto_dict[key]) for key in common_keys}

    # Access values individually
    Reform_values = {key: Reform_dict[key] for key in common_keys}
    Proto_values = {key: proto_dict[key] for key in common_keys}

    # Use values from proto_dict as keys in Reform_dict
    Reform_dict_with_proto_keys = {tuple((proto_dict[key]).numpy()): Reform_dict[key] for key in common_keys}

    return Reform_values, Proto_values, Reform_dict_with_proto_keys

# %%
import torch
import numpy as np
from torch_geometric.data import Data
import warnings
import time
warnings.filterwarnings("ignore")

def base_training_task_generator(graph, num_classes, num_support, num_query, start_seed, spacing, num_seeds, task_random_seeds, random_seeds):
    train_indexes_before_reindexing_list = []
    test_indexes_before_reindexing_list = []
    task_datasets_euc = []
    context_dictionary_list = []
    train_set_list = []
    test_set_list = []
    euc_proto = []


    num_tasks = num_seeds
    
    metadata_generator = MetaDataGenerator(sampled_graph_base, num_tasks, num_classes, num_support, num_query, task_random_seeds, random_seeds, 10, 3)
    tasks, edge_indices_train_list, edge_indices_test_list, support_random_walks_list, query_random_walks_list = metadata_generator.generate_tasks()

    for i, task in enumerate(tasks):
        #print(f"Task = {i} - Seed: {task_random_seeds[i]}")
        seed = task_random_seeds[i]
        extractor = create_feature_label_extractor(graph, tasks)
        train_features, train_labels, test_features, test_labels, support_features, support_labels, query_features, query_labels, train_degrees, test_degrees, support_degrees, query_degrees = extractor(i, seed) 
        train_indexes_before_reindexing_list.append(task['train'])
        train_set_list.append(task['train'])
        test_set_list.append(task['test'])
        test_indexes_before_reindexing_list.append(task['test'])
        
        reindexed_train_set, reindexed_edge_indices_train, reindexed_random_walks_train, old_to_new_mapping_train = reindex_nodes(i, train_indexes_before_reindexing_list, edge_indices_train_list, support_random_walks_list)
        reindexed_test_set, reindexed_edge_indices_test, reindexed_random_walks_test, old_to_new_mapping_test = reindex_nodes(i, test_indexes_before_reindexing_list, edge_indices_test_list, query_random_walks_list)
        
        data_train_euc = Data(x=train_features, edge_index=reindexed_edge_indices_train, y=train_labels)
        data_test_euc = Data(x=test_features, edge_index=reindexed_edge_indices_test, y=test_labels)
        task_datasets_euc.append((data_train_euc, data_test_euc))
        
        labels_for_nodes, remaining_nodes, original_first_node_list, all_firsts = dict_for_custom_loss_function(reindexed_random_walks_train, old_to_new_mapping_train, graph)
        result_label_dict = create_label_dict(labels_for_nodes, remaining_nodes, all_firsts)
        
        unique_elements_result = get_unique_elements_in_order(all_firsts)
        unique_elements_result = np.array(unique_elements_result).reshape(num_classes, num_support)
        
        # Add elements to the reformulated dictionary
        add_elements_to_dictionary_list(result_label_dict, unique_elements_result)
        context_dictionary_list.append(result_label_dict)
        eucledian_prototype = calculate_euclidean_prototype(train_features, train_degrees, result_label_dict)
        euc_proto.append(eucledian_prototype)
        Reform_values, Proto_values, Reform_dict_with_proto_keys = create_C_dictionary(result_label_dict, eucledian_prototype)
        
    return context_dictionary_list, task_datasets_euc

graph = sampled_graph_base
num_classes = base_classes_graph
num_support = num_support_base
num_query = num_query_base
start_seed = start_seed_base
spacing = 50
num_seeds = num_episodes_base
task_random_seeds = [start_seed + i * spacing for i in range(num_seeds)]
random_seeds = [42]

start_time = time.time()
context_dictionary_list, task_datasets_euc = base_training_task_generator(graph, num_classes, num_support, num_query, start_seed, spacing, num_seeds, task_random_seeds, random_seeds)
end_time = time.time()
execution_time = end_time - start_time

print("Execution Time:", execution_time, "seconds")
# Out:
# Execution Time: 27.151235580444336 seconds

# %%
# !pip install torch_geometric
# Out:
# Requirement already satisfied: torch_geometric in /opt/conda/lib/python3.10/site-packages (2.5.1)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (4.66.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (1.26.4)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (1.11.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (2024.2.0)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (3.1.2)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (3.9.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (2.31.0)
# Requirement already satisfied: pyparsing in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (3.1.1)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (1.2.2)
# Requirement already satisfied: psutil>=5.8.0 in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (5.9.3)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (1.9.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch_geometric) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->torch_geometric) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->torch_geometric) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->torch_geometric) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->torch_geometric) (2024.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->torch_geometric) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->torch_geometric) (3.2.0)

# %%
import torch

def Lintra_loss(embeddings, context_dictionary, target_radius):
    loss_intra = 0
    num_clusters = len(context_dictionary)

    # Calculate mean vectors for each cluster
    mean_vectors = {j: torch.mean(embeddings[cluster_elements], dim=0) for j, cluster_elements in context_dictionary.items()}

    # Calculate intra-cluster loss
    for j, cluster_elements in context_dictionary.items():
        mean_vector = mean_vectors[j]

        for i in cluster_elements:
            embedding_i = embeddings[i]
            norm_diff = torch.norm(embedding_i - mean_vector)
            loss_contrib = torch.clamp(norm_diff - target_radius, min=0)

            # Calculate the sum of all d_{ij} within the cluster
            sum_dij = torch.sum(torch.clamp(torch.norm(embeddings[cluster_elements] - mean_vector, dim=1) - target_radius, min=0))

            # Normalize dij by the sum of all dij within the cluster
            normalized_dij = loss_contrib / sum_dij

            # Add the normalized contribution to the overall loss
            loss_intra += normalized_dij
            
    # Normalize the overall loss by the number of clusters
    loss_intra_normalized = loss_intra / num_clusters
    return loss_intra_normalized, mean_vectors

# %%
import torch

def Linter_loss(embeddings, context_dictionary):
    mean_vectors = {j: torch.mean(embeddings[cluster_elements], dim=0) for j, cluster_elements in context_dictionary.items()}

    loss_inter = 0
    num_clusters = len(context_dictionary)

    for j, cluster_j in context_dictionary.items():
        for p, cluster_p in context_dictionary.items():
            if p != j and j in mean_vectors and p in mean_vectors:  # Check if keys exist
                norm_diff = -torch.log(torch.norm(mean_vectors[j] - mean_vectors[p]) )
                loss_inter += norm_diff
    loss_inter_normalised = loss_inter / num_clusters
    return loss_inter_normalised, mean_vectors

# %%
import torch
import torch.nn.functional as F

def accuracy_cosine(output, labels, mean_vectors):
    _, predicted = torch.max(output, 1)
    correct = 0
    total = labels.size(0)

    for i in range(total):
        output_node = output[i, :]
        similarities = {label: F.cosine_similarity(output_node.unsqueeze(0), mean_vector.unsqueeze(0)) for label, mean_vector in mean_vectors.items()}

        # Find the label with the maximum cosine similarity
        closest_label_sim = max(similarities, key=similarities.get)

        # If the closest label by cosine similarity matches the true label, consider it correct
        if closest_label_sim == labels[i].item():
            correct += 1

    return correct / total

# %%
def accuracy_euclidean(output, labels, mean_vectors):
    _, predicted = torch.max(output, 1)
    correct = 0
    total = labels.size(0)

    for i in range(total):
        output_node = output[i, :]
        distances = {label: torch.dist(output_node.unsqueeze(0), mean_vector.unsqueeze(0)) for label, mean_vector in mean_vectors.items()}

        # Find the label with the minimum Euclidean distance
        closest_label_dist = min(distances, key=distances.get)

        # If the closest label by Euclidean distance matches the true label, consider it correct
        if closest_label_dist == labels[i].item():
            correct += 1

    return correct / total

# %% [markdown]
# ### Training stage: This part is called Base Training of the graph in meta-learning framework

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch_geometric.data import Data
from torch_geometric.nn import GATConv
import torch.nn.functional as F
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from tqdm import tqdm


class GATmodel(nn.Module):
    '''
    input x shape is [node_num, node_feature]
    output out shape is [node_num, class_num]
    '''
    def __init__(self, in_feature, hidden_feature):
        super(GATmodel, self).__init__()
        self.in_feature = in_feature
        self.hidden_feature = hidden_feature
        self.build()
        print("GATConv init.")

    def build(self):
        self.gat_layer_1 = GATConv(in_channels=self.in_feature, out_channels=self.hidden_feature, heads=3, concat=False)
        self.gat_layer_2 = GATConv(in_channels=self.hidden_feature, out_channels=self.hidden_feature, heads=3, concat=False)
    
    def forward(self, x, edge_index):
        gout_1 = self.gat_layer_1(x, edge_index)
        gout_2 = F.dropout(F.relu(gout_1), p=0.2)
        gout_2 = self.gat_layer_2(gout_2, edge_index)
        return gout_2


def meta_train(meta_model, task_datasets, meta_lr, weight_decays, context_dictionary_list):
    optimizer = optim.Adam(meta_model.parameters(), lr=meta_lr, weight_decay=weight_decays)

    total_losses = []  # List to store total losses over meta-epochs
    task_train_losses = []  # List to store task train losses over meta-epochs
    task_test_losses = [[] for _ in range(len(task_datasets))]  # List to store task test losses over meta-epochs
    task_train_accuracies = [[] for _ in range(len(task_datasets))]  # List to store task train accuracies over meta-epochs
    task_test_accuracies = []  # List to store task test accuracies 
    task_cluster_means = [[] for _ in range(len(task_datasets))]  # List to store task means over episodes
    all_train_data = []
    task_dictionary = {}

     

    # Inner loop (tasks)
    for i, task_data in enumerate(task_datasets):
        task_train_data, task_test_data = task_data

        all_train_data.append(task_train_data)
        # Training phase
        meta_model.train()
        optimizer.zero_grad()

        train_output = meta_model(task_train_data.x, task_train_data.edge_index)  # Embeddings (train)
        train_label = task_train_data.y
        loss_intra, _ = Lintra_loss(train_output, context_dictionary_list[i], 0.01)
        loss_inter, mean_vectors = Linter_loss(train_output, context_dictionary_list[i])

        loss =   1 * loss_intra + 0.25 * loss_inter
        loss.backward()
        optimizer.step()
        

        # Validation phase
        meta_model.eval()  # Set the model to evaluation mode
        test_output = meta_model(task_test_data.x, task_test_data.edge_index)
        test_acc = accuracy_euclidean(test_output, task_test_data.y, mean_vectors) * 100
        task_dictionary[i] = test_acc
        # Append metrics to lists
        task_cluster_means[i].append(mean_vectors)
        task_train_losses.append(loss.item())
        task_test_accuracies.append(test_acc)

        print(f'task = {i}, loss = {loss.item():.2f}, test acc = {test_acc:.2f}%')
        

    # Return  meta-model, task cluster means and task dictionary
    return  meta_model, task_cluster_means, task_dictionary, task_train_losses, task_test_accuracies

# %%
# Example usage:
in_channels = graph_feats_size
hidden_channels = 512
meta_lr = 0.00001
weight_decays = 5e-3  # List of weight decay values for each task

# %%
import time

# Record the start time
start_time = time.time()

# Instantiate the meta-model only once outside the loop
meta_model = GATmodel(in_channels, hidden_channels)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
meta_model = meta_model.to(device)

# Train the meta-learning model with regularization
model, cluster_means, task_dictionary, task_train_losses, task_test_accuracies = meta_train(meta_model, task_datasets_euc, meta_lr, weight_decays, context_dictionary_list)

# Find the episode number and corresponding accuracy with the highest accuracy
best_episode = max(task_dictionary, key=task_dictionary.get)
best_accuracy = task_dictionary[best_episode]

# Print the result
print(f"The best accuracy is {best_accuracy:.2f} at episode number {best_episode}.")

# Save the trained model
torch.save(model.state_dict(), 'meta_model.pth')

# Record the end time
end_time = time.time()

# Calculate and print the execution time
execution_time = end_time - start_time
print(f'Total execution time: {execution_time} seconds')
# Out:
# GATConv init.
# task = 0, loss = 2.23, test acc = 92.68%
# task = 1, loss = 2.22, test acc = 93.28%
# task = 2, loss = 2.25, test acc = 80.18%
# task = 3, loss = 2.26, test acc = 90.08%
# task = 4, loss = 2.26, test acc = 92.56%
# task = 5, loss = 2.20, test acc = 82.11%
# task = 6, loss = 2.17, test acc = 82.35%
# task = 7, loss = 2.24, test acc = 81.63%
# task = 8, loss = 2.19, test acc = 91.20%
# task = 9, loss = 2.22, test acc = 83.21%
# task = 10, loss = 2.23, test acc = 94.02%
# task = 11, loss = 2.24, test acc = 97.32%
# task = 12, loss = 2.20, test acc = 89.22%
# task = 13, loss = 2.29, test acc = 89.06%
# task = 14, loss = 2.24, test acc = 91.85%
# task = 15, loss = 2.25, test acc = 98.57%
# task = 16, loss = 2.22, test acc = 94.50%
# task = 17, loss = 2.23, test acc = 90.00%
# task = 18, loss = 2.23, test acc = 97.14%
# task = 19, loss = 2.25, test acc = 99.12%
# task = 20, loss = 2.24, test acc = 95.24%
# task = 21, loss = 2.20, test acc = 92.19%
# task = 22, loss = 2.19, test acc = 95.38%
# task = 23, loss = 2.19, test acc = 90.60%
# task = 24, loss = 2.26, test acc = 93.94%
# task = 25, loss = 2.21, test acc = 86.29%
# task = 26, loss = 2.20, test acc = 96.12%
# task = 27, loss = 2.20, test acc = 99.11%
# task = 28, loss = 2.18, test acc = 86.57%
# task = 29, loss = 2.22, test acc = 95.90%
# task = 30, loss = 2.23, test acc = 93.69%
# task = 31, loss = 2.19, test acc = 97.22%
# task = 32, loss = 2.20, test acc = 99.22%
# task = 33, loss = 2.19, test acc = 93.58%
# task = 34, loss = 2.17, test acc = 93.80%
# task = 35, loss = 2.20, test acc = 97.44%
# task = 36, loss = 2.21, test acc = 95.93%
# task = 37, loss = 2.16, test acc = 79.51%
# task = 38, loss = 2.25, test acc = 95.50%
# task = 39, loss = 2.19, test acc = 96.52%
# task = 40, loss = 2.19, test acc = 92.66%
# task = 41, loss = 2.19, test acc = 98.52%
# task = 42, loss = 2.16, test acc = 90.09%
# task = 43, loss = 2.23, test acc = 99.24%
# task = 44, loss = 2.18, test acc = 93.75%
# task = 45, loss = 2.25, test acc = 93.91%
# task = 46, loss = 2.20, test acc = 90.48%
# task = 47, loss = 2.19, test acc = 93.80%
# task = 48, loss = 2.20, test acc = 97.96%
# task = 49, loss = 2.18, test acc = 95.00%
# task = 50, loss = 2.15, test acc = 99.21%
# task = 51, loss = 2.18, test acc = 96.12%
# task = 52, loss = 2.28, test acc = 95.97%
# task = 53, loss = 2.18, test acc = 96.72%
# task = 54, loss = 2.14, test acc = 94.74%
# task = 55, loss = 2.17, test acc = 95.45%
# task = 56, loss = 2.16, test acc = 91.41%
# task = 57, loss = 2.16, test acc = 83.69%
# task = 58, loss = 2.17, test acc = 91.00%
# task = 59, loss = 2.16, test acc = 88.46%
# task = 60, loss = 2.14, test acc = 97.79%
# task = 61, loss = 2.15, test acc = 95.76%
# task = 62, loss = 2.15, test acc = 94.20%
# task = 63, loss = 2.16, test acc = 95.24%
# task = 64, loss = 2.18, test acc = 96.33%
# task = 65, loss = 2.13, test acc = 99.21%
# task = 66, loss = 2.13, test acc = 96.64%
# task = 67, loss = 2.16, test acc = 94.53%
# task = 68, loss = 2.16, test acc = 97.41%
# task = 69, loss = 2.13, test acc = 97.73%
# task = 70, loss = 2.17, test acc = 98.31%
# task = 71, loss = 2.16, test acc = 97.73%
# task = 72, loss = 2.13, test acc = 96.99%
# task = 73, loss = 2.13, test acc = 95.52%
# task = 74, loss = 2.17, test acc = 97.69%
# task = 75, loss = 2.16, test acc = 98.45%
# task = 76, loss = 2.12, test acc = 96.69%
# task = 77, loss = 2.23, test acc = 95.35%
# task = 78, loss = 2.10, test acc = 92.19%
# task = 79, loss = 2.12, test acc = 96.33%
# task = 80, loss = 2.13, test acc = 97.18%
# task = 81, loss = 2.16, test acc = 98.45%
# task = 82, loss = 2.13, test acc = 99.21%
# task = 83, loss = 2.08, test acc = 95.80%
# task = 84, loss = 2.14, test acc = 98.54%
# task = 85, loss = 2.11, test acc = 97.62%
# task = 86, loss = 2.16, test acc = 97.67%
# task = 87, loss = 2.07, test acc = 97.69%
# task = 88, loss = 2.16, test acc = 95.45%
# task = 89, loss = 2.16, test acc = 98.59%
# task = 90, loss = 2.11, test acc = 97.86%
# task = 91, loss = 2.09, test acc = 98.18%
# task = 92, loss = 2.09, test acc = 100.00%
# task = 93, loss = 2.09, test acc = 98.01%
# task = 94, loss = 2.10, test acc = 97.73%
# task = 95, loss = 2.13, test acc = 97.06%
# task = 96, loss = 2.09, test acc = 93.85%
# task = 97, loss = 2.12, test acc = 99.25%
# task = 98, loss = 2.10, test acc = 94.40%
# task = 99, loss = 2.12, test acc = 97.79%
# task = 100, loss = 2.08, test acc = 96.85%
# task = 101, loss = 2.07, test acc = 99.14%
# task = 102, loss = 2.12, test acc = 97.56%
# task = 103, loss = 2.12, test acc = 98.54%
# task = 104, loss = 2.09, test acc = 97.95%
# task = 105, loss = 2.07, test acc = 98.56%
# task = 106, loss = 2.13, test acc = 98.45%
# task = 107, loss = 2.14, test acc = 97.60%
# task = 108, loss = 2.13, test acc = 97.76%
# task = 109, loss = 2.08, test acc = 97.62%
# task = 110, loss = 2.08, test acc = 97.54%
# task = 111, loss = 2.05, test acc = 95.71%
# task = 112, loss = 2.13, test acc = 98.39%
# task = 113, loss = 2.09, test acc = 98.62%
# task = 114, loss = 2.10, test acc = 99.17%
# task = 115, loss = 2.17, test acc = 87.80%
# task = 116, loss = 2.11, test acc = 97.74%
# task = 117, loss = 2.13, test acc = 97.14%
# task = 118, loss = 2.09, test acc = 96.75%
# task = 119, loss = 2.18, test acc = 94.89%
# task = 120, loss = 2.07, test acc = 99.19%
# task = 121, loss = 2.12, test acc = 96.43%
# task = 122, loss = 2.17, test acc = 93.55%
# task = 123, loss = 2.08, test acc = 98.26%
# task = 124, loss = 2.05, test acc = 92.62%
# task = 125, loss = 2.06, test acc = 94.53%
# task = 126, loss = 2.05, test acc = 97.74%
# task = 127, loss = 2.04, test acc = 98.50%
# task = 128, loss = 2.05, test acc = 98.35%
# task = 129, loss = 2.11, test acc = 96.27%
# task = 130, loss = 2.04, test acc = 98.41%
# task = 131, loss = 2.03, test acc = 96.80%
# task = 132, loss = 2.03, test acc = 96.00%
# task = 133, loss = 1.99, test acc = 97.79%
# task = 134, loss = 2.07, test acc = 96.92%
# task = 135, loss = 2.07, test acc = 95.76%
# task = 136, loss = 2.05, test acc = 93.70%
# task = 137, loss = 2.05, test acc = 97.28%
# task = 138, loss = 2.03, test acc = 98.53%
# task = 139, loss = 2.07, test acc = 97.39%
# task = 140, loss = 2.02, test acc = 98.54%
# task = 141, loss = 2.04, test acc = 97.73%
# task = 142, loss = 2.05, test acc = 99.09%
# task = 143, loss = 2.07, test acc = 100.00%
# task = 144, loss = 2.09, test acc = 97.69%
# task = 145, loss = 2.04, test acc = 98.54%
# task = 146, loss = 2.00, test acc = 97.60%
# task = 147, loss = 2.04, test acc = 98.48%
# task = 148, loss = 2.07, test acc = 98.40%
# task = 149, loss = 2.03, test acc = 97.01%
# task = 150, loss = 2.13, test acc = 98.59%
# task = 151, loss = 2.05, test acc = 97.81%
# task = 152, loss = 1.99, test acc = 97.69%
# task = 153, loss = 2.03, test acc = 99.25%
# task = 154, loss = 2.02, test acc = 97.69%
# task = 155, loss = 2.03, test acc = 98.44%
# task = 156, loss = 2.01, test acc = 96.03%
# task = 157, loss = 2.02, test acc = 98.43%
# task = 158, loss = 2.06, test acc = 94.96%
# task = 159, loss = 2.01, test acc = 99.22%
# task = 160, loss = 2.03, test acc = 98.51%
# task = 161, loss = 2.01, test acc = 96.75%
# task = 162, loss = 2.08, test acc = 97.74%
# task = 163, loss = 1.99, test acc = 95.65%
# task = 164, loss = 2.00, test acc = 97.81%
# task = 165, loss = 2.04, test acc = 95.12%
# task = 166, loss = 2.01, test acc = 98.48%
# task = 167, loss = 1.97, test acc = 95.08%
# task = 168, loss = 1.99, test acc = 96.72%
# task = 169, loss = 2.02, test acc = 97.86%
# task = 170, loss = 2.01, test acc = 98.21%
# task = 171, loss = 2.02, test acc = 98.61%
# task = 172, loss = 1.99, test acc = 96.90%
# task = 173, loss = 1.98, test acc = 97.58%
# task = 174, loss = 1.98, test acc = 98.23%
# task = 175, loss = 2.00, test acc = 97.46%
# task = 176, loss = 2.00, test acc = 100.00%
# task = 177, loss = 1.96, test acc = 98.25%
# task = 178, loss = 2.00, test acc = 95.74%
# task = 179, loss = 1.96, test acc = 99.32%
# task = 180, loss = 2.01, test acc = 95.65%
# task = 181, loss = 2.00, test acc = 98.56%
# task = 182, loss = 2.00, test acc = 97.84%
# task = 183, loss = 2.02, test acc = 97.30%
# task = 184, loss = 1.98, test acc = 97.48%
# task = 185, loss = 1.96, test acc = 97.14%
# task = 186, loss = 1.99, test acc = 94.24%
# task = 187, loss = 1.96, test acc = 97.25%
# task = 188, loss = 2.01, test acc = 100.00%
# task = 189, loss = 1.97, test acc = 95.45%
# task = 190, loss = 1.93, test acc = 97.28%
# task = 191, loss = 1.98, test acc = 95.83%
# task = 192, loss = 1.95, test acc = 98.11%
# task = 193, loss = 1.94, test acc = 97.54%
# task = 194, loss = 1.96, test acc = 99.23%
# task = 195, loss = 1.92, test acc = 96.97%
# task = 196, loss = 1.98, test acc = 99.25%
# task = 197, loss = 1.96, test acc = 96.95%
# task = 198, loss = 1.98, test acc = 97.81%
# task = 199, loss = 1.95, test acc = 98.67%
# The best accuracy is 100.00 at episode number 92.
# Total execution time: 22.132580995559692 seconds

# %%
import matplotlib.pyplot as plt

def plot_performance(task_train_losses, task_test_accuracies, name=None):
    """
    Plots the training losses and test accuracies for a given task.

    Parameters:
    - task_train_losses (list): List of training losses for each epoch.
    - task_test_accuracies (list): List of test accuracies for each epoch.
    - name (str): Name to save the plot with. If None, the plot won't be saved.
    """
    epochs = range(1, len(task_train_losses) + 1)

    # Plotting training losses
    plt.figure(figsize=(5, 5))
    plt.subplot(2, 1, 1)
    plt.plot(epochs, task_train_losses, 'b', label='Training Loss')
    plt.title('Training Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    # Plotting test accuracies
    plt.subplot(2, 1, 2)
    plt.plot(epochs, task_test_accuracies, 'r', label='Test Accuracy')
    plt.title('Test Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.tight_layout()
    
    # Save the plot with the specified name if provided
    if name:
        plt.savefig(f"{name}.png")
    
    plt.show()


plot_performance(task_train_losses, task_test_accuracies, name = 'base training')

# %%
# Print the result
print(f"The best accuracy is {best_accuracy:.2f}% at episode number: {best_episode}.")
# Out:
# The best accuracy is 100.00% at episode number: 92.

# %%
def consolidate_cluster_means(cluster_means, best_episode):
    if best_episode < 0 or best_episode >= len(cluster_means):
        raise ValueError("best_episode index is out of range")

    # Access the dictionary corresponding to the best episode
    best_episode_dict = cluster_means[best_episode][0]

    return best_episode_dict

# %%
#consolidate_cluster_means(cluster_means, best_episode)

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch

def plot_cluster_means_tsne(coordinates, figsize=(2, 2), name=None):
    # Convert coordinates to numpy array
    coordinates_array = np.array([coord.detach().numpy() if isinstance(coord, torch.Tensor) else coord for coord in coordinates.values()])

    # Plotting
    fig, ax = plt.subplots(figsize=figsize)  # Specify the figure size
    for i, (label, coord) in enumerate(coordinates.items()):
        if isinstance(coord, torch.Tensor):
            coord = coord.detach().numpy()
        ax.scatter(coord[0], coord[1], label=f'Class {label}', marker='o',s= 50)
        #ax.annotate(f'{label}', (coord[0], coord[1]), textcoords="offset points", xytext=(0.1,0.1), ha='center')

    # Add labels and legend
    ax.set_xlabel('Dimension 1')
    ax.set_ylabel('Dimension 2')
    ax.set_title('Class Prototypes')

    # Remove ticks and labels from the x and y axes
#     ax.set_xticks([])
#     ax.set_yticks([])
#     ax.xaxis.set_visible(True)
#     ax.yaxis.set_visible(True)
    
    # Add grid lines
    ax.grid(True)

    # Save the plot with the specified name if provided
    if name:
        plt.savefig(f"{name}.png")

    # Show the plot
    plt.show()


plot_cluster_means_tsne(consolidate_cluster_means(cluster_means, best_episode), figsize=(2.5, 2.5), name = 'base clusters')

# %% [markdown]
# ### Finetuning:
# 1. Load the pre-trained model
# 2. Create incremental graph streams
# 3. finetune the model

# %%
meta_model = GATmodel(in_channels, hidden_channels)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
meta_model = meta_model.to(device)
# Out:
# GATConv init.

# %%
# Load the saved model
loaded_model = GATmodel(in_channels, hidden_channels)
loaded_model.load_state_dict(torch.load('/kaggle/working/meta_model.pth'))
loaded_model = loaded_model.to(device)
print(loaded_model)
# Out:
# GATConv init.
# GATmodel(
#   (gat_layer_1): GATConv(1433, 512, heads=3)
#   (gat_layer_2): GATConv(512, 512, heads=3)
# )

# %%
import dgl
import numpy as np

def process_incremental_graphs(graph, num_classes_to_keep, random_seed=None, remaining_classes=None):
    # Fix the random seed
    if random_seed is not None:
        np.random.seed(random_seed)

    # Step 1: Identify the number of classes in the graph
    num_classes = len(np.unique(graph.ndata['label'].numpy()))

    # Step 2: Validate the given number of classes to keep
    if not 0 < num_classes_to_keep <= num_classes:
        raise ValueError("Invalid number of classes to keep.")

    # Step 3: Initialize remaining classes if not provided
    if remaining_classes is None:
        remaining_classes = set(range(num_classes))

    # Step 4: Sample classes without replacement until all classes are exhausted
    if len(remaining_classes) < num_classes_to_keep:
        raise ValueError("Not enough remaining classes to sample.")

    p_classes = np.random.choice(list(remaining_classes), size=num_classes_to_keep, replace=False)


    #print(f"Sampled Classes: {p_classes}")

    # Step 5: Sample nodes corresponding to the specified classes without replacement
    p_nodes = [i for i in range(graph.number_of_nodes()) if graph.ndata['label'][i].item() in p_classes]
    sampled_graph = dgl.node_subgraph(graph, p_nodes)

    # Step 6: Extract node labels and features corresponding to sampled nodes
    sampled_labels = sampled_graph.ndata['label']
    sampled_features = graph.ndata['feat'][p_nodes]  # Replace 'feat' with the actual feature name

    # Step 7: Set the features for the sampled graph
    sampled_graph.ndata['feat'] = sampled_features

    # Step 8: Create a new DGL graph object with sampled features and labels
    new_graph = dgl.graph((sampled_graph.edges()[0], sampled_graph.edges()[1]), num_nodes=sampled_graph.number_of_nodes())
    new_graph.ndata['label'] = sampled_labels
    new_graph.ndata['feat'] = sampled_features  # Replace 'feat' with the actual feature name

    return new_graph, remaining_classes

# %%
import random
import numpy as np
import torch
import dgl.data
from collections import OrderedDict

class FineTune_DataGenerator:
    def __init__(self, dataset, num_tasks, num_classes, num_support, num_query, base_classes, novel_classes_list, task_random_seeds, random_seeds, num_walks, walk_length, stream_seed):
        self.dataset = dataset
        self.num_tasks = num_tasks
        self.num_classes = num_classes
        self.num_support = num_support
        self.num_query = num_query
        self.task_random_seeds = task_random_seeds
        self.random_seeds = random_seeds
        self.num_walks = num_walks
        self.walk_length = walk_length
        self.base_classes = base_classes
        self.novel_classes_list = novel_classes_list
        self.stream_seed = stream_seed
        self.task_data = []


    def set_random_seed(self, seed):
        random.seed(seed)
        np.random.seed(seed)
        torch.manual_seed(seed)

    def create_task(self, seed, task_random_seeds, base_classes, novel_classes_list):
        tasks_base_unique_classes = []
        tasks_last_k_classes = []
        edge_indices_train_list_base_unique_classes = []
        edge_indices_train_list_last_k_classes = []
        edge_indices_test_list_base_unique_classes = []
        edge_indices_test_list_last_k_classes = []
        support_random_walks_list_base_unique_classes = []
        support_random_walks_list_last_k_classes = []
        query_random_walks_list_base_unique_classes = []
        query_random_walks_list_last_k_classes = []

        for task_seed in task_random_seeds:
            self.set_random_seed(task_seed)
            task_base_unique_classes = {}
            task_last_k_classes = {}
            support_set_last_k_classes = []
            support_set_base_unique_classes = []
            query_set_last_k_classes = []
            query_set_base_unique_classes = []




            for c in base_classes:

                indices = np.where(self.dataset.ndata['label'].numpy() == c)[0]
                support_indices = np.random.choice(indices, size=self.num_support, replace= False)
                query_indices = np.random.choice(indices, size=self.num_query, replace= False)

                support_set_base_unique_classes.extend(support_indices)
                query_set_base_unique_classes.extend(query_indices)

            support_random_walks = self.generate_random_walks(support_set_base_unique_classes)
            support_random_walks_list_base_unique_classes.append(support_random_walks)

            query_random_walks = self.generate_random_walks(query_set_base_unique_classes)
            query_random_walks_list_base_unique_classes.append(query_random_walks)

            # Include query nodes and nodes from query random walks in the 'test' set
            test_set = list(set(query_set_base_unique_classes + [node for walk in query_random_walks for node in walk]))
            task_base_unique_classes['test'] = test_set

            train_set = list(set(support_set_base_unique_classes + [node for walk in support_random_walks for node in walk]))
            task_base_unique_classes['train'] = train_set
            task_base_unique_classes['query_set'] = query_set_base_unique_classes
            task_base_unique_classes['support_set'] = support_set_base_unique_classes
            task_base_unique_classes['seed'] = task_seed

            tasks_base_unique_classes.append(task_base_unique_classes)

            # Generate edge indices for the combined set of query nodes and nodes from query random walks
            edge_indices_test = self.get_edges_from_nodes(test_set)
            edge_indices_train = self.get_edges_from_nodes(train_set)

            edge_indices_test_list_base_unique_classes.append(edge_indices_test)
            edge_indices_train_list_base_unique_classes.append(edge_indices_train)



            for c in novel_classes_list:
                np.random.seed(self.stream_seed)

                indices = np.where(self.dataset.ndata['label'].numpy() == c)[0]
                support_indices = np.random.choice(indices, size=self.num_support, replace= True)
                query_indices = np.random.choice(indices, size=self.num_query, replace= True)

                support_set_last_k_classes.extend(support_indices)
                query_set_last_k_classes.extend(query_indices)

            support_random_walks = self.generate_random_walks(support_set_last_k_classes)
            support_random_walks_list_last_k_classes.append(support_random_walks)

            query_random_walks = self.generate_random_walks(query_set_last_k_classes)
            query_random_walks_list_last_k_classes.append(query_random_walks)

            # Include query nodes and nodes from query random walks in the 'test' set
            test_set = list(set(query_set_last_k_classes + [node for walk in query_random_walks for node in walk]))
            task_last_k_classes['test'] = test_set

            train_set = list(set(support_set_last_k_classes + [node for walk in support_random_walks for node in walk]))
            task_last_k_classes['train'] = train_set
            task_last_k_classes['query_set'] = query_set_last_k_classes
            task_last_k_classes['support_set'] = support_set_last_k_classes
            task_last_k_classes['seed'] = task_seed

            tasks_last_k_classes.append(task_last_k_classes)

            # Generate edge indices for the combined set of query nodes and nodes from query random walks
            edge_indices_test = self.get_edges_from_nodes(test_set)
            edge_indices_train = self.get_edges_from_nodes(train_set)

            edge_indices_test_list_last_k_classes.append(edge_indices_test)
            edge_indices_train_list_last_k_classes.append(edge_indices_train)

        return tasks_last_k_classes, edge_indices_train_list_last_k_classes, edge_indices_test_list_last_k_classes, support_random_walks_list_last_k_classes, query_random_walks_list_last_k_classes, tasks_base_unique_classes, edge_indices_train_list_base_unique_classes, edge_indices_test_list_base_unique_classes, support_random_walks_list_base_unique_classes, query_random_walks_list_base_unique_classes



    def generate_random_walks(self, nodes):
        random_walks = []

        for node in nodes:
            for _ in range(self.num_walks):
                current_node = node
                walk = [current_node]
                for _ in range(self.walk_length - 1):
                    neighbors = list(self.dataset.successors(current_node).numpy())
                    if len(neighbors) > 0:
                        current_node = random.choice(neighbors)
                        walk.append(current_node)
                    else:
                        break
                random_walks.append(walk)

        return random_walks

    def get_edges_from_nodes(self, nodes):
        src, dst = [], []
        for node in nodes:
            successors = list(self.dataset.successors(node).numpy())
            for successor in successors:
                src.append(node)
                dst.append(successor)

        edge_index = torch.stack([torch.tensor(src), torch.tensor(dst)], dim=0).long()
        return edge_index

    def generate_tasks(self):
        tasks_base_unique_classes = []
        tasks_last_k_classes = []
        edge_indices_train_list_base_unique_classes = []
        edge_indices_train_list_last_k_classes = []
        edge_indices_test_list_base_unique_classes = []
        edge_indices_test_list_last_k_classes = []
        support_random_walks_list_base_unique_classes = []
        support_random_walks_list_last_k_classes = []
        query_random_walks_list_base_unique_classes = []
        query_random_walks_list_last_k_classes = []


        for seed in self.random_seeds:
            tasks_data_last_k_classes, edges_train_last_k_classes, edges_test_last_k_classes, support_walks_last_k_classes, query_walks_last_k_classes, tasks_data_base_unique_classes, edges_train_base_unique_classes, edges_test_base_unique_classes, support_walks_base_unique_classes, query_walks_base_unique_classes = self.create_task(seed, self.task_random_seeds, self.base_classes, self.novel_classes_list)
            tasks_base_unique_classes.extend(tasks_data_base_unique_classes)
            tasks_last_k_classes.extend(tasks_data_last_k_classes)
            edge_indices_train_list_base_unique_classes.extend(edges_train_base_unique_classes)
            edge_indices_train_list_last_k_classes.extend(edges_train_last_k_classes)
            edge_indices_test_list_base_unique_classes.extend(edges_test_base_unique_classes)
            edge_indices_test_list_last_k_classes.extend(edges_test_last_k_classes)
            support_random_walks_list_base_unique_classes.extend(support_walks_base_unique_classes)
            support_random_walks_list_last_k_classes.extend(support_walks_last_k_classes)
            query_random_walks_list_base_unique_classes.extend(query_walks_base_unique_classes)
            query_random_walks_list_last_k_classes.extend(query_walks_last_k_classes)


        return tasks_base_unique_classes, tasks_last_k_classes , edge_indices_train_list_base_unique_classes, edge_indices_train_list_last_k_classes, edge_indices_test_list_base_unique_classes, edge_indices_test_list_last_k_classes, support_random_walks_list_base_unique_classes, support_random_walks_list_last_k_classes, query_random_walks_list_base_unique_classes, query_random_walks_list_last_k_classes

# %%
import torch
from torch_geometric.data import Data
import numpy as np

def create_context_and_datasets(graph, num_classes, num_support, num_query, base_classes, novel_classes_list, stream_seed, start_seed, spacing, num_seeds):
    # Your existing code for generating random seeds
    task_random_seeds = [start_seed + i * spacing for i in range(num_seeds)]
    random_seeds = [42]
    num_tasks = num_seeds

    # Your existing code for generating tasks and extracting features
    metadata_generator = FineTune_DataGenerator(graph, num_tasks, num_classes, num_support, num_query, base_classes, novel_classes_list, task_random_seeds, random_seeds, 10, 3,  stream_seed)
    tasks_base_unique_classes, tasks_last_k_classes, edge_indices_train_list_base_unique_classes, edge_indices_train_list_last_k_classes, edge_indices_test_list_base_unique_classes, edge_indices_test_list_last_k_classes, support_random_walks_list_base_unique_classes, support_random_walks_list_last_k_classes, query_random_walks_list_base_unique_classes, query_random_walks_list_last_k_classes = metadata_generator.generate_tasks()

    # Your existing code for combining tasks
    combined_query_random_walks_list = [
        query_base + query_last_k
        for query_base, query_last_k in zip(query_random_walks_list_base_unique_classes, query_random_walks_list_last_k_classes)
    ]

    # Your existing code for combining edge indices
    combined_edge_indices_train_list = [
        torch.cat([edge_base, edge_last_k], dim=1)
        for edge_base, edge_last_k in zip(edge_indices_train_list_base_unique_classes, edge_indices_train_list_last_k_classes)
    ]

    combined_edge_indices_test_list = [
        torch.cat([edge_base, edge_last_k], dim=1)
        for edge_base, edge_last_k in zip(edge_indices_test_list_base_unique_classes, edge_indices_test_list_last_k_classes)
    ]

    # Your existing code for combining support random walks
    combined_support_random_walks_list = [
        support_base + support_last_k
        for support_base, support_last_k in zip(support_random_walks_list_base_unique_classes, support_random_walks_list_last_k_classes)
    ]

    combined_tasks = []
    for base_task, last_k_task in zip(tasks_base_unique_classes, tasks_last_k_classes):
        combined_task = {
            'test': base_task['test'] + last_k_task['test'],
            'train': base_task['train'] + last_k_task['train'],
            'query_set': base_task['query_set'] + last_k_task['query_set'],
            'support_set': base_task['support_set'] + last_k_task['support_set'],
            'seed': base_task['seed'],  # You may want to choose which seed to use
        }
        combined_tasks.append(combined_task)

    train_set_list = []
    test_set_list = []
    context_dictionary_list = []
    task_datasets_euc = []

    for i, task in enumerate(combined_tasks):
        #print(f"Episodes: {i} - Seed: {task['seed']}, streaming seed = {stream_seed}")
        seed = tasks_last_k_classes[i]['seed']
        extractor = create_feature_label_extractor(graph, combined_tasks)
        train_features, train_labels, test_features, test_labels, support_features, support_labels, query_features, query_labels, train_degrees, test_degrees, support_degrees, query_degrees = extractor(i, seed)

        train_set_list.append(task['train'])
        test_set_list.append(task['test'])

        reindexed_train_set, reindexed_edge_indices_train, reindexed_random_walks_train, old_to_new_mapping_train = reindex_nodes(i, train_set_list, combined_edge_indices_train_list, combined_support_random_walks_list)
        reindexed_test_set, reindexed_edge_indices_test, reindexed_random_walks_test, old_to_new_mapping_test = reindex_nodes(i, test_set_list, combined_edge_indices_test_list, combined_query_random_walks_list)

        data_train_euc = Data(x=train_features, edge_index=reindexed_edge_indices_train, y=train_labels)
        data_test_euc = Data(x=test_features, edge_index=reindexed_edge_indices_test, y=test_labels)
        task_datasets_euc.append((data_train_euc, data_test_euc))

        labels_for_nodes, remaining_nodes, original_first_node_list, all_firsts = dict_for_custom_loss_function(reindexed_random_walks_train, old_to_new_mapping_train, graph)

        result_label_dict = create_label_dict(labels_for_nodes, remaining_nodes, all_firsts)

        unique_elements_result = get_unique_elements_in_order(all_firsts)

        unique_elements_result = np.array(unique_elements_result).reshape(num_classes, num_support)
        # Add elements to the reformulated dictionary
        add_elements_to_dictionary_list(result_label_dict, unique_elements_result)
        # Print the reformulated dictionary after adding elements
        context_dictionary_list.append(result_label_dict)

    return context_dictionary_list, task_datasets_euc

# %%
def get_unique_classes(graph):
    """
    Extracts unique class labels from the 'label' attribute of a graph's node data.

    Parameters:
    - graph: The input graph.

    Returns:
    - list_of_classes: A list of unique class labels.
    """
    try:
        # Assuming 'label' is a tensor or NumPy array
        class_labels = graph.ndata['label'].numpy()
    except KeyError:
        # Adjust the key if the attribute name is different
        print("Error: 'label' attribute not found in node data.")
        return []

    # Extract unique class labels
    unique_classes = set(class_labels)

    # Convert the set to a list (order not guaranteed)
    list_of_classes = list(unique_classes)

    return list_of_classes

# %%
base_remaining_classes = set(range(len(np.unique(Original_graph.ndata['label'].numpy()))))  # Start with all classes

sampled_graph_base, _ = process_incremental_graphs(
    Original_graph,
    num_classes_to_keep= 3,
    random_seed=n_seed,
    remaining_classes=base_remaining_classes
)
get_unique_classes(sampled_graph_base)
# Out:
# [0, 1, 5]

# %%
import torch

def KDloss(teacher_train_output, train_output, novel_classes, train_label):
    # Convert novel_classes to a tensor for comparison
    novel_classes_tensor = torch.tensor(novel_classes)

    # Find indices of rows in train_label corresponding to novel_classes
    novel_indices = torch.where(torch.isin(train_label, novel_classes_tensor))[0]

    # Create a boolean mask for filtering
    mask = torch.ones(len(train_label), dtype=torch.bool)
    mask[novel_indices] = False

    # Filter out the corresponding rows from teacher_train_output and train_output
    teacher_train_output_filtered = teacher_train_output[mask]
    train_output_filtered = train_output[mask]


    # Node alignment loss
    squared_distance = torch.sum((torch.exp(teacher_train_output_filtered) - torch.exp(train_output_filtered)) ** 1, dim=1)
    # Average over samples
    N = teacher_train_output_filtered.size(0)
    node_loss = torch.mean(squared_distance) / N

   

    return node_loss

# %%
def fine_tune(teacher_model, novel_classes, meta_model, task_datasets, ft_lr, weight_decays, context_dictionary_list):
    optimizer = optim.Adam(meta_model.parameters(), lr=ft_lr, weight_decay=weight_decays)

    total_losses = []  # List to store total losses over meta-epochs
    task_train_losses = []  # List to store task train losses over meta-epochs
    task_test_losses = [[] for _ in range(len(task_datasets))]  # List to store task test losses over meta-epochs
    task_train_accuracies = [[] for _ in range(len(task_datasets))]  # List to store task train accuracies over meta-epochs
    task_test_accuracies = []  # List to store task test accuracies 
    task_cluster_means = [[] for _ in range(len(task_datasets))]  # List to store task means over episodes
    all_train_data = []
    task_dictionary = {}

     

    # Inner loop (tasks)
    for i, task_data in enumerate(task_datasets):
        task_train_data, task_test_data = task_data

        all_train_data.append(task_train_data)
        
        # teacher model will be in evaluation mode
        teacher_model.eval()
        
        
        teacher_train_output = teacher_model(task_train_data.x, task_train_data.edge_index)
        # Training phase
        meta_model.train()
        optimizer.zero_grad()

        train_output = meta_model(task_train_data.x, task_train_data.edge_index)  # Embeddings (train)
        train_label = task_train_data.y
        loss_intra, _ = Lintra_loss(train_output, context_dictionary_list[i], 0.01)
        loss_inter, mean_vectors = Linter_loss(train_output, context_dictionary_list[i])
        
        
        
        # Calculate the knowledge distillation loss
        node_loss = KDloss(teacher_train_output, train_output, novel_classes, train_label)
        


        loss =   1 * loss_intra + 1 * loss_inter + node_loss
        loss.backward()
        optimizer.step()
        

        # Validation phase
        meta_model.eval()  # Set the model to evaluation mode
        test_output = meta_model(task_test_data.x, task_test_data.edge_index)
        test_acc = accuracy_cosine(test_output, task_test_data.y, mean_vectors) * 100
        task_dictionary[i] = test_acc
        # Append metrics to lists
        task_cluster_means[i].append(mean_vectors)
        task_train_losses.append(loss.item())
        task_test_accuracies.append(test_acc)

        print(f'task = {i}, loss = {loss.item():.2f}, test acc = {test_acc:.2f}%')


    # Return  meta-model, task cluster means and task dictionary
    return  meta_model, task_cluster_means, task_dictionary, task_train_losses, task_test_accuracies

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import time

# streaming_seeds = [42, 56, 72, 84, 32, 60, 126, 141, 12, 10]
streaming_seeds = fixed_list
# starting_seeds = [510, 410, 830, 780, 315, 900, 795, 123, 721, 945]
starting_seeds = starting_seeds
previous_classes = set()  # Initialize an empty set outside the loop
base_classes_list = []    # Initialize an empty list for base classes
novel_classes_list = []   # Initialize an empty list for novel classes
p = 0

start_time = time.time()  # Record start time

for i in range(base_classes_graph, 8, n_way):
    sampled_graph_base, _ = process_incremental_graphs(
        Original_graph,
        num_classes_to_keep=i,
        random_seed=n_seed,
        remaining_classes=base_remaining_classes
    )

    all_classes = get_unique_classes(sampled_graph_base)

    if i == base_classes_graph:
        base_classes = list(set(all_classes))
        base_classes_list.extend(all_classes)  # Append base classes to the list
        print(f'Number of Classes (Base) = {i}, Base classes are: {base_classes}')
    else:
        print(f"========================== Streaming session: {p+1} ==========================")
        print(f'Number of Classes (Base + Novel) = {i}')
        novel_classes = list(set(all_classes) - previous_classes)
        novel_classes_list.extend(novel_classes)  # Append novel classes to the list
        print(f'Novel classes are: {novel_classes}')
        stream_seed = streaming_seeds[p]
        start_seed = starting_seeds[p]
        p += 1

        # Print the total novel classes list at each step only for i > 20
        print(f'Base Classes: {base_classes}')
        print(f'Total Novel Classes List: {novel_classes_list}')

        num_classes = i
        num_support = num_support_finetune
        num_query = 10
        spacing = 50
        num_seeds = num_episodes_finetune  #number of episodes in each stream
        ft_lr = 0.000001

        context_dictionary_list, task_datasets_eucledian = create_context_and_datasets(sampled_graph_base, num_classes, num_support, num_query, base_classes, novel_classes_list, stream_seed, start_seed, spacing, num_seeds)
        
        # Train the meta-learning model with regularization
        teacher_model = loaded_model
        current_model, cluster_means, task_dictionary, task_train_losses, task_test_accuracies = fine_tune(teacher_model, novel_classes, meta_model, task_datasets_eucledian, ft_lr, weight_decays, context_dictionary_list)
        loaded_model = current_model
        # Find the episode number and corresponding accuracy with the highest accuracy
        best_episode = max(task_dictionary, key=task_dictionary.get)
        best_accuracy = task_dictionary[best_episode]
        
        # Save the model after each streaming session
        model_name = f'streaming_model_{p}.pt'
        torch.save(model.state_dict(), model_name)
        print(f'Model saved as: {model_name}')
        
        # Print the result
        plot_performance(task_train_losses, task_test_accuracies)
        print(f"The best accuracy is {best_accuracy:.2f}% at episode number {best_episode}.")
        name = f'streaming_{p}_cluster_means'
        plot_cluster_means_tsne(consolidate_cluster_means(cluster_means, best_episode), name = name)
        
        plt.close()  # Close the current plot to avoid overlapping with the next iteration
        
    previous_classes = set(all_classes)

end_time = time.time()  # Record end time
execution_time = end_time - start_time
print(f"Total execution time: {execution_time} seconds.")
# Out:
# Number of Classes (Base) = 2, Base classes are: [0, 1]
# ========================== Streaming session: 1 ==========================
# Number of Classes (Base + Novel) = 3
# Novel classes are: [5]
# Base Classes: [0, 1]
# Total Novel Classes List: [5]
# task = 0, loss = 11.02, test acc = 76.39%
# task = 1, loss = 10.88, test acc = 85.05%
# task = 2, loss = 10.97, test acc = 83.00%
# task = 3, loss = 11.08, test acc = 80.81%
# task = 4, loss = 10.79, test acc = 83.78%
# task = 5, loss = 10.80, test acc = 85.90%
# task = 6, loss = 10.83, test acc = 78.87%
# task = 7, loss = 10.76, test acc = 84.47%
# task = 8, loss = 10.71, test acc = 86.13%
# task = 9, loss = 10.82, test acc = 83.26%
# task = 10, loss = 10.84, test acc = 78.90%
# task = 11, loss = 10.78, test acc = 79.70%
# task = 12, loss = 10.83, test acc = 86.73%
# task = 13, loss = 10.76, test acc = 78.16%
# task = 14, loss = 10.82, test acc = 80.28%
# task = 15, loss = 10.84, test acc = 87.61%
# task = 16, loss = 10.77, test acc = 75.12%
# task = 17, loss = 10.97, test acc = 84.47%
# task = 18, loss = 11.03, test acc = 80.88%
# task = 19, loss = 10.80, test acc = 78.14%
# task = 20, loss = 10.50, test acc = 83.41%
# task = 21, loss = 11.05, test acc = 76.67%
# task = 22, loss = 10.82, test acc = 82.76%
# task = 23, loss = 10.96, test acc = 80.84%
# task = 24, loss = 11.03, test acc = 86.57%
# task = 25, loss = 10.69, test acc = 85.02%
# task = 26, loss = 10.88, test acc = 79.79%
# task = 27, loss = 10.97, test acc = 83.48%
# task = 28, loss = 10.88, test acc = 82.61%
# task = 29, loss = 10.83, test acc = 82.20%
# task = 30, loss = 10.86, test acc = 77.73%
# task = 31, loss = 10.71, test acc = 89.81%
# task = 32, loss = 10.79, test acc = 71.69%
# task = 33, loss = 10.81, test acc = 81.55%
# task = 34, loss = 11.03, test acc = 84.39%
# task = 35, loss = 11.11, test acc = 73.20%
# task = 36, loss = 10.70, test acc = 75.88%
# task = 37, loss = 10.75, test acc = 84.33%
# task = 38, loss = 10.83, test acc = 83.90%
# task = 39, loss = 10.85, test acc = 85.20%
# task = 40, loss = 10.72, test acc = 84.89%
# task = 41, loss = 11.14, test acc = 84.16%
# task = 42, loss = 10.74, test acc = 80.69%
# task = 43, loss = 10.67, test acc = 82.16%
# task = 44, loss = 10.90, test acc = 80.09%
# task = 45, loss = 10.77, test acc = 85.84%
# task = 46, loss = 10.90, test acc = 85.44%
# task = 47, loss = 10.76, test acc = 88.64%
# task = 48, loss = 10.73, test acc = 86.49%
# task = 49, loss = 10.64, test acc = 81.50%
# task = 50, loss = 10.66, test acc = 78.07%
# task = 51, loss = 10.64, test acc = 83.96%
# task = 52, loss = 11.00, test acc = 79.05%
# task = 53, loss = 11.08, test acc = 82.04%
# task = 54, loss = 10.81, test acc = 81.33%
# task = 55, loss = 10.95, test acc = 73.25%
# task = 56, loss = 10.67, test acc = 83.98%
# task = 57, loss = 11.01, test acc = 81.50%
# task = 58, loss = 10.95, test acc = 80.83%
# task = 59, loss = 10.89, test acc = 86.04%
# task = 60, loss = 10.57, test acc = 78.43%
# task = 61, loss = 10.67, test acc = 80.37%
# task = 62, loss = 10.86, test acc = 86.06%
# task = 63, loss = 10.67, test acc = 86.13%
# task = 64, loss = 10.89, test acc = 81.45%
# task = 65, loss = 11.02, test acc = 80.00%
# task = 66, loss = 10.72, test acc = 83.25%
# task = 67, loss = 10.79, test acc = 82.56%
# task = 68, loss = 10.67, test acc = 83.89%
# task = 69, loss = 10.83, test acc = 85.15%
# task = 70, loss = 10.68, test acc = 81.13%
# task = 71, loss = 10.69, test acc = 83.33%
# task = 72, loss = 10.56, test acc = 80.48%
# task = 73, loss = 10.74, test acc = 85.52%
# task = 74, loss = 10.55, test acc = 82.84%
# task = 75, loss = 10.75, test acc = 78.92%
# task = 76, loss = 10.25, test acc = 78.32%
# task = 77, loss = 10.51, test acc = 85.22%
# task = 78, loss = 10.42, test acc = 81.04%
# task = 79, loss = 10.84, test acc = 82.82%
# task = 80, loss = 10.93, test acc = 78.11%
# task = 81, loss = 10.93, test acc = 74.40%
# task = 82, loss = 10.96, test acc = 83.98%
# task = 83, loss = 10.85, test acc = 83.90%
# task = 84, loss = 10.83, test acc = 83.70%
# task = 85, loss = 10.15, test acc = 83.19%
# task = 86, loss = 10.79, test acc = 86.60%
# task = 87, loss = 10.63, test acc = 84.54%
# task = 88, loss = 10.87, test acc = 87.27%
# task = 89, loss = 10.90, test acc = 81.61%
# task = 90, loss = 10.73, test acc = 81.00%
# task = 91, loss = 10.79, test acc = 87.20%
# task = 92, loss = 10.72, test acc = 84.28%
# task = 93, loss = 10.96, test acc = 79.02%
# task = 94, loss = 11.01, test acc = 83.26%
# task = 95, loss = 10.87, test acc = 79.72%
# task = 96, loss = 10.53, test acc = 78.07%
# task = 97, loss = 10.73, test acc = 83.56%
# task = 98, loss = 10.80, test acc = 83.09%
# task = 99, loss = 10.61, test acc = 80.29%
# task = 100, loss = 10.76, test acc = 84.43%
# task = 101, loss = 10.75, test acc = 75.00%
# task = 102, loss = 10.79, test acc = 85.65%
# task = 103, loss = 10.63, test acc = 85.44%
# task = 104, loss = 10.49, test acc = 81.64%
# task = 105, loss = 10.86, test acc = 87.78%
# task = 106, loss = 10.58, test acc = 81.90%
# task = 107, loss = 10.86, test acc = 88.15%
# task = 108, loss = 10.68, test acc = 83.11%
# task = 109, loss = 10.89, test acc = 84.16%
# task = 110, loss = 10.58, test acc = 82.95%
# task = 111, loss = 10.69, test acc = 83.17%
# task = 112, loss = 10.52, test acc = 79.79%
# task = 113, loss = 10.77, test acc = 79.64%
# task = 114, loss = 10.77, test acc = 82.57%
# task = 115, loss = 10.68, test acc = 79.63%
# task = 116, loss = 10.45, test acc = 80.90%
# task = 117, loss = 10.61, test acc = 82.93%
# task = 118, loss = 10.75, test acc = 81.73%
# task = 119, loss = 10.75, test acc = 81.57%
# task = 120, loss = 10.72, test acc = 85.26%
# task = 121, loss = 10.71, test acc = 86.55%
# task = 122, loss = 10.87, test acc = 80.66%
# task = 123, loss = 10.47, test acc = 85.65%
# task = 124, loss = 10.85, test acc = 80.08%
# task = 125, loss = 10.81, test acc = 82.13%
# task = 126, loss = 10.89, test acc = 78.50%
# task = 127, loss = 11.11, test acc = 82.38%
# task = 128, loss = 10.71, test acc = 78.88%
# task = 129, loss = 10.70, test acc = 84.58%
# task = 130, loss = 10.74, test acc = 89.00%
# task = 131, loss = 10.55, test acc = 83.16%
# task = 132, loss = 10.55, test acc = 85.78%
# task = 133, loss = 10.64, test acc = 82.02%
# task = 134, loss = 10.86, test acc = 87.56%
# task = 135, loss = 10.64, test acc = 75.32%
# task = 136, loss = 10.55, test acc = 81.74%
# task = 137, loss = 10.50, test acc = 83.19%
# task = 138, loss = 10.69, test acc = 82.46%
# task = 139, loss = 10.64, test acc = 88.00%
# task = 140, loss = 10.56, test acc = 85.92%
# task = 141, loss = 10.85, test acc = 86.91%
# task = 142, loss = 10.46, test acc = 78.50%
# task = 143, loss = 10.82, test acc = 84.85%
# task = 144, loss = 10.78, test acc = 81.14%
# task = 145, loss = 10.51, test acc = 82.61%
# task = 146, loss = 10.57, test acc = 85.98%
# task = 147, loss = 10.67, test acc = 85.91%
# task = 148, loss = 10.69, test acc = 80.70%
# task = 149, loss = 10.44, test acc = 81.33%
# task = 150, loss = 10.83, test acc = 84.33%
# task = 151, loss = 10.67, test acc = 85.92%
# task = 152, loss = 10.61, test acc = 84.19%
# task = 153, loss = 10.57, test acc = 79.53%
# task = 154, loss = 10.70, test acc = 87.28%
# task = 155, loss = 10.70, test acc = 79.34%
# task = 156, loss = 10.55, test acc = 87.83%
# task = 157, loss = 10.74, test acc = 84.79%
# task = 158, loss = 10.83, test acc = 84.73%
# task = 159, loss = 10.40, test acc = 83.80%
# task = 160, loss = 10.46, test acc = 88.41%
# task = 161, loss = 10.61, test acc = 87.18%
# task = 162, loss = 10.37, test acc = 80.28%
# task = 163, loss = 10.35, test acc = 86.05%
# task = 164, loss = 10.45, test acc = 84.00%
# task = 165, loss = 10.56, test acc = 80.72%
# task = 166, loss = 10.89, test acc = 86.08%
# task = 167, loss = 10.63, test acc = 83.66%
# task = 168, loss = 10.52, test acc = 83.78%
# task = 169, loss = 10.82, test acc = 81.95%
# task = 170, loss = 10.71, test acc = 86.67%
# task = 171, loss = 10.65, test acc = 89.78%
# task = 172, loss = 10.69, test acc = 83.63%
# task = 173, loss = 10.53, test acc = 82.27%
# task = 174, loss = 10.52, test acc = 87.04%
# task = 175, loss = 10.41, test acc = 80.10%
# task = 176, loss = 10.75, test acc = 87.89%
# task = 177, loss = 10.67, test acc = 84.21%
# task = 178, loss = 10.83, test acc = 88.35%
# task = 179, loss = 10.41, test acc = 84.07%
# task = 180, loss = 10.58, test acc = 83.80%
# task = 181, loss = 10.64, test acc = 84.16%
# task = 182, loss = 10.29, test acc = 86.89%
# task = 183, loss = 10.48, test acc = 87.56%
# task = 184, loss = 10.42, test acc = 86.98%
# task = 185, loss = 10.52, test acc = 85.84%
# task = 186, loss = 10.75, test acc = 88.89%
# task = 187, loss = 10.21, test acc = 82.14%
# task = 188, loss = 10.18, test acc = 86.16%
# task = 189, loss = 10.52, test acc = 78.70%
# task = 190, loss = 10.58, test acc = 84.85%
# task = 191, loss = 10.55, test acc = 80.38%
# task = 192, loss = 10.74, test acc = 86.11%
# task = 193, loss = 10.42, test acc = 89.55%
# task = 194, loss = 10.58, test acc = 83.70%
# task = 195, loss = 10.76, test acc = 87.56%
# task = 196, loss = 10.94, test acc = 87.20%
# task = 197, loss = 10.49, test acc = 86.67%
# task = 198, loss = 10.53, test acc = 86.93%
# task = 199, loss = 10.61, test acc = 84.18%
# Model saved as: streaming_model_1.pt
# The best accuracy is 89.81% at episode number 31.
# ========================== Streaming session: 2 ==========================
# Number of Classes (Base + Novel) = 4
# Novel classes are: [2]
# Base Classes: [0, 1]
# Total Novel Classes List: [5, 2]
# task = 0, loss = 15.30, test acc = 81.07%
# task = 1, loss = 15.44, test acc = 78.93%
# task = 2, loss = 15.44, test acc = 82.69%
# task = 3, loss = 15.34, test acc = 83.96%
# task = 4, loss = 15.28, test acc = 81.63%
# task = 5, loss = 15.56, test acc = 81.12%
# task = 6, loss = 15.34, test acc = 78.05%
# task = 7, loss = 15.21, test acc = 81.05%
# task = 8, loss = 14.98, test acc = 74.91%
# task = 9, loss = 15.20, test acc = 80.21%
# task = 10, loss = 15.25, test acc = 81.82%
# task = 11, loss = 14.99, test acc = 75.71%
# task = 12, loss = 15.43, test acc = 79.30%
# task = 13, loss = 15.55, test acc = 77.62%
# task = 14, loss = 15.03, test acc = 80.80%
# task = 15, loss = 15.44, test acc = 81.21%
# task = 16, loss = 15.36, test acc = 79.76%
# task = 17, loss = 15.20, test acc = 80.29%
# task = 18, loss = 14.96, test acc = 82.63%
# task = 19, loss = 15.17, test acc = 69.74%
# task = 20, loss = 15.02, test acc = 82.11%
# task = 21, loss = 15.74, test acc = 72.92%
# task = 22, loss = 15.22, test acc = 76.21%
# task = 23, loss = 15.31, test acc = 79.86%
# task = 24, loss = 15.13, test acc = 85.41%
# task = 25, loss = 15.06, test acc = 77.70%
# task = 26, loss = 15.12, test acc = 75.52%
# task = 27, loss = 15.14, test acc = 81.75%
# task = 28, loss = 15.40, test acc = 72.22%
# task = 29, loss = 15.44, test acc = 80.00%
# task = 30, loss = 15.65, test acc = 84.40%
# task = 31, loss = 14.95, test acc = 81.31%
# task = 32, loss = 15.55, test acc = 81.05%
# task = 33, loss = 15.27, test acc = 83.15%
# task = 34, loss = 14.92, test acc = 80.38%
# task = 35, loss = 14.86, test acc = 80.14%
# task = 36, loss = 15.19, test acc = 82.33%
# task = 37, loss = 15.40, test acc = 77.57%
# task = 38, loss = 15.21, test acc = 84.03%
# task = 39, loss = 15.23, test acc = 78.36%
# task = 40, loss = 15.25, test acc = 74.00%
# task = 41, loss = 15.24, test acc = 80.74%
# task = 42, loss = 15.05, test acc = 84.06%
# task = 43, loss = 15.10, test acc = 78.26%
# task = 44, loss = 15.12, test acc = 87.86%
# task = 45, loss = 14.94, test acc = 79.93%
# task = 46, loss = 15.12, test acc = 76.87%
# task = 47, loss = 15.10, test acc = 86.82%
# task = 48, loss = 15.09, test acc = 87.25%
# task = 49, loss = 15.21, test acc = 79.08%
# task = 50, loss = 15.17, test acc = 82.43%
# task = 51, loss = 15.45, test acc = 81.79%
# task = 52, loss = 15.05, test acc = 83.88%
# task = 53, loss = 15.22, test acc = 80.36%
# task = 54, loss = 15.26, test acc = 80.37%
# task = 55, loss = 14.98, test acc = 76.90%
# task = 56, loss = 14.98, test acc = 79.93%
# task = 57, loss = 15.24, test acc = 79.56%
# task = 58, loss = 15.04, test acc = 76.84%
# task = 59, loss = 15.39, test acc = 76.84%
# task = 60, loss = 14.95, test acc = 78.60%
# task = 61, loss = 15.17, test acc = 77.74%
# task = 62, loss = 15.03, test acc = 78.90%
# task = 63, loss = 15.12, test acc = 84.73%
# task = 64, loss = 15.33, test acc = 85.56%
# task = 65, loss = 15.10, test acc = 82.12%
# task = 66, loss = 15.22, test acc = 79.56%
# task = 67, loss = 14.76, test acc = 69.44%
# task = 68, loss = 14.99, test acc = 79.24%
# task = 69, loss = 14.92, test acc = 83.45%
# task = 70, loss = 14.97, test acc = 79.58%
# task = 71, loss = 15.24, test acc = 77.24%
# task = 72, loss = 15.26, test acc = 79.64%
# task = 73, loss = 15.16, test acc = 78.75%
# task = 74, loss = 14.91, test acc = 76.82%
# task = 75, loss = 15.08, test acc = 82.33%
# task = 76, loss = 15.19, test acc = 82.51%
# task = 77, loss = 15.01, test acc = 80.07%
# task = 78, loss = 15.25, test acc = 84.29%
# task = 79, loss = 15.28, test acc = 81.88%
# task = 80, loss = 15.05, test acc = 81.95%
# task = 81, loss = 14.79, test acc = 79.17%
# task = 82, loss = 15.24, test acc = 79.31%
# task = 83, loss = 15.29, test acc = 80.61%
# task = 84, loss = 15.02, test acc = 84.03%
# task = 85, loss = 15.26, test acc = 77.37%
# task = 86, loss = 15.45, test acc = 78.91%
# task = 87, loss = 15.06, test acc = 81.85%
# task = 88, loss = 15.15, test acc = 82.55%
# task = 89, loss = 15.03, test acc = 81.18%
# task = 90, loss = 15.13, test acc = 73.87%
# task = 91, loss = 15.22, test acc = 79.49%
# task = 92, loss = 15.09, test acc = 80.28%
# task = 93, loss = 14.80, test acc = 71.38%
# task = 94, loss = 15.03, test acc = 81.92%
# task = 95, loss = 15.00, test acc = 88.32%
# task = 96, loss = 15.11, test acc = 80.21%
# task = 97, loss = 14.92, test acc = 84.42%
# task = 98, loss = 15.17, test acc = 78.46%
# task = 99, loss = 14.79, test acc = 78.71%
# task = 100, loss = 15.07, test acc = 79.66%
# task = 101, loss = 15.04, test acc = 82.61%
# task = 102, loss = 15.13, test acc = 77.35%
# task = 103, loss = 15.23, test acc = 81.11%
# task = 104, loss = 14.75, test acc = 81.05%
# task = 105, loss = 15.08, test acc = 84.12%
# task = 106, loss = 15.14, test acc = 82.49%
# task = 107, loss = 15.10, test acc = 81.49%
# task = 108, loss = 14.86, test acc = 74.65%
# task = 109, loss = 15.12, test acc = 76.89%
# task = 110, loss = 14.81, test acc = 72.14%
# task = 111, loss = 15.06, test acc = 81.03%
# task = 112, loss = 14.96, test acc = 78.93%
# task = 113, loss = 15.18, test acc = 78.80%
# task = 114, loss = 14.97, test acc = 83.57%
# task = 115, loss = 14.79, test acc = 84.03%
# task = 116, loss = 15.12, test acc = 78.03%
# task = 117, loss = 15.06, test acc = 83.72%
# task = 118, loss = 14.88, test acc = 83.46%
# task = 119, loss = 14.77, test acc = 82.62%
# task = 120, loss = 14.94, test acc = 78.43%
# task = 121, loss = 14.78, test acc = 76.82%
# task = 122, loss = 14.71, test acc = 78.55%
# task = 123, loss = 15.12, test acc = 85.31%
# task = 124, loss = 14.91, test acc = 79.55%
# task = 125, loss = 14.92, test acc = 76.87%
# task = 126, loss = 15.02, test acc = 82.00%
# task = 127, loss = 14.80, test acc = 85.87%
# task = 128, loss = 15.25, test acc = 77.53%
# task = 129, loss = 14.96, test acc = 82.05%
# task = 130, loss = 14.92, test acc = 82.33%
# task = 131, loss = 15.06, test acc = 79.85%
# task = 132, loss = 15.02, test acc = 75.46%
# task = 133, loss = 15.00, test acc = 77.97%
# task = 134, loss = 15.31, test acc = 82.18%
# task = 135, loss = 15.03, test acc = 76.57%
# task = 136, loss = 14.85, test acc = 80.85%
# task = 137, loss = 14.94, test acc = 83.16%
# task = 138, loss = 15.08, test acc = 78.45%
# task = 139, loss = 14.93, test acc = 80.43%
# task = 140, loss = 14.99, test acc = 80.85%
# task = 141, loss = 15.24, test acc = 79.50%
# task = 142, loss = 15.01, test acc = 80.27%
# task = 143, loss = 14.71, test acc = 77.78%
# task = 144, loss = 15.16, test acc = 79.47%
# task = 145, loss = 14.67, test acc = 86.51%
# task = 146, loss = 14.92, test acc = 77.97%
# task = 147, loss = 14.77, test acc = 83.39%
# task = 148, loss = 14.73, test acc = 77.57%
# task = 149, loss = 14.81, test acc = 79.31%
# task = 150, loss = 14.90, test acc = 83.87%
# task = 151, loss = 14.89, test acc = 80.71%
# task = 152, loss = 14.96, test acc = 75.70%
# task = 153, loss = 14.88, test acc = 82.31%
# task = 154, loss = 14.83, test acc = 81.34%
# task = 155, loss = 15.08, test acc = 76.55%
# task = 156, loss = 15.02, test acc = 79.93%
# task = 157, loss = 15.02, test acc = 80.67%
# task = 158, loss = 14.80, test acc = 85.25%
# task = 159, loss = 14.86, test acc = 78.65%
# task = 160, loss = 15.04, test acc = 77.40%
# task = 161, loss = 14.93, test acc = 78.25%
# task = 162, loss = 14.94, test acc = 80.50%
# task = 163, loss = 15.16, test acc = 80.22%
# task = 164, loss = 15.04, test acc = 81.25%
# task = 165, loss = 14.68, test acc = 81.82%
# task = 166, loss = 14.88, test acc = 81.75%
# task = 167, loss = 14.79, test acc = 81.47%
# task = 168, loss = 14.85, test acc = 79.17%
# task = 169, loss = 14.91, test acc = 79.66%
# task = 170, loss = 15.32, test acc = 80.14%
# task = 171, loss = 14.69, test acc = 72.86%
# task = 172, loss = 15.03, test acc = 84.84%
# task = 173, loss = 14.77, test acc = 80.42%
# task = 174, loss = 14.87, test acc = 78.99%
# task = 175, loss = 14.91, test acc = 82.14%
# task = 176, loss = 14.67, test acc = 81.95%
# task = 177, loss = 14.92, test acc = 79.73%
# task = 178, loss = 14.57, test acc = 81.08%
# task = 179, loss = 14.74, test acc = 84.56%
# task = 180, loss = 14.75, test acc = 81.32%
# task = 181, loss = 15.07, test acc = 85.82%
# task = 182, loss = 14.92, test acc = 83.88%
# task = 183, loss = 14.89, test acc = 81.36%
# task = 184, loss = 14.89, test acc = 85.19%
# task = 185, loss = 14.98, test acc = 76.39%
# task = 186, loss = 14.93, test acc = 78.40%
# task = 187, loss = 14.57, test acc = 85.24%
# task = 188, loss = 14.56, test acc = 85.26%
# task = 189, loss = 14.67, test acc = 80.97%
# task = 190, loss = 14.63, test acc = 84.57%
# task = 191, loss = 14.72, test acc = 87.54%
# task = 192, loss = 14.91, test acc = 77.66%
# task = 193, loss = 14.94, test acc = 80.42%
# task = 194, loss = 14.57, test acc = 82.75%
# task = 195, loss = 14.75, test acc = 78.38%
# task = 196, loss = 15.10, test acc = 67.35%
# task = 197, loss = 14.79, test acc = 81.85%
# task = 198, loss = 14.61, test acc = 80.36%
# task = 199, loss = 15.02, test acc = 81.02%
# Model saved as: streaming_model_2.pt
# The best accuracy is 88.32% at episode number 95.
# ========================== Streaming session: 3 ==========================
# Number of Classes (Base + Novel) = 5
# Novel classes are: [4]
# Base Classes: [0, 1]
# Total Novel Classes List: [5, 2, 4]
# task = 0, loss = 19.74, test acc = 75.53%
# task = 1, loss = 19.71, test acc = 64.47%
# task = 2, loss = 19.85, test acc = 69.86%
# task = 3, loss = 19.66, test acc = 72.38%
# task = 4, loss = 19.68, test acc = 71.09%
# task = 5, loss = 19.65, test acc = 69.27%
# task = 6, loss = 19.72, test acc = 74.80%
# task = 7, loss = 19.90, test acc = 69.69%
# task = 8, loss = 19.78, test acc = 72.16%
# task = 9, loss = 19.44, test acc = 66.12%
# task = 10, loss = 20.03, test acc = 70.22%
# task = 11, loss = 19.89, test acc = 71.28%
# task = 12, loss = 19.65, test acc = 67.40%
# task = 13, loss = 19.65, test acc = 74.93%
# task = 14, loss = 19.64, test acc = 72.32%
# task = 15, loss = 19.66, test acc = 63.59%
# task = 16, loss = 19.71, test acc = 66.57%
# task = 17, loss = 19.56, test acc = 74.32%
# task = 18, loss = 19.50, test acc = 74.15%
# task = 19, loss = 19.60, test acc = 70.93%
# task = 20, loss = 19.58, test acc = 70.66%
# task = 21, loss = 19.65, test acc = 74.19%
# task = 22, loss = 19.76, test acc = 70.99%
# task = 23, loss = 19.48, test acc = 71.66%
# task = 24, loss = 19.80, test acc = 71.47%
# task = 25, loss = 19.59, test acc = 70.72%
# task = 26, loss = 19.80, test acc = 62.50%
# task = 27, loss = 19.22, test acc = 79.94%
# task = 28, loss = 19.61, test acc = 69.95%
# task = 29, loss = 19.78, test acc = 70.85%
# task = 30, loss = 19.77, test acc = 72.01%
# task = 31, loss = 19.53, test acc = 69.71%
# task = 32, loss = 19.43, test acc = 71.15%
# task = 33, loss = 19.70, test acc = 72.32%
# task = 34, loss = 19.64, test acc = 71.71%
# task = 35, loss = 19.36, test acc = 70.94%
# task = 36, loss = 19.59, test acc = 72.22%
# task = 37, loss = 19.62, test acc = 69.84%
# task = 38, loss = 19.58, test acc = 70.93%
# task = 39, loss = 19.57, test acc = 73.10%
# task = 40, loss = 19.52, test acc = 70.27%
# task = 41, loss = 19.63, test acc = 68.80%
# task = 42, loss = 19.64, test acc = 69.71%
# task = 43, loss = 19.56, test acc = 75.07%
# task = 44, loss = 19.54, test acc = 75.00%
# task = 45, loss = 19.69, test acc = 72.85%
# task = 46, loss = 19.65, test acc = 72.29%
# task = 47, loss = 19.64, test acc = 76.20%
# task = 48, loss = 19.69, test acc = 70.63%
# task = 49, loss = 19.61, test acc = 70.73%
# task = 50, loss = 19.59, test acc = 72.70%
# task = 51, loss = 19.45, test acc = 70.42%
# task = 52, loss = 19.74, test acc = 71.64%
# task = 53, loss = 19.45, test acc = 68.65%
# task = 54, loss = 19.44, test acc = 71.82%
# task = 55, loss = 19.43, test acc = 76.33%
# task = 56, loss = 19.56, test acc = 69.27%
# task = 57, loss = 19.82, test acc = 69.33%
# task = 58, loss = 19.54, test acc = 67.66%
# task = 59, loss = 19.65, test acc = 69.95%
# task = 60, loss = 19.50, test acc = 68.10%
# task = 61, loss = 19.93, test acc = 71.77%
# task = 62, loss = 19.67, test acc = 74.19%
# task = 63, loss = 19.38, test acc = 71.94%
# task = 64, loss = 19.33, test acc = 73.01%
# task = 65, loss = 19.56, test acc = 71.07%
# task = 66, loss = 19.49, test acc = 70.67%
# task = 67, loss = 19.75, test acc = 72.75%
# task = 68, loss = 19.46, test acc = 74.93%
# task = 69, loss = 19.38, test acc = 66.76%
# task = 70, loss = 19.55, test acc = 72.30%
# task = 71, loss = 19.63, test acc = 71.13%
# task = 72, loss = 19.47, test acc = 66.42%
# task = 73, loss = 19.64, test acc = 69.17%
# task = 74, loss = 19.65, test acc = 68.80%
# task = 75, loss = 19.66, test acc = 62.43%
# task = 76, loss = 19.55, test acc = 73.64%
# task = 77, loss = 19.49, test acc = 69.95%
# task = 78, loss = 19.53, test acc = 71.01%
# task = 79, loss = 19.39, test acc = 71.92%
# task = 80, loss = 19.40, test acc = 71.67%
# task = 81, loss = 19.55, test acc = 69.68%
# task = 82, loss = 19.39, test acc = 73.55%
# task = 83, loss = 19.27, test acc = 70.83%
# task = 84, loss = 19.49, test acc = 69.50%
# task = 85, loss = 19.63, test acc = 75.20%
# task = 86, loss = 19.51, test acc = 63.76%
# task = 87, loss = 19.54, test acc = 70.71%
# task = 88, loss = 19.33, test acc = 68.75%
# task = 89, loss = 19.50, test acc = 67.34%
# task = 90, loss = 19.42, test acc = 72.53%
# task = 91, loss = 19.43, test acc = 74.06%
# task = 92, loss = 19.26, test acc = 70.67%
# task = 93, loss = 19.26, test acc = 66.76%
# task = 94, loss = 19.64, test acc = 67.63%
# task = 95, loss = 19.40, test acc = 68.80%
# task = 96, loss = 19.43, test acc = 70.93%
# task = 97, loss = 19.26, test acc = 71.47%
# task = 98, loss = 19.39, test acc = 74.35%
# task = 99, loss = 19.36, test acc = 69.73%
# task = 100, loss = 19.57, test acc = 70.16%
# task = 101, loss = 19.16, test acc = 70.40%
# task = 102, loss = 19.45, test acc = 70.31%
# task = 103, loss = 19.24, test acc = 71.50%
# task = 104, loss = 19.14, test acc = 73.01%
# task = 105, loss = 19.30, test acc = 77.05%
# task = 106, loss = 19.34, test acc = 76.00%
# task = 107, loss = 19.34, test acc = 69.89%
# task = 108, loss = 19.04, test acc = 79.46%
# task = 109, loss = 19.32, test acc = 65.13%
# task = 110, loss = 19.22, test acc = 68.68%
# task = 111, loss = 19.29, test acc = 70.08%
# task = 112, loss = 19.13, test acc = 71.88%
# task = 113, loss = 19.35, test acc = 68.68%
# task = 114, loss = 19.35, test acc = 69.42%
# task = 115, loss = 19.61, test acc = 64.81%
# task = 116, loss = 19.24, test acc = 69.83%
# task = 117, loss = 19.66, test acc = 73.71%
# task = 118, loss = 19.21, test acc = 68.58%
# task = 119, loss = 19.37, test acc = 69.17%
# task = 120, loss = 19.48, test acc = 66.58%
# task = 121, loss = 19.21, test acc = 71.28%
# task = 122, loss = 19.23, test acc = 68.99%
# task = 123, loss = 19.31, test acc = 68.68%
# task = 124, loss = 19.36, test acc = 70.46%
# task = 125, loss = 19.39, test acc = 71.27%
# task = 126, loss = 19.46, test acc = 67.40%
# task = 127, loss = 19.19, test acc = 75.07%
# task = 128, loss = 19.21, test acc = 71.35%
# task = 129, loss = 19.32, test acc = 68.75%
# task = 130, loss = 19.49, test acc = 68.92%
# task = 131, loss = 19.34, test acc = 69.51%
# task = 132, loss = 19.38, test acc = 70.94%
# task = 133, loss = 19.21, test acc = 70.78%
# task = 134, loss = 19.50, test acc = 70.89%
# task = 135, loss = 19.19, test acc = 72.30%
# task = 136, loss = 19.45, test acc = 72.56%
# task = 137, loss = 19.21, test acc = 75.63%
# task = 138, loss = 19.22, test acc = 67.95%
# task = 139, loss = 19.38, test acc = 70.14%
# task = 140, loss = 19.36, test acc = 72.24%
# task = 141, loss = 19.42, test acc = 73.64%
# task = 142, loss = 19.20, test acc = 75.67%
# task = 143, loss = 19.14, test acc = 75.68%
# task = 144, loss = 19.40, test acc = 71.35%
# task = 145, loss = 19.38, test acc = 67.45%
# task = 146, loss = 19.23, test acc = 69.87%
# task = 147, loss = 19.18, test acc = 71.08%
# task = 148, loss = 18.88, test acc = 74.39%
# task = 149, loss = 19.08, test acc = 70.96%
# task = 150, loss = 19.30, test acc = 69.89%
# task = 151, loss = 19.27, test acc = 73.89%
# task = 152, loss = 19.32, test acc = 72.30%
# task = 153, loss = 19.45, test acc = 72.22%
# task = 154, loss = 19.40, test acc = 70.03%
# task = 155, loss = 19.21, test acc = 72.67%
# task = 156, loss = 19.15, test acc = 73.45%
# task = 157, loss = 19.16, test acc = 72.68%
# task = 158, loss = 19.20, test acc = 70.72%
# task = 159, loss = 18.99, test acc = 75.71%
# task = 160, loss = 19.01, test acc = 70.99%
# task = 161, loss = 19.32, test acc = 68.99%
# task = 162, loss = 19.19, test acc = 71.43%
# task = 163, loss = 19.06, test acc = 70.19%
# task = 164, loss = 19.23, test acc = 70.22%
# task = 165, loss = 19.05, test acc = 69.62%
# task = 166, loss = 18.99, test acc = 77.90%
# task = 167, loss = 19.11, test acc = 74.10%
# task = 168, loss = 19.21, test acc = 76.28%
# task = 169, loss = 19.00, test acc = 71.50%
# task = 170, loss = 19.05, test acc = 74.37%
# task = 171, loss = 19.42, test acc = 73.32%
# task = 172, loss = 18.91, test acc = 73.67%
# task = 173, loss = 19.26, test acc = 69.32%
# task = 174, loss = 19.15, test acc = 70.82%
# task = 175, loss = 19.16, test acc = 73.09%
# task = 176, loss = 19.16, test acc = 68.94%
# task = 177, loss = 18.96, test acc = 69.88%
# task = 178, loss = 19.25, test acc = 73.76%
# task = 179, loss = 19.14, test acc = 69.41%
# task = 180, loss = 19.14, test acc = 72.33%
# task = 181, loss = 19.07, test acc = 63.59%
# task = 182, loss = 19.23, test acc = 70.41%
# task = 183, loss = 19.17, test acc = 70.33%
# task = 184, loss = 19.13, test acc = 73.00%
# task = 185, loss = 18.76, test acc = 74.44%
# task = 186, loss = 19.02, test acc = 73.98%
# task = 187, loss = 19.24, test acc = 68.77%
# task = 188, loss = 18.92, test acc = 68.23%
# task = 189, loss = 18.96, test acc = 75.34%
# task = 190, loss = 18.99, test acc = 74.42%
# task = 191, loss = 19.20, test acc = 70.27%
# task = 192, loss = 19.23, test acc = 73.81%
# task = 193, loss = 19.01, test acc = 71.62%
# task = 194, loss = 18.92, test acc = 71.16%
# task = 195, loss = 19.06, test acc = 74.06%
# task = 196, loss = 19.27, test acc = 72.65%
# task = 197, loss = 19.08, test acc = 76.57%
# task = 198, loss = 19.08, test acc = 68.09%
# task = 199, loss = 18.84, test acc = 70.56%
# Model saved as: streaming_model_3.pt
# The best accuracy is 79.94% at episode number 27.
# ========================== Streaming session: 4 ==========================
# Number of Classes (Base + Novel) = 6
# Novel classes are: [3]
# Base Classes: [0, 1]
# Total Novel Classes List: [5, 2, 4, 3]
# task = 0, loss = 24.42, test acc = 65.69%
# task = 1, loss = 24.45, test acc = 71.83%
# task = 2, loss = 25.25, test acc = 63.49%
# task = 3, loss = 25.03, test acc = 69.20%
# task = 4, loss = 24.69, test acc = 62.47%
# task = 5, loss = 24.69, test acc = 72.69%
# task = 6, loss = 24.83, test acc = 58.80%
# task = 7, loss = 24.86, test acc = 64.77%
# task = 8, loss = 24.89, test acc = 60.59%
# task = 9, loss = 24.76, test acc = 68.57%
# task = 10, loss = 24.90, test acc = 73.03%
# task = 11, loss = 24.50, test acc = 67.93%
# task = 12, loss = 24.45, test acc = 67.86%
# task = 13, loss = 24.78, test acc = 60.53%
# task = 14, loss = 24.47, test acc = 71.67%
# task = 15, loss = 24.37, test acc = 68.58%
# task = 16, loss = 24.38, test acc = 68.51%
# task = 17, loss = 24.62, test acc = 68.53%
# task = 18, loss = 24.54, test acc = 67.73%
# task = 19, loss = 25.03, test acc = 71.58%
# task = 20, loss = 24.74, test acc = 72.11%
# task = 21, loss = 24.64, test acc = 69.15%
# task = 22, loss = 24.43, test acc = 69.85%
# task = 23, loss = 24.37, test acc = 72.54%
# task = 24, loss = 24.92, test acc = 66.19%
# task = 25, loss = 24.25, test acc = 69.37%
# task = 26, loss = 24.41, test acc = 71.90%
# task = 27, loss = 24.77, test acc = 67.28%
# task = 28, loss = 24.43, test acc = 68.98%
# task = 29, loss = 24.48, test acc = 67.09%
# task = 30, loss = 24.52, test acc = 66.53%
# task = 31, loss = 24.21, test acc = 74.26%
# task = 32, loss = 24.53, test acc = 64.29%
# task = 33, loss = 24.52, test acc = 63.83%
# task = 34, loss = 24.49, test acc = 71.90%
# task = 35, loss = 24.70, test acc = 69.37%
# task = 36, loss = 24.43, test acc = 63.06%
# task = 37, loss = 24.64, test acc = 70.39%
# task = 38, loss = 24.33, test acc = 69.68%
# task = 39, loss = 24.74, test acc = 71.19%
# task = 40, loss = 24.70, test acc = 67.98%
# task = 41, loss = 24.52, test acc = 67.44%
# task = 42, loss = 24.42, test acc = 71.28%
# task = 43, loss = 24.94, test acc = 65.02%
# task = 44, loss = 24.51, test acc = 69.18%
# task = 45, loss = 24.56, test acc = 61.07%
# task = 46, loss = 24.69, test acc = 67.27%
# task = 47, loss = 24.67, test acc = 70.65%
# task = 48, loss = 24.49, test acc = 69.67%
# task = 49, loss = 24.29, test acc = 71.37%
# task = 50, loss = 24.53, test acc = 68.26%
# task = 51, loss = 24.27, test acc = 70.09%
# task = 52, loss = 24.57, test acc = 67.22%
# task = 53, loss = 24.36, test acc = 70.64%
# task = 54, loss = 24.45, test acc = 65.21%
# task = 55, loss = 24.52, test acc = 71.55%
# task = 56, loss = 24.67, test acc = 70.11%
# task = 57, loss = 24.23, test acc = 63.10%
# task = 58, loss = 24.55, test acc = 64.61%
# task = 59, loss = 24.48, test acc = 68.41%
# task = 60, loss = 24.58, test acc = 66.53%
# task = 61, loss = 24.41, test acc = 71.92%
# task = 62, loss = 24.04, test acc = 69.77%
# task = 63, loss = 24.68, test acc = 72.94%
# task = 64, loss = 24.40, test acc = 67.80%
# task = 65, loss = 24.52, test acc = 65.58%
# task = 66, loss = 24.73, test acc = 68.97%
# task = 67, loss = 24.24, test acc = 70.11%
# task = 68, loss = 24.36, test acc = 68.58%
# task = 69, loss = 24.47, test acc = 73.67%
# task = 70, loss = 24.47, test acc = 71.84%
# task = 71, loss = 24.42, test acc = 71.14%
# task = 72, loss = 24.46, test acc = 71.57%
# task = 73, loss = 24.26, test acc = 71.95%
# task = 74, loss = 24.78, test acc = 69.23%
# task = 75, loss = 24.55, test acc = 66.53%
# task = 76, loss = 24.49, test acc = 68.74%
# task = 77, loss = 24.54, test acc = 64.93%
# task = 78, loss = 24.35, test acc = 72.13%
# task = 79, loss = 24.05, test acc = 68.83%
# task = 80, loss = 24.36, test acc = 72.00%
# task = 81, loss = 24.18, test acc = 68.74%
# task = 82, loss = 24.50, test acc = 65.96%
# task = 83, loss = 24.04, test acc = 70.19%
# task = 84, loss = 24.72, test acc = 60.52%
# task = 85, loss = 24.48, test acc = 68.46%
# task = 86, loss = 24.51, test acc = 63.70%
# task = 87, loss = 24.28, test acc = 69.94%
# task = 88, loss = 24.02, test acc = 67.89%
# task = 89, loss = 24.47, test acc = 77.32%
# task = 90, loss = 24.52, test acc = 63.16%
# task = 91, loss = 24.66, test acc = 70.98%
# task = 92, loss = 24.24, test acc = 67.50%
# task = 93, loss = 24.35, test acc = 69.45%
# task = 94, loss = 24.27, test acc = 69.58%
# task = 95, loss = 24.21, test acc = 61.30%
# task = 96, loss = 24.27, test acc = 71.19%
# task = 97, loss = 24.30, test acc = 71.86%
# task = 98, loss = 24.12, test acc = 67.94%
# task = 99, loss = 24.68, test acc = 64.32%
# task = 100, loss = 24.36, test acc = 70.00%
# task = 101, loss = 24.91, test acc = 69.02%
# task = 102, loss = 23.94, test acc = 71.31%
# task = 103, loss = 24.25, test acc = 66.67%
# task = 104, loss = 23.93, test acc = 70.00%
# task = 105, loss = 24.03, test acc = 67.88%
# task = 106, loss = 24.56, test acc = 59.40%
# task = 107, loss = 24.25, test acc = 70.20%
# task = 108, loss = 24.16, test acc = 70.95%
# task = 109, loss = 24.58, test acc = 63.38%
# task = 110, loss = 24.29, test acc = 66.74%
# task = 111, loss = 23.96, test acc = 66.59%
# task = 112, loss = 24.02, test acc = 69.08%
# task = 113, loss = 24.03, test acc = 70.91%
# task = 114, loss = 24.30, test acc = 66.18%
# task = 115, loss = 24.59, test acc = 68.67%
# task = 116, loss = 23.99, test acc = 72.03%
# task = 117, loss = 24.36, test acc = 68.07%
# task = 118, loss = 24.31, test acc = 68.85%
# task = 119, loss = 24.10, test acc = 69.04%
# task = 120, loss = 24.41, test acc = 65.62%
# task = 121, loss = 24.38, test acc = 70.73%
# task = 122, loss = 23.90, test acc = 68.71%
# task = 123, loss = 24.58, test acc = 64.85%
# task = 124, loss = 24.40, test acc = 74.07%
# task = 125, loss = 24.12, test acc = 66.74%
# task = 126, loss = 23.98, test acc = 72.16%
# task = 127, loss = 23.75, test acc = 69.44%
# task = 128, loss = 24.25, test acc = 70.16%
# task = 129, loss = 24.13, test acc = 71.25%
# task = 130, loss = 24.10, test acc = 72.09%
# task = 131, loss = 24.30, test acc = 72.77%
# task = 132, loss = 24.17, test acc = 70.87%
# task = 133, loss = 24.12, test acc = 66.81%
# task = 134, loss = 24.02, test acc = 67.37%
# task = 135, loss = 24.51, test acc = 66.60%
# task = 136, loss = 24.20, test acc = 69.25%
# task = 137, loss = 24.06, test acc = 72.16%
# task = 138, loss = 24.28, test acc = 70.26%
# task = 139, loss = 24.20, test acc = 74.05%
# task = 140, loss = 24.04, test acc = 68.83%
# task = 141, loss = 24.39, test acc = 65.70%
# task = 142, loss = 24.22, test acc = 64.64%
# task = 143, loss = 24.19, test acc = 63.64%
# task = 144, loss = 23.64, test acc = 64.76%
# task = 145, loss = 24.08, test acc = 70.00%
# task = 146, loss = 24.21, test acc = 69.35%
# task = 147, loss = 24.07, test acc = 73.42%
# task = 148, loss = 24.03, test acc = 70.43%
# task = 149, loss = 24.06, test acc = 70.71%
# task = 150, loss = 23.98, test acc = 73.61%
# task = 151, loss = 23.81, test acc = 68.91%
# task = 152, loss = 24.24, test acc = 69.54%
# task = 153, loss = 23.96, test acc = 63.06%
# task = 154, loss = 23.72, test acc = 70.28%
# task = 155, loss = 24.22, test acc = 73.43%
# task = 156, loss = 24.28, test acc = 68.10%
# task = 157, loss = 24.11, test acc = 67.72%
# task = 158, loss = 24.41, test acc = 69.25%
# task = 159, loss = 24.10, test acc = 71.95%
# task = 160, loss = 23.92, test acc = 71.40%
# task = 161, loss = 24.08, test acc = 71.25%
# task = 162, loss = 23.90, test acc = 67.87%
# task = 163, loss = 23.81, test acc = 70.91%
# task = 164, loss = 24.03, test acc = 70.85%
# task = 165, loss = 24.09, test acc = 64.45%
# task = 166, loss = 24.20, test acc = 63.50%
# task = 167, loss = 23.90, test acc = 67.14%
# task = 168, loss = 23.93, test acc = 70.78%
# task = 169, loss = 24.10, test acc = 62.88%
# task = 170, loss = 24.12, test acc = 70.51%
# task = 171, loss = 24.33, test acc = 68.98%
# task = 172, loss = 23.98, test acc = 61.23%
# task = 173, loss = 23.68, test acc = 68.90%
# task = 174, loss = 23.79, test acc = 68.15%
# task = 175, loss = 24.02, test acc = 69.55%
# task = 176, loss = 24.03, test acc = 68.63%
# task = 177, loss = 24.06, test acc = 65.81%
# task = 178, loss = 24.06, test acc = 65.74%
# task = 179, loss = 24.05, test acc = 69.56%
# task = 180, loss = 23.88, test acc = 74.21%
# task = 181, loss = 23.59, test acc = 72.11%
# task = 182, loss = 24.19, test acc = 67.56%
# task = 183, loss = 23.89, test acc = 68.91%
# task = 184, loss = 23.57, test acc = 74.61%
# task = 185, loss = 23.70, test acc = 71.58%
# task = 186, loss = 24.20, test acc = 66.24%
# task = 187, loss = 23.86, test acc = 69.13%
# task = 188, loss = 24.01, test acc = 65.28%
# task = 189, loss = 23.92, test acc = 74.57%
# task = 190, loss = 24.15, test acc = 68.50%
# task = 191, loss = 24.30, test acc = 69.23%
# task = 192, loss = 24.30, test acc = 64.22%
# task = 193, loss = 24.27, test acc = 66.11%
# task = 194, loss = 23.76, test acc = 69.54%
# task = 195, loss = 24.20, test acc = 68.06%
# task = 196, loss = 24.07, test acc = 67.57%
# task = 197, loss = 23.66, test acc = 63.03%
# task = 198, loss = 24.17, test acc = 67.86%
# task = 199, loss = 23.91, test acc = 75.16%
# Model saved as: streaming_model_4.pt
# The best accuracy is 77.32% at episode number 89.
# ========================== Streaming session: 5 ==========================
# Number of Classes (Base + Novel) = 7
# Novel classes are: [6]
# Base Classes: [0, 1]
# Total Novel Classes List: [5, 2, 4, 3, 6]
# task = 0, loss = 29.16, test acc = 69.56%
# task = 1, loss = 28.94, test acc = 66.86%
# task = 2, loss = 29.02, test acc = 69.32%
# task = 3, loss = 28.53, test acc = 67.36%
# task = 4, loss = 29.07, test acc = 72.81%
# task = 5, loss = 29.38, test acc = 69.42%
# task = 6, loss = 29.19, test acc = 66.17%
# task = 7, loss = 28.79, test acc = 69.83%
# task = 8, loss = 28.75, test acc = 69.67%
# task = 9, loss = 28.88, test acc = 70.00%
# task = 10, loss = 29.12, test acc = 75.18%
# task = 11, loss = 28.57, test acc = 70.42%
# task = 12, loss = 28.88, test acc = 70.68%
# task = 13, loss = 28.47, test acc = 65.15%
# task = 14, loss = 28.99, test acc = 70.55%
# task = 15, loss = 28.31, test acc = 72.05%
# task = 16, loss = 28.88, test acc = 68.69%
# task = 17, loss = 28.69, test acc = 71.04%
# task = 18, loss = 29.00, test acc = 74.39%
# task = 19, loss = 29.24, test acc = 68.39%
# task = 20, loss = 28.95, test acc = 72.71%
# task = 21, loss = 28.85, test acc = 68.90%
# task = 22, loss = 28.58, test acc = 71.80%
# task = 23, loss = 28.71, test acc = 71.25%
# task = 24, loss = 28.67, test acc = 70.23%
# task = 25, loss = 28.67, test acc = 71.74%
# task = 26, loss = 28.41, test acc = 74.08%
# task = 27, loss = 28.77, test acc = 70.53%
# task = 28, loss = 28.82, test acc = 73.51%
# task = 29, loss = 28.88, test acc = 72.11%
# task = 30, loss = 29.02, test acc = 72.51%
# task = 31, loss = 28.42, test acc = 72.08%
# task = 32, loss = 29.00, test acc = 71.46%
# task = 33, loss = 29.10, test acc = 68.44%
# task = 34, loss = 28.78, test acc = 70.22%
# task = 35, loss = 28.54, test acc = 69.07%
# task = 36, loss = 29.10, test acc = 64.71%
# task = 37, loss = 28.73, test acc = 71.11%
# task = 38, loss = 28.98, test acc = 69.98%
# task = 39, loss = 28.08, test acc = 70.43%
# task = 40, loss = 28.64, test acc = 68.01%
# task = 41, loss = 28.72, test acc = 67.77%
# task = 42, loss = 28.29, test acc = 67.90%
# task = 43, loss = 28.26, test acc = 72.97%
# task = 44, loss = 28.58, test acc = 67.83%
# task = 45, loss = 28.76, test acc = 69.98%
# task = 46, loss = 28.43, test acc = 69.16%
# task = 47, loss = 28.94, test acc = 69.07%
# task = 48, loss = 28.13, test acc = 70.72%
# task = 49, loss = 28.29, test acc = 77.15%
# task = 50, loss = 28.73, test acc = 71.53%
# task = 51, loss = 28.73, test acc = 67.94%
# task = 52, loss = 28.41, test acc = 70.43%
# task = 53, loss = 28.48, test acc = 71.58%
# task = 54, loss = 28.55, test acc = 70.52%
# task = 55, loss = 28.71, test acc = 76.13%
# task = 56, loss = 28.68, test acc = 69.71%
# task = 57, loss = 28.26, test acc = 71.81%
# task = 58, loss = 28.69, test acc = 74.57%
# task = 59, loss = 29.05, test acc = 68.23%
# task = 60, loss = 28.68, test acc = 71.51%
# task = 61, loss = 28.87, test acc = 68.07%
# task = 62, loss = 28.51, test acc = 70.72%
# task = 63, loss = 28.33, test acc = 69.51%
# task = 64, loss = 28.24, test acc = 69.66%
# task = 65, loss = 28.65, test acc = 69.23%
# task = 66, loss = 28.99, test acc = 70.93%
# task = 67, loss = 28.58, test acc = 69.66%
# task = 68, loss = 28.45, test acc = 66.73%
# task = 69, loss = 28.64, test acc = 66.54%
# task = 70, loss = 28.64, test acc = 68.40%
# task = 71, loss = 28.51, test acc = 73.03%
# task = 72, loss = 28.09, test acc = 70.44%
# task = 73, loss = 28.48, test acc = 72.41%
# task = 74, loss = 28.84, test acc = 65.51%
# task = 75, loss = 28.31, test acc = 70.72%
# task = 76, loss = 28.30, test acc = 72.69%
# task = 77, loss = 28.61, test acc = 68.89%
# task = 78, loss = 28.22, test acc = 71.10%
# task = 79, loss = 28.35, test acc = 66.54%
# task = 80, loss = 28.61, test acc = 71.12%
# task = 81, loss = 28.35, test acc = 68.86%
# task = 82, loss = 28.50, test acc = 69.33%
# task = 83, loss = 27.87, test acc = 67.84%
# task = 84, loss = 28.66, test acc = 71.69%
# task = 85, loss = 28.23, test acc = 72.19%
# task = 86, loss = 28.39, test acc = 69.73%
# task = 87, loss = 29.24, test acc = 73.09%
# task = 88, loss = 28.39, test acc = 71.10%
# task = 89, loss = 28.25, test acc = 74.21%
# task = 90, loss = 28.89, test acc = 67.44%
# task = 91, loss = 28.04, test acc = 71.85%
# task = 92, loss = 28.28, test acc = 73.14%
# task = 93, loss = 28.74, test acc = 67.04%
# task = 94, loss = 28.58, test acc = 74.95%
# task = 95, loss = 28.09, test acc = 73.06%
# task = 96, loss = 28.42, test acc = 71.59%
# task = 97, loss = 28.29, test acc = 68.95%
# task = 98, loss = 28.39, test acc = 70.63%
# task = 99, loss = 28.20, test acc = 69.81%
# task = 100, loss = 28.13, test acc = 71.43%
# task = 101, loss = 28.42, test acc = 69.83%
# task = 102, loss = 28.01, test acc = 72.53%
# task = 103, loss = 28.29, test acc = 70.64%
# task = 104, loss = 28.24, test acc = 71.24%
# task = 105, loss = 28.62, test acc = 68.92%
# task = 106, loss = 28.61, test acc = 72.83%
# task = 107, loss = 28.69, test acc = 72.84%
# task = 108, loss = 28.34, test acc = 72.49%
# task = 109, loss = 28.18, test acc = 73.52%
# task = 110, loss = 28.73, test acc = 66.61%
# task = 111, loss = 28.56, test acc = 68.70%
# task = 112, loss = 28.38, test acc = 71.43%
# task = 113, loss = 27.94, test acc = 68.60%
# task = 114, loss = 28.60, test acc = 72.59%
# task = 115, loss = 28.85, test acc = 69.46%
# task = 116, loss = 28.15, test acc = 68.13%
# task = 117, loss = 28.36, test acc = 72.08%
# task = 118, loss = 28.24, test acc = 71.69%
# task = 119, loss = 28.07, test acc = 71.94%
# task = 120, loss = 28.62, test acc = 66.48%
# task = 121, loss = 28.63, test acc = 69.92%
# task = 122, loss = 28.32, test acc = 70.02%
# task = 123, loss = 28.57, test acc = 65.75%
# task = 124, loss = 28.04, test acc = 72.44%
# task = 125, loss = 28.45, test acc = 69.85%
# task = 126, loss = 28.32, test acc = 71.01%
# task = 127, loss = 28.07, test acc = 69.98%
# task = 128, loss = 28.50, test acc = 61.36%
# task = 129, loss = 28.17, test acc = 70.78%
# task = 130, loss = 28.00, test acc = 68.22%
# task = 131, loss = 28.33, test acc = 69.80%
# task = 132, loss = 27.86, test acc = 69.96%
# task = 133, loss = 28.37, test acc = 70.51%
# task = 134, loss = 28.16, test acc = 70.49%
# task = 135, loss = 28.28, test acc = 70.76%
# task = 136, loss = 27.94, test acc = 71.27%
# task = 137, loss = 28.68, test acc = 66.22%
# task = 138, loss = 28.38, test acc = 71.03%
# task = 139, loss = 28.14, test acc = 74.57%
# task = 140, loss = 27.80, test acc = 67.08%
# task = 141, loss = 28.08, test acc = 70.79%
# task = 142, loss = 28.30, test acc = 67.92%
# task = 143, loss = 28.23, test acc = 71.07%
# task = 144, loss = 28.34, test acc = 72.39%
# task = 145, loss = 28.10, test acc = 70.19%
# task = 146, loss = 28.14, test acc = 70.02%
# task = 147, loss = 28.46, test acc = 66.47%
# task = 148, loss = 28.08, test acc = 74.66%
# task = 149, loss = 28.09, test acc = 70.07%
# task = 150, loss = 28.45, test acc = 75.05%
# task = 151, loss = 28.03, test acc = 72.30%
# task = 152, loss = 27.95, test acc = 73.01%
# task = 153, loss = 28.13, test acc = 68.17%
# task = 154, loss = 28.08, test acc = 67.82%
# task = 155, loss = 28.34, test acc = 71.32%
# task = 156, loss = 28.03, test acc = 68.17%
# task = 157, loss = 28.47, test acc = 72.21%
# task = 158, loss = 27.75, test acc = 64.76%
# task = 159, loss = 28.15, test acc = 70.02%
# task = 160, loss = 28.10, test acc = 71.98%
# task = 161, loss = 28.18, test acc = 72.90%
# task = 162, loss = 27.84, test acc = 71.17%
# task = 163, loss = 28.00, test acc = 69.66%
# task = 164, loss = 27.94, test acc = 72.64%
# task = 165, loss = 27.96, test acc = 70.83%
# task = 166, loss = 27.89, test acc = 71.61%
# task = 167, loss = 28.24, test acc = 69.03%
# task = 168, loss = 28.24, test acc = 71.04%
# task = 169, loss = 28.26, test acc = 71.72%
# task = 170, loss = 28.33, test acc = 72.78%
# task = 171, loss = 27.67, test acc = 71.80%
# task = 172, loss = 27.73, test acc = 70.40%
# task = 173, loss = 28.16, test acc = 70.28%
# task = 174, loss = 28.13, test acc = 72.43%
# task = 175, loss = 28.24, test acc = 68.74%
# task = 176, loss = 28.18, test acc = 64.64%
# task = 177, loss = 28.25, test acc = 63.82%
# task = 178, loss = 27.73, test acc = 69.10%
# task = 179, loss = 28.07, test acc = 72.37%
# task = 180, loss = 28.29, test acc = 66.07%
# task = 181, loss = 28.23, test acc = 69.06%
# task = 182, loss = 28.00, test acc = 70.02%
# task = 183, loss = 28.22, test acc = 74.29%
# task = 184, loss = 28.15, test acc = 69.84%
# task = 185, loss = 28.09, test acc = 66.67%
# task = 186, loss = 27.78, test acc = 68.31%
# task = 187, loss = 27.45, test acc = 69.26%
# task = 188, loss = 28.40, test acc = 67.64%
# task = 189, loss = 28.46, test acc = 71.40%
# task = 190, loss = 27.99, test acc = 69.37%
# task = 191, loss = 28.04, test acc = 71.51%
# task = 192, loss = 27.86, test acc = 71.43%
# task = 193, loss = 27.69, test acc = 72.99%
# task = 194, loss = 28.05, test acc = 71.19%
# task = 195, loss = 27.73, test acc = 68.82%
# task = 196, loss = 28.15, test acc = 67.23%
# task = 197, loss = 27.86, test acc = 73.52%
# task = 198, loss = 27.97, test acc = 72.01%
# task = 199, loss = 27.80, test acc = 72.86%
# Model saved as: streaming_model_5.pt
# The best accuracy is 77.15% at episode number 49.
# Total execution time: 843.1945598125458 seconds.
