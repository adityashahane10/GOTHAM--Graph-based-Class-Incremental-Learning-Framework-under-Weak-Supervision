# %%
# !pip install dgl
# !pip install torch_geometric
# Out:
# Requirement already satisfied: dgl in /opt/conda/lib/python3.10/site-packages (2.1.0)
# Requirement already satisfied: numpy>=1.14.0 in /opt/conda/lib/python3.10/site-packages (from dgl) (1.24.4)
# Requirement already satisfied: scipy>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from dgl) (1.11.4)
# Requirement already satisfied: networkx>=2.1 in /opt/conda/lib/python3.10/site-packages (from dgl) (3.2.1)
# Requirement already satisfied: requests>=2.19.0 in /opt/conda/lib/python3.10/site-packages (from dgl) (2.31.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from dgl) (4.66.1)
# Requirement already satisfied: psutil>=5.8.0 in /opt/conda/lib/python3.10/site-packages (from dgl) (5.9.3)
# Requirement already satisfied: torchdata>=0.5.0 in /opt/conda/lib/python3.10/site-packages (from dgl) (0.7.1+cpu)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->dgl) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->dgl) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->dgl) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->dgl) (2023.11.17)
# Requirement already satisfied: torch>=2 in /opt/conda/lib/python3.10/site-packages (from torchdata>=0.5.0->dgl) (2.1.2+cpu)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=2->torchdata>=0.5.0->dgl) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=2->torchdata>=0.5.0->dgl) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=2->torchdata>=0.5.0->dgl) (1.12)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=2->torchdata>=0.5.0->dgl) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=2->torchdata>=0.5.0->dgl) (2023.12.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=2->torchdata>=0.5.0->dgl) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=2->torchdata>=0.5.0->dgl) (1.3.0)
# Requirement already satisfied: torch_geometric in /opt/conda/lib/python3.10/site-packages (2.5.1)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (4.66.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (1.24.4)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (1.11.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (2023.12.2)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (3.1.2)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (3.9.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (2.31.0)
# Requirement already satisfied: pyparsing in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (3.1.1)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (1.2.2)
# Requirement already satisfied: psutil>=5.8.0 in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (5.9.3)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (1.9.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch_geometric) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->torch_geometric) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->torch_geometric) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->torch_geometric) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->torch_geometric) (2023.11.17)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->torch_geometric) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->torch_geometric) (3.2.0)

# %%
# !pip install ogb
# Out:
# Requirement already satisfied: ogb in /opt/conda/lib/python3.10/site-packages (1.3.6)
# Requirement already satisfied: torch>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from ogb) (2.1.2+cpu)
# Requirement already satisfied: numpy>=1.16.0 in /opt/conda/lib/python3.10/site-packages (from ogb) (1.24.4)
# Requirement already satisfied: tqdm>=4.29.0 in /opt/conda/lib/python3.10/site-packages (from ogb) (4.66.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /opt/conda/lib/python3.10/site-packages (from ogb) (1.2.2)
# Requirement already satisfied: pandas>=0.24.0 in /opt/conda/lib/python3.10/site-packages (from ogb) (2.2.0)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.10/site-packages (from ogb) (1.16.0)
# Requirement already satisfied: urllib3>=1.24.0 in /opt/conda/lib/python3.10/site-packages (from ogb) (1.26.18)
# Requirement already satisfied: outdated>=0.2.0 in /opt/conda/lib/python3.10/site-packages (from ogb) (0.2.2)
# Requirement already satisfied: setuptools>=44 in /opt/conda/lib/python3.10/site-packages (from outdated>=0.2.0->ogb) (69.0.3)
# Requirement already satisfied: littleutils in /opt/conda/lib/python3.10/site-packages (from outdated>=0.2.0->ogb) (0.2.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from outdated>=0.2.0->ogb) (2.31.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.24.0->ogb) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.24.0->ogb) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.24.0->ogb) (2023.4)
# Requirement already satisfied: scipy>=1.3.2 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.20.0->ogb) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.20.0->ogb) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.20.0->ogb) (3.2.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (2023.12.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.6.0->ogb) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->outdated>=0.2.0->ogb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->outdated>=0.2.0->ogb) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->outdated>=0.2.0->ogb) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.6.0->ogb) (1.3.0)

# %%
# import dgl
# import torch
# from ogb.nodeproppred import DglNodePropPredDataset


# # Load the dataset
# dataset_products = DglNodePropPredDataset(name='ogbn-products')

# # Get the graph and labels
# graph_products, labels_products = dataset_products[0]

# %%
# # Print out some basic information about the dataset
# print('Number of nodes:', graph_products.number_of_nodes())
# print('Number of edges:', graph_products.number_of_edges())
# print('Number of classes:', dataset_products.num_classes)

# %%
# graph_products.ndata['feat'].shape
# labels_products.shape

# %%
# import numpy as np

# # Assuming labels_arxiv is a NumPy array
# unique_elements, counts = np.unique(labels_products, return_counts=True)
# print(dict(zip(unique_elements, counts)))

# %%
# import pandas as pd

# # Read the label counts
# label_counts = pd.read_csv('/kaggle/input/ogbn-products/raw/node-label.csv').value_counts()
# label_counts = label_counts.rename('counts')
# label_counts = pd.DataFrame(label_counts)

# # Read the label category mapping
# label_cat = pd.read_csv('/kaggle/input/ogbn-products/mapping/labelidx2productcategory.csv')

# # Merge based on index of label_counts and 'label_index' column of label_cat
# merged_df = pd.merge(label_counts, label_cat, left_index=True, right_on='label idx')

# # Sort the merged DataFrame by 'label idx' in ascending order
# merged_df_sorted = merged_df.sort_values(by='label idx')

# # Print the sorted DataFrame
# print(merged_df_sorted)

# %% [markdown]
# ### Experimenting with obgn-arxiv

# %%
import dgl
import torch
from ogb.nodeproppred import DglNodePropPredDataset


# Load the dataset
dataset_arxiv = DglNodePropPredDataset(name='ogbn-arxiv')

# Get the graph and labels
graph_arxiv, labels_arxiv = dataset_arxiv[0]

# Print out some basic information about the dataset
print('Number of nodes:', graph_arxiv.number_of_nodes())
print('Number of edges:', graph_arxiv.number_of_edges())
print('Number of classes:', dataset_arxiv.num_classes)
# Out:
# Number of nodes: 169343
# Number of edges: 1166243
# Number of classes: 40

# %%
graph_arxiv.ndata['feat'].shape
labels_arxiv.shape
# Out:
# torch.Size([169343, 1])

# %%
import numpy as np

# Assuming labels_arxiv is a NumPy array
unique_elements, counts = np.unique(labels_arxiv, return_counts=True)
print(dict(zip(unique_elements, counts)))
# Out:
# {0: 565, 1: 687, 2: 4839, 3: 2080, 4: 5862, 5: 4958, 6: 1618, 7: 589, 8: 6232, 9: 2820, 10: 7869, 11: 750, 12: 29, 13: 2358, 14: 597, 15: 403, 16: 27321, 17: 515, 18: 749, 19: 2877, 20: 2076, 21: 393, 22: 1903, 23: 2834, 24: 22187, 25: 1257, 26: 4605, 27: 4801, 28: 21406, 29: 416, 30: 11814, 31: 2828, 32: 411, 33: 1271, 34: 7867, 35: 127, 36: 3524, 37: 2369, 38: 1507, 39: 2029}

# %%
import pandas as pd

# Read the label counts
label_counts = pd.read_csv('/kaggle/input/ogbn-arxiv/raw/node-label.csv').value_counts()
label_counts = label_counts.rename('counts')
label_counts = pd.DataFrame(label_counts)

# Read the label category mapping
label_cat = pd.read_csv('/kaggle/input/ogbn-arxiv/mapping/labelidx2arxivcategeory.csv')

# Merge based on index of label_counts and 'label_index' column of label_cat
merged_df = pd.merge(label_counts, label_cat, left_index=True, right_on='label idx')

# Sort the merged DataFrame by 'label idx' in ascending order
merged_df_sorted = merged_df.sort_values(by='label idx')

# Print the sorted DataFrame
print(merged_df_sorted)
# Out:
#     counts  label idx arxiv category
# 0      565          0    arxiv cs na
# 1      687          1    arxiv cs mm
# 2     4839          2    arxiv cs lo
# 3     2080          3    arxiv cs cy
# 4     5861          4    arxiv cs cr
# 5     4958          5    arxiv cs dc
# 6     1618          6    arxiv cs hc
# 7      589          7    arxiv cs ce
# 8     6232          8    arxiv cs ni
# 9     2820          9    arxiv cs cc
# 10    7869         10    arxiv cs ai
# 11     750         11    arxiv cs ma
# 12      29         12    arxiv cs gl
# 13    2358         13    arxiv cs ne
# 14     597         14    arxiv cs sc
# 15     403         15    arxiv cs ar
# 16   27321         16    arxiv cs cv
# 17     515         17    arxiv cs gr
# 18     749         18    arxiv cs et
# 19    2877         19    arxiv cs sy
# 20    2076         20    arxiv cs cg
# 21     393         21    arxiv cs oh
# 22    1903         22    arxiv cs pl
# 23    2834         23    arxiv cs se
# 24   22187         24    arxiv cs lg
# 25    1257         25    arxiv cs sd
# 26    4605         26    arxiv cs si
# 27    4801         27    arxiv cs ro
# 28   21406         28    arxiv cs it
# 29     416         29    arxiv cs pf
# 30   11814         30    arxiv cs cl
# 31    2828         31    arxiv cs ir
# 32     411         32    arxiv cs ms
# 33    1271         33    arxiv cs fl
# 34    7867         34    arxiv cs ds
# 35     127         35    arxiv cs os
# 36    3524         36    arxiv cs gt
# 37    2369         37    arxiv cs db
# 38    1507         38    arxiv cs dl
# 39    2029         39    arxiv cs dm

# %% [markdown]
# so now, graph_arxiv has both features and labels

# %%
graph_arxiv.ndata['label'] = labels_arxiv
print(type(graph_arxiv.ndata['label']))
# Out:
# <class 'torch.Tensor'>

# %%
label_cat['arxiv category'].to_dict()
# Out:
# {0: 'arxiv cs na',
#  1: 'arxiv cs mm',
#  2: 'arxiv cs lo',
#  3: 'arxiv cs cy',
#  4: 'arxiv cs cr',
#  5: 'arxiv cs dc',
#  6: 'arxiv cs hc',
#  7: 'arxiv cs ce',
#  8: 'arxiv cs ni',
#  9: 'arxiv cs cc',
#  10: 'arxiv cs ai',
#  11: 'arxiv cs ma',
#  12: 'arxiv cs gl',
#  13: 'arxiv cs ne',
#  14: 'arxiv cs sc',
#  15: 'arxiv cs ar',
#  16: 'arxiv cs cv',
#  17: 'arxiv cs gr',
#  18: 'arxiv cs et',
#  19: 'arxiv cs sy',
#  20: 'arxiv cs cg',
#  21: 'arxiv cs oh',
#  22: 'arxiv cs pl',
#  23: 'arxiv cs se',
#  24: 'arxiv cs lg',
#  25: 'arxiv cs sd',
#  26: 'arxiv cs si',
#  27: 'arxiv cs ro',
#  28: 'arxiv cs it',
#  29: 'arxiv cs pf',
#  30: 'arxiv cs cl',
#  31: 'arxiv cs ir',
#  32: 'arxiv cs ms',
#  33: 'arxiv cs fl',
#  34: 'arxiv cs ds',
#  35: 'arxiv cs os',
#  36: 'arxiv cs gt',
#  37: 'arxiv cs db',
#  38: 'arxiv cs dl',
#  39: 'arxiv cs dm'}

# %%
import torch

# Assuming graph_arxiv.ndata['label'] is your tensor
graph_arxiv.ndata['label'] = graph_arxiv.ndata['label'].squeeze()

# Now label_tensor is a 1-dimensional tensor
print(graph_arxiv.ndata['label'])
# Out:
# tensor([ 4,  5, 28,  ..., 10,  4,  1])

# %% [markdown]
# ### Obgn-arxiv experiments: GFSCIL with semantic embeddings

# %%
# !pip install dgl
# !pip install geoopt
# !pip install geomstats
# !pip install dgl
# !pip install torch
# Out:
# Requirement already satisfied: dgl in /opt/conda/lib/python3.10/site-packages (2.1.0)
# Requirement already satisfied: numpy>=1.14.0 in /opt/conda/lib/python3.10/site-packages (from dgl) (1.24.4)
# Requirement already satisfied: scipy>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from dgl) (1.11.4)
# Requirement already satisfied: networkx>=2.1 in /opt/conda/lib/python3.10/site-packages (from dgl) (3.2.1)
# Requirement already satisfied: requests>=2.19.0 in /opt/conda/lib/python3.10/site-packages (from dgl) (2.31.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from dgl) (4.66.1)
# Requirement already satisfied: psutil>=5.8.0 in /opt/conda/lib/python3.10/site-packages (from dgl) (5.9.3)
# Requirement already satisfied: torchdata>=0.5.0 in /opt/conda/lib/python3.10/site-packages (from dgl) (0.7.1+cpu)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->dgl) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->dgl) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->dgl) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->dgl) (2023.11.17)
# Requirement already satisfied: torch>=2 in /opt/conda/lib/python3.10/site-packages (from torchdata>=0.5.0->dgl) (2.1.2+cpu)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=2->torchdata>=0.5.0->dgl) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=2->torchdata>=0.5.0->dgl) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=2->torchdata>=0.5.0->dgl) (1.12)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=2->torchdata>=0.5.0->dgl) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=2->torchdata>=0.5.0->dgl) (2023.12.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=2->torchdata>=0.5.0->dgl) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=2->torchdata>=0.5.0->dgl) (1.3.0)
# Requirement already satisfied: geoopt in /opt/conda/lib/python3.10/site-packages (0.5.0)
# Requirement already satisfied: torch>=1.9.0 in /opt/conda/lib/python3.10/site-packages (from geoopt) (2.1.2+cpu)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from geoopt) (1.24.4)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from geoopt) (1.11.4)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.9.0->geoopt) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=1.9.0->geoopt) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.9.0->geoopt) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.9.0->geoopt) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.9.0->geoopt) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.9.0->geoopt) (2023.12.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.9.0->geoopt) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.9.0->geoopt) (1.3.0)
# Requirement already satisfied: geomstats in /opt/conda/lib/python3.10/site-packages (2.7.0)
# Requirement already satisfied: joblib>=0.17.0 in /opt/conda/lib/python3.10/site-packages (from geomstats) (1.3.2)
# Requirement already satisfied: matplotlib>=3.3.4 in /opt/conda/lib/python3.10/site-packages (from geomstats) (3.7.4)
# Requirement already satisfied: numpy>=1.18.1 in /opt/conda/lib/python3.10/site-packages (from geomstats) (1.24.4)
# Requirement already satisfied: pandas>=1.1.5 in /opt/conda/lib/python3.10/site-packages (from geomstats) (2.2.0)
# Requirement already satisfied: scikit-learn>=0.22.1 in /opt/conda/lib/python3.10/site-packages (from geomstats) (1.2.2)
# Requirement already satisfied: scipy>=1.9 in /opt/conda/lib/python3.10/site-packages (from geomstats) (1.11.4)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.4->geomstats) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.4->geomstats) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.4->geomstats) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.4->geomstats) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.4->geomstats) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.4->geomstats) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.4->geomstats) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.4->geomstats) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.5->geomstats) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.5->geomstats) (2023.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.22.1->geomstats) (3.2.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.4->geomstats) (1.16.0)
# Requirement already satisfied: dgl in /opt/conda/lib/python3.10/site-packages (2.1.0)
# Requirement already satisfied: numpy>=1.14.0 in /opt/conda/lib/python3.10/site-packages (from dgl) (1.24.4)
# Requirement already satisfied: scipy>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from dgl) (1.11.4)
# Requirement already satisfied: networkx>=2.1 in /opt/conda/lib/python3.10/site-packages (from dgl) (3.2.1)
# Requirement already satisfied: requests>=2.19.0 in /opt/conda/lib/python3.10/site-packages (from dgl) (2.31.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from dgl) (4.66.1)
# Requirement already satisfied: psutil>=5.8.0 in /opt/conda/lib/python3.10/site-packages (from dgl) (5.9.3)
# Requirement already satisfied: torchdata>=0.5.0 in /opt/conda/lib/python3.10/site-packages (from dgl) (0.7.1+cpu)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->dgl) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->dgl) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->dgl) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->dgl) (2023.11.17)
# Requirement already satisfied: torch>=2 in /opt/conda/lib/python3.10/site-packages (from torchdata>=0.5.0->dgl) (2.1.2+cpu)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=2->torchdata>=0.5.0->dgl) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=2->torchdata>=0.5.0->dgl) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=2->torchdata>=0.5.0->dgl) (1.12)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=2->torchdata>=0.5.0->dgl) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=2->torchdata>=0.5.0->dgl) (2023.12.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=2->torchdata>=0.5.0->dgl) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=2->torchdata>=0.5.0->dgl) (1.3.0)
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (2.1.2+cpu)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch) (2023.12.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch) (1.3.0)

# %%
import logging
import matplotlib.pyplot as plt

import geomstats.backend as gs
import geomstats.visualization as visualization

from geomstats.datasets.utils import load_karate_graph
from geomstats.geometry.poincare_ball import PoincareBall

# %%
import random
import numpy as np
import torch
import dgl.data

# %%
import torch
import numpy as np
from gensim.models import Word2Vec
from nltk.tokenize import word_tokenize
import torch.nn.functional as F
def generate_semantic_embeddings(class_names_dict, embedding_dim= 512):
    # Tokenize class names
    tokenized_class_names = [word_tokenize(class_name.lower()) for class_name in class_names_dict.values()]
    
    # Train Word2Vec model
    model = Word2Vec(sentences=tokenized_class_names, vector_size = embedding_dim, window=5, min_count=1, workers=40)
    
    # Access the learned embeddings
    label_embeddings = {label: torch.tensor(model.wv[label]) for label, class_name in class_names_dict.items()}
    
    return label_embeddings


# Example usage:
class_names_dict = {0: 'arxiv cs na',
 1: 'arxiv cs mm',
 2: 'arxiv cs lo',
 3: 'arxiv cs cy',
 4: 'arxiv cs cr',
 5: 'arxiv cs dc',
 6: 'arxiv cs hc',
 7: 'arxiv cs ce',
 8: 'arxiv cs ni',
 9: 'arxiv cs cc',
 10: 'arxiv cs ai',
 11: 'arxiv cs ma',
 12: 'arxiv cs gl',
 13: 'arxiv cs ne',
 14: 'arxiv cs sc',
 15: 'arxiv cs ar',
 16: 'arxiv cs cv',
 17: 'arxiv cs gr',
 18: 'arxiv cs et',
 19: 'arxiv cs sy',
 20: 'arxiv cs cg',
 21: 'arxiv cs oh',
 22: 'arxiv cs pl',
 23: 'arxiv cs se',
 24: 'arxiv cs lg',
 25: 'arxiv cs sd',
 26: 'arxiv cs si',
 27: 'arxiv cs ro',
 28: 'arxiv cs it',
 29: 'arxiv cs pf',
 30: 'arxiv cs cl',
 31: 'arxiv cs ir',
 32: 'arxiv cs ms',
 33: 'arxiv cs fl',
 34: 'arxiv cs ds',
 35: 'arxiv cs os',
 36: 'arxiv cs gt',
 37: 'arxiv cs db',
 38: 'arxiv cs dl',
 39: 'arxiv cs dm'}
semantic_embeddings = generate_semantic_embeddings(class_names_dict)

# %%
# semantic_embeddings

# %%
Original_graph = graph_arxiv   #DGL object
base_classes_graph = 10
num_support_base = 10
num_query_base = 10
start_seed_base = 100
num_episodes_base = 300
graph_feats_size = Original_graph.ndata['feat'].shape[1]
n_seed = 42



fixed_list = [52, 46, 11, 24, 52, 70, 66, 41, 162, 1110]
starting_seeds = [425, 310, 20,180, 535, 110, 195, 233, 541, 945]
"""
meta_lr = 0.00001
"""
# Out:
# '\nmeta_lr = 0.00001\n'

# %%
Original_graph.ndata['feat'].shape[1]
# Out:
# 128

# %%
import dgl
import numpy as np

def process_graph(graph, num_classes_to_keep, random_seed=None, remaining_classes=None):
    # Fix the random seed
    if random_seed is not None:
        np.random.seed(random_seed)

    # Step 1: Identify the number of classes in the graph
    num_classes = len(np.unique(graph.ndata['label'].numpy()))

    # Step 2: Validate the given number of classes to keep
    if not 0 < num_classes_to_keep <= num_classes:
        raise ValueError("Invalid number of classes to keep.")

    # Step 3: Initialize remaining classes if not provided
    if remaining_classes is None:
        remaining_classes = set(range(num_classes))

    # Step 4: Sample classes without replacement until all classes are exhausted
    if len(remaining_classes) < num_classes_to_keep:
        raise ValueError("Not enough remaining classes to sample.")

    p_classes = np.random.choice(list(remaining_classes), size=num_classes_to_keep, replace=False)
    remaining_classes -= set(p_classes)

    # Step 5: Sample nodes corresponding to the specified classes without replacement
    p_nodes = [i for i in range(graph.number_of_nodes()) if graph.ndata['label'][i].item() in p_classes]
    sampled_graph = dgl.node_subgraph(graph, p_nodes)

    # Step 6: Extract node labels and features corresponding to sampled nodes
    sampled_labels = sampled_graph.ndata['label']
    sampled_features = graph.ndata['feat'][p_nodes]  # Replace 'feat' with the actual feature name

    # Step 7: Set the features for the sampled graph
    sampled_graph.ndata['feat'] = sampled_features

    # Step 8: Create a new DGL graph object with sampled features and labels
    new_graph = dgl.graph((sampled_graph.edges()[0], sampled_graph.edges()[1]), num_nodes=sampled_graph.number_of_nodes())
    new_graph.ndata['label'] = sampled_labels
    new_graph.ndata['feat'] = sampled_features  # Replace 'feat' with the actual feature name

    return new_graph, remaining_classes

# %%
def get_unique_classes(graph):
    """
    Extracts unique class labels from the 'label' attribute of a graph's node data.

    Parameters:
    - graph: The input graph.

    Returns:
    - list_of_classes: A list of unique class labels.
    """
    try:
        # Assuming 'label' is a tensor or NumPy array
        class_labels = graph.ndata['label'].numpy()

    except KeyError:
        # Adjust the key if the attribute name is different
        print("Error: 'label' attribute not found in node data.")
        return []

    # Extract unique class labels
    unique_classes = set(class_labels)

    # Convert the set to a list (order not guaranteed)
    list_of_classes = list(unique_classes)

    return list_of_classes

# %%
# Example usage:
base_remaining_classes = set(range(len(np.unique(Original_graph.ndata['label'].numpy()))))  # Start with all classes
# print(base_remaining_classes)

# Sample a subgraph with 20 classes from the base graph
sampled_graph_base, _ = process_graph(
    Original_graph,
    num_classes_to_keep= base_classes_graph,
    random_seed = n_seed,
    remaining_classes=base_remaining_classes
)
print(f'Base graph classes: {get_unique_classes(sampled_graph_base)}')
# Out:
# Base graph classes: [4, 37, 6, 39, 12, 15, 16, 19, 26, 27]

# %%
import random
import numpy as np
import torch
import dgl.data

class MetaDataGenerator:
    def __init__(self, dataset, num_tasks, num_classes, num_support, num_query, task_random_seeds, random_seeds, num_walks, walk_length):
        self.dataset = dataset
        self.num_tasks = num_tasks
        self.num_classes = num_classes
        self.num_support = num_support
        self.num_query = num_query
        self.task_random_seeds = task_random_seeds
        self.random_seeds = random_seeds
        self.num_walks = num_walks
        self.walk_length = walk_length
        self.task_data = []

    def set_random_seed(self, seed):
        random.seed(seed)
        np.random.seed(seed)
        torch.manual_seed(seed)

    def create_task(self, seed, task_random_seeds):
        tasks = []
        edge_indices_train_list = []
        edge_indices_test_list = []
        support_random_walks_list = []
        query_random_walks_list = []

        for task_seed in task_random_seeds:
            self.set_random_seed(task_seed)
            task = {}
            support_set = []
            query_set = []

            unique_classes = np.unique(self.dataset.ndata['label'].numpy())
            class_group = np.random.choice(unique_classes, self.num_classes, replace=False)

            for c in class_group:
                indices = np.where(self.dataset.ndata['label'].numpy() == c)[0]
                support_indices = np.random.choice(indices, size=self.num_support, replace=False)
                query_indices = np.random.choice(indices, size=self.num_query, replace=False)

                support_set.extend(support_indices)
                query_set.extend(query_indices)

            support_random_walks = self.generate_random_walks(support_set)
            support_random_walks_list.append(support_random_walks)

            query_random_walks = self.generate_random_walks(query_set)
            query_random_walks_list.append(query_random_walks)

            # Include query nodes and nodes from query random walks in the 'test' set
            test_set = list(set(query_set + [node for walk in query_random_walks for node in walk]))
            task['test'] = test_set

            train_set = list(set(support_set + [node for walk in support_random_walks for node in walk]))
            task['train'] = train_set
            task['query_set'] = query_set
            task['support_set'] = support_set
            task['seed'] = task_seed

            tasks.append(task)

            # Generate edge indices for the combined set of query nodes and nodes from query random walks
            edge_indices_test = self.get_edges_from_nodes(test_set)
            edge_indices_train = self.get_edges_from_nodes(train_set)

            edge_indices_test_list.append(edge_indices_test)
            edge_indices_train_list.append(edge_indices_train)

        return tasks, edge_indices_train_list, edge_indices_test_list, support_random_walks_list, query_random_walks_list

    def generate_random_walks(self, nodes):
        random_walks = []

        for node in nodes:
            for _ in range(self.num_walks):
                current_node = node
                walk = [current_node]
                for _ in range(self.walk_length - 1):
                    neighbors = list(self.dataset.successors(current_node).numpy())
                    if len(neighbors) > 0:
                        current_node = random.choice(neighbors)
                        walk.append(current_node)
                    else:
                        break
                random_walks.append(walk)

        return random_walks

    def get_edges_from_nodes(self, nodes):
        src, dst = [], []
        for node in nodes:
            successors = list(self.dataset.successors(node).numpy())
            for successor in successors:
                src.append(node)
                dst.append(successor)

        edge_index = torch.stack([torch.tensor(src), torch.tensor(dst)], dim=0).long()
        return edge_index

    def generate_tasks(self):
        tasks = []
        edge_indices_train_list = []
        edge_indices_test_list = []
        support_random_walks_list = []
        query_random_walks_list = []


        for seed in self.random_seeds:
            tasks_data, edges_train, edges_test, support_walks, query_walks = self.create_task(seed, self.task_random_seeds)
            tasks.extend(tasks_data)
            edge_indices_train_list.extend(edges_train)
            edge_indices_test_list.extend(edges_test)
            support_random_walks_list.extend(support_walks)
            query_random_walks_list.extend(query_walks)



        return tasks, edge_indices_train_list, edge_indices_test_list, support_random_walks_list, query_random_walks_list

# %%
import torch
import dgl

def create_feature_label_extractor(graph, tasks):
    def feature_label_extractor(task_id, seed):
        task = tasks[task_id]

        train_set = task['train']
        test_set = task['test']
        support_set = task['support_set']  # Include support set
        query_set = task['query_set']  # Include query set

        # Extract features and labels for the entire graph
        all_features = graph.ndata['feat']
        all_labels = graph.ndata['label']

        # Extract features and labels for the train set
        train_features = all_features[train_set]
        train_labels = all_labels[train_set]

        # Extract features and labels for the test set
        test_features = all_features[test_set]
        test_labels = all_labels[test_set]

        # Extract features and labels for the support set
        support_features = all_features[support_set]
        support_labels = all_labels[support_set]

        # Extract features and labels for the query set
        query_features = all_features[query_set]
        query_labels = all_labels[query_set]

        # Calculate the degrees of nodes
        train_degrees = graph.in_degrees(train_set)
        test_degrees = graph.in_degrees(test_set)
        support_degrees = graph.in_degrees(support_set)
        query_degrees = graph.in_degrees(query_set)

        return (
            torch.tensor(train_features), torch.tensor(train_labels),
            torch.tensor(test_features), torch.tensor(test_labels),
            torch.tensor(support_features), torch.tensor(support_labels),
            torch.tensor(query_features), torch.tensor(query_labels),
            torch.tensor(train_degrees), torch.tensor(test_degrees),
            torch.tensor(support_degrees), torch.tensor(query_degrees)
        )

    return feature_label_extractor

# %%
import torch

def reindex_nodes(task_id, train_set_list, edge_indices_list, random_walks_list):
    # Extracting task-specific data
    train_set = train_set_list[task_id]
    src_train, dst_train = edge_indices_list[task_id]  # Assuming edge_indices_list is a list of tensors
    random_walks_train = random_walks_list[task_id]

    # Reindexing nodes in train_set
    node_mapping = {old_node: new_node for new_node, old_node in enumerate(train_set)}
    reindexed_train_set = [node_mapping[node] for node in train_set]

    # Reindexing nodes in edge_indices
    reindexed_edge_indices = torch.stack([
        torch.tensor([node_mapping.get(int(source), -1) for source in src_train], dtype=torch.long),
        torch.tensor([node_mapping.get(int(destination), -1) for destination in dst_train], dtype=torch.long)
    ], dim=0)

    # Filter out rows with missing nodes
    mask = (reindexed_edge_indices != -1).all(dim=0)
    reindexed_edge_indices = reindexed_edge_indices[:, mask]

    # Reindexing nodes in random_walks
    reindexed_random_walks = [
        [node_mapping.get(int(node), -1) for node in walk]
        for walk in random_walks_train
    ]

    # Filter out walks with missing nodes
    reindexed_random_walks = [walk for walk in reindexed_random_walks if -1 not in walk]

    # Create a dictionary for old to new node indices
    old_to_new_mapping = {old_node: new_node for old_node, new_node in node_mapping.items()}

    return reindexed_train_set, reindexed_edge_indices, reindexed_random_walks, old_to_new_mapping

# %%
def dict_for_custom_loss_function(reindexed_random_walks, old_to_new_mapping_train, graph):
    original_first_node_list = []
    remaining_nodes = []
    all_firsts = []

    for walks in reindexed_random_walks:
        reindexed_first_node = walks[0]
        all_firsts.append(reindexed_first_node)
        reindexed_remaining_nodes = walks[1:]
        #print(reindexed_remaining_nodes)

        # Find the corresponding original node index using the original-to-reindexed mapping
        original_first_node = next((old_node for old_node, new_node in old_to_new_mapping_train.items() if reindexed_first_node == new_node), None)
        original_first_node_list.append(original_first_node)
        remaining_nodes.append(reindexed_remaining_nodes)


    # Assuming original_labels is a dictionary with node indices as keys and labels as values
    labels_for_nodes = [graph.ndata['label'][node] for node in original_first_node_list if node is not None]

    return labels_for_nodes, remaining_nodes, original_first_node_list, all_firsts

# %%
def create_label_dict(labels_for_nodes, remaining_nodes, all_firsts):
    final_list = []
    for i in range(len(labels_for_nodes)):
        final = [labels_for_nodes[i], remaining_nodes[i]]
        final_list.append(final)

    label_dict = {}
    for item in final_list:
        label = item[0].item()  # Convert tensor label to integer
        nodes_list = item[1]


        if label not in label_dict:
            label_dict[label] = nodes_list
        else:
            label_dict[label].extend(nodes_list)



    # Perform set operation to remove duplicates within each list
    for key in label_dict:
        label_dict[key] = list(set(label_dict[key]))

    return label_dict

# %%
# !pip install torch_geometric
# Out:
# Requirement already satisfied: torch_geometric in /opt/conda/lib/python3.10/site-packages (2.5.1)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (4.66.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (1.24.4)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (1.11.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (2023.12.2)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (3.1.2)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (3.9.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (2.31.0)
# Requirement already satisfied: pyparsing in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (3.1.1)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (1.2.2)
# Requirement already satisfied: psutil>=5.8.0 in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (5.9.3)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (1.9.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch_geometric) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->torch_geometric) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->torch_geometric) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->torch_geometric) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->torch_geometric) (2023.11.17)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->torch_geometric) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->torch_geometric) (3.2.0)

# %%
import torch

def calculate_euclidean_prototype(features, degree_tensor, class_dict):
    # Initialize a dictionary to store prototypes for each class
    class_prototypes = {}

    for class_label, nodes in class_dict.items():
        # Extract features for the nodes in the current class
        class_features = features[nodes]

        # Extract degrees for the nodes in the current class
        class_degrees = degree_tensor[nodes]

        # Calculate the weighted sum of features
        weighted_sum = torch.sum(class_degrees.unsqueeze(1) * class_features, dim=0)

        # Calculate the sum of degrees
        sum_degrees = torch.sum(class_degrees)

        # Calculate the prototype (weighted average)
        prototype = weighted_sum / sum_degrees

        # Store the prototype in the dictionary
        class_prototypes[class_label] = prototype

    return class_prototypes

# %%
def get_unique_elements_in_order(input_list):
    unique_elements_set = set()
    unique_elements_list = []

    for element in input_list:
        if element not in unique_elements_set:
            unique_elements_set.add(element)
            unique_elements_list.append(element)

    return unique_elements_list

# %%
def add_elements_to_dictionary_list(reformulated_dict, unique_elements_result):
    for i, class_label in enumerate(reformulated_dict.keys()):
        # Get the row corresponding to the class label
        row_elements = unique_elements_result[i]

        # Add each element to the list in the dictionary
        for element in row_elements:
            reformulated_dict[class_label].append(element)

# %%
def create_C_dictionary(Reform_dict, proto_dict):
    # Ensure both dictionaries have the same keys
    common_keys = set(Reform_dict.keys()).intersection(proto_dict.keys())

    # Create a new dictionary with values from both dictionaries for common keys
    C_dict = {key: (Reform_dict[key], proto_dict[key]) for key in common_keys}

    # Access values individually
    Reform_values = {key: Reform_dict[key] for key in common_keys}
    Proto_values = {key: proto_dict[key] for key in common_keys}

    # Use values from proto_dict as keys in Reform_dict
    Reform_dict_with_proto_keys = {tuple((proto_dict[key]).numpy()): Reform_dict[key] for key in common_keys}

    return Reform_values, Proto_values, Reform_dict_with_proto_keys

# %%
# import torch

# def calculate_concatenated_matrix(train_features, train_labels, semantic_vectors):
#     # Calculate unique class labels from train_labels
#     class_labels = torch.unique(train_labels)
    
#     # Initialize a list to store final matrices for each class
#     final_matrices = []
#     class_labels_list = []  # Initialize a list to store class labels
    
#     # Iterate through each class
#     for class_label in class_labels:
#         # Get the semantic vector for the current class
#         semantic_vector = semantic_vectors[class_label.item()]
        
#         # Filter train_features for the current class
#         class_indices = torch.nonzero(train_labels == class_label).squeeze(1)
#         class_features = train_features[class_indices]
        
#         # Filter train_labels for the current class (ensuring labels match features)
#         class_labels_tensor = train_labels[class_indices]
        
#         # Store class labels in a list
#         class_labels_list.append(class_labels_tensor)
        
#         # Initialize the final matrix for the current class
#         final_matrix = []
        
#         # Iterate through each feature vector
#         for vector in class_features:
#             # Concatenate the feature vector with the semantic vector
#             concatenated_vector = torch.cat((vector, semantic_vector))
#             final_matrix.append(concatenated_vector)
        
#         # Append the final matrix for the current class to the list of final matrices
#         final_matrices.append(final_matrix)
    
#     # Convert final_matrices to tensor
#     new_train_features = torch.cat([torch.stack(final_matrix) for final_matrix in final_matrices])
    
#     # Concatenate the filtered labels to match the new_train_features
#     new_train_labels = torch.cat(class_labels_list)
    
#     return new_train_features, new_train_labels

# %%
import torch
import numpy as np
from torch_geometric.data import Data
import warnings
warnings.filterwarnings("ignore")

def base_training_task_generator(graph, num_classes, num_support, num_query, start_seed, spacing, num_seeds, task_random_seeds, random_seeds, semantic_vectors):
    train_indexes_before_reindexing_list = []
    test_indexes_before_reindexing_list = []
    task_datasets_euc = []
    context_dictionary_list = []
    train_set_list = []
    test_set_list = []
    euc_proto = []


    num_tasks = num_seeds
    
    metadata_generator = MetaDataGenerator(sampled_graph_base, num_tasks, num_classes, num_support, num_query, task_random_seeds, random_seeds, 10, 3)
    tasks, edge_indices_train_list, edge_indices_test_list, support_random_walks_list, query_random_walks_list = metadata_generator.generate_tasks()

    for i, task in enumerate(tasks):
        #print(f"Task = {i} - Seed: {task_random_seeds[i]}")
        seed = task_random_seeds[i]
        extractor = create_feature_label_extractor(graph, tasks)
        train_features, train_labels, test_features, test_labels, support_features, support_labels, query_features, query_labels, train_degrees, test_degrees, support_degrees, query_degrees = extractor(i, seed) 
        #print(train_features.shape)
        #train_features, train_labels = calculate_concatenated_matrix(train_features, train_labels, semantic_vectors)
        #print(train_features.shape)
        train_indexes_before_reindexing_list.append(task['train'])
        train_set_list.append(task['train'])
        test_set_list.append(task['test'])
        test_indexes_before_reindexing_list.append(task['test'])
        
        reindexed_train_set, reindexed_edge_indices_train, reindexed_random_walks_train, old_to_new_mapping_train = reindex_nodes(i, train_indexes_before_reindexing_list, edge_indices_train_list, support_random_walks_list)
        reindexed_test_set, reindexed_edge_indices_test, reindexed_random_walks_test, old_to_new_mapping_test = reindex_nodes(i, test_indexes_before_reindexing_list, edge_indices_test_list, query_random_walks_list)
        
        data_train_euc = Data(x=train_features, edge_index=reindexed_edge_indices_train, y=train_labels)
        data_test_euc = Data(x=test_features, edge_index=reindexed_edge_indices_test, y=test_labels)
        task_datasets_euc.append((data_train_euc, data_test_euc))
        
        labels_for_nodes, remaining_nodes, original_first_node_list, all_firsts = dict_for_custom_loss_function(reindexed_random_walks_train, old_to_new_mapping_train, graph)
        result_label_dict = create_label_dict(labels_for_nodes, remaining_nodes, all_firsts)
        
        unique_elements_result = get_unique_elements_in_order(all_firsts)
        unique_elements_result = np.array(unique_elements_result).reshape(num_classes, num_support)
        
        # Add elements to the reformulated dictionary
        add_elements_to_dictionary_list(result_label_dict, unique_elements_result)
        context_dictionary_list.append(result_label_dict)
        eucledian_prototype = calculate_euclidean_prototype(train_features, train_degrees, result_label_dict)
        euc_proto.append(eucledian_prototype)
        Reform_values, Proto_values, Reform_dict_with_proto_keys = create_C_dictionary(result_label_dict, eucledian_prototype)
        
    return context_dictionary_list, task_datasets_euc

graph = sampled_graph_base
num_classes = base_classes_graph
num_support = num_support_base
num_query = num_query_base
start_seed = start_seed_base
spacing = 50
num_seeds = num_episodes_base
task_random_seeds = [start_seed + i * spacing for i in range(num_seeds)]
random_seeds = [42]

context_dictionary_list, task_datasets_euc = base_training_task_generator(graph, num_classes, num_support, num_query, start_seed, spacing, num_seeds, task_random_seeds, random_seeds, semantic_embeddings)

# %%
import torch

def create_new_proto(mean_vectors, semantic_vectors):
    new_proto_vectors = {}

    for label in mean_vectors.keys():
#         print(f'label shape(mean): {label.shape}')
        if label in semantic_vectors:
            #print(f'create proto: {label}')
#             print(f' shape(semantics): {semantic_vectors[label].shape}')
#             print(f' shape(mean): {mean_vectors[label].shape}')
            # Take the mean along the last dimension of the concatenated tensor
            new_vector = torch.mean(torch.stack([1 * mean_vectors[label],  1 * semantic_vectors[label]]), dim=0)
            new_proto_vectors[label] = new_vector
        else:
            # Handle the case where there is no corresponding semantic vector
            print(f"No semantic vector found for label {label}")

    return new_proto_vectors

# %%
import torch

def Lintra_loss(embeddings, context_dictionary, target_radius, semantic_vectors):
    loss_intra = 0
    num_clusters = len(context_dictionary)

    # Calculate mean vectors for each cluster
    mean_vectors = {j: torch.mean(embeddings[cluster_elements], dim=0) for j, cluster_elements in context_dictionary.items()}
    mean_vectors = create_new_proto(mean_vectors, semantic_vectors)
    # Calculate intra-cluster loss
    for j, cluster_elements in context_dictionary.items():
        mean_vector = mean_vectors[j]

        for i in cluster_elements:
            embedding_i = embeddings[i]
            norm_diff = torch.norm(embedding_i - mean_vector)
            loss_contrib = torch.clamp(norm_diff - target_radius, min=0)

            # Calculate the sum of all d_{ij} within the cluster
            sum_dij = torch.sum(torch.clamp(torch.norm(embeddings[cluster_elements] - mean_vector, dim=1) - target_radius, min=0))

            # Normalize dij by the sum of all dij within the cluster
            #normalized_dij = loss_contrib / sum_dij
            normalized_dij = loss_contrib

            # Add the normalized contribution to the overall loss
            loss_intra += normalized_dij
            
    # Normalize the overall loss by the number of clusters
    loss_intra_normalized = loss_intra / num_clusters
    return loss_intra_normalized, mean_vectors

# %%
import torch

def Linter_loss(embeddings, context_dictionary, semantic_vectors):
    mean_vectors = {j: torch.mean(embeddings[cluster_elements], dim=0) for j, cluster_elements in context_dictionary.items()}
    mean_vectors = create_new_proto(mean_vectors, semantic_vectors)
    loss_inter = 0
    num_clusters = len(context_dictionary)

    for j, cluster_j in context_dictionary.items():
        for p, cluster_p in context_dictionary.items():
            if p != j and j in mean_vectors and p in mean_vectors:  # Check if keys exist
                norm_diff = -torch.log(torch.norm(mean_vectors[j] - mean_vectors[p]) )
                loss_inter += norm_diff
    loss_inter_normalised = loss_inter / num_clusters
    return loss_inter_normalised, mean_vectors

# %%
import torch

def L_proto(mean_vectors, semantic_embeddings):
    semantic_loss = 0
    semantic_embeddings_dict = {}
    
    for label, mean_vector in mean_vectors.items():
        semantic_embedding = semantic_embeddings[label]
        loss = torch.norm(mean_vector - semantic_embedding)
        semantic_loss += loss
        semantic_embeddings_dict[label] = semantic_embedding
    
    return semantic_loss, semantic_embedding, semantic_embeddings_dict

# %%
import torch
import torch.nn.functional as F

def accuracy_cosine(output, labels, mean_vectors):
    _, predicted = torch.max(output, 1)
    correct = 0
    total = labels.size(0)

    for i in range(total):
        output_node = output[i, :]
        similarities = {label: F.cosine_similarity(output_node.unsqueeze(0), mean_vector.unsqueeze(0)) for label, mean_vector in mean_vectors.items()}

        # Find the label with the maximum cosine similarity
        closest_label_sim = max(similarities, key=similarities.get)

        # If the closest label by cosine similarity matches the true label, consider it correct
        if closest_label_sim == labels[i].item():
            correct += 1

    return correct / total

# %%
def accuracy_euclidean(output, labels, mean_vectors):
    _, predicted = torch.max(output, 1)
    correct = 0
    total = labels.size(0)

    for i in range(total):
        output_node = output[i, :]
        distances = {label: torch.dist(output_node.unsqueeze(0), mean_vector.unsqueeze(0)) for label, mean_vector in mean_vectors.items()}

        # Find the label with the minimum Euclidean distance
        closest_label_dist = min(distances, key=distances.get)

        # If the closest label by Euclidean distance matches the true label, consider it correct
        if closest_label_dist == labels[i].item():
            correct += 1

    return correct / total

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch_geometric.data import Data
from torch_geometric.nn import GATConv
import torch.nn.functional as F
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from tqdm import tqdm


class GATmodel(nn.Module):
    '''
    input x shape is [node_num, node_feature]
    output out shape is [node_num, class_num]
    '''
    def __init__(self, in_feature, hidden_feature, out_channels):
        super(GATmodel, self).__init__()
        self.in_feature = in_feature
        self.hidden_feature = hidden_feature
        self.out_channels = out_channels
        self.build()
        print("GATConv init.")

    def build(self):
        self.gat_layer_1 = GATConv(in_channels=self.in_feature, out_channels=self.hidden_feature, heads=3, concat=False)
        self.gat_layer_2 = GATConv(in_channels=self.hidden_feature, out_channels=self.out_channels, heads=3, concat=False)
    
    def forward(self, x, edge_index):
        gout_1 = self.gat_layer_1(x, edge_index)
        gout_2 = F.dropout(F.relu(gout_1), p=0.2)
        gout_2 = self.gat_layer_2(gout_2, edge_index)
        return gout_2
    
class NeuralNetwork(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(NeuralNetwork, self).__init__()
        self.fc = nn.Linear(input_size, hidden_size)

    def forward(self, x):
        out = self.fc(x)
        return out


def meta_train(meta_model, semantic_model, task_datasets, meta_lr, weight_decays, context_dictionary_list, semantic_vectors):
    optimizer_meta = optim.Adam(meta_model.parameters(), lr=meta_lr, weight_decay=weight_decays)
    optimizer_semantic = optim.Adam(semantic_model.parameters(), lr=0.0005, weight_decay=weight_decays)
    
    total_losses = []  # List to store total losses over meta-epochs
    task_train_losses = []  # List to store task train losses over meta-epochs
    task_test_losses = [[] for _ in range(len(task_datasets))]  # List to store task test losses over meta-epochs
    task_train_accuracies = [[] for _ in range(len(task_datasets))]  # List to store task train accuracies over meta-epochs
    task_test_accuracies = []  # List to store task test accuracies 
    task_cluster_means = [[] for _ in range(len(task_datasets))]  # List to store task means over episodes
    all_train_data = []
    task_dictionary = {}

    for i, task_data in enumerate(task_datasets):
        task_train_data, task_test_data = task_data
        all_train_data.append(task_train_data)
        
        # Training phase
        meta_model.train()
        semantic_model.train()  # Set the semantic model to training mode
        optimizer_meta.zero_grad()
        optimizer_semantic.zero_grad()

        train_output = meta_model(task_train_data.x, task_train_data.edge_index)  # Embeddings (train)
        loss_intra, _ = Lintra_loss(train_output, context_dictionary_list[i], 0.01, semantic_vectors)
        loss_inter, mean_vectors = Linter_loss(train_output, context_dictionary_list[i], semantic_vectors)
        
        # Semantic model forward pass
        semantic_output = {}
        for label, embed in semantic_vectors.items():
            output = semantic_model(embed).squeeze()
            semantic_output[label] = output
            #print(f'here shape: {semantic_output[label].shape}')
            
        # Calculate semantic loss
        semantic_loss, semantic_output, semantic_embeddings_dict = L_proto(mean_vectors, semantic_output)
        
        # Backpropagate through semantic model
        semantic_loss.backward(retain_graph=True)  # Specify retain_graph=True
        optimizer_semantic.step()
        
        loss = 1 * loss_intra + 0.25 * loss_inter
        loss.backward()
        optimizer_meta.step()

        # Validation phase
        meta_model.eval()  # Set the model to evaluation mode
        test_output = meta_model(task_test_data.x, task_test_data.edge_index)
        test_acc = accuracy_cosine(test_output, task_test_data.y, mean_vectors) * 100
        task_dictionary[i] = test_acc
        
        # Append metrics to lists
        task_cluster_means[i].append(mean_vectors)
        task_train_losses.append(loss.item())
        task_test_accuracies.append(test_acc)
        
        print(f'task = {i}, loss = {loss.item():.2f}, loss_semantic = {semantic_loss.item():.2f}, test acc = {test_acc:.2f}%')

    return meta_model, semantic_model, task_cluster_means, task_dictionary, task_train_losses, task_test_accuracies

# %%
# Example usage:
in_channels = graph_feats_size
hidden_channels = 512
out_channels = 512
meta_lr = 0.001
weight_decays = 5e-3  # List of weight decay values for each task

input_size = 512  # Assuming each feature tensor has a shape of (1, 512)
hidden_size = 512

# %%
import time
from scipy.spatial.distance import cdist


# Record the start time
start_time = time.time()

# Instantiate the meta-model only once outside the loop
meta_model = GATmodel(in_channels, hidden_channels, out_channels)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
meta_model = meta_model.to(device)
semantic_vectors = semantic_embeddings

semantic_model = NeuralNetwork(input_size, hidden_size)
semantic_model = semantic_model.to(device)

# Train the meta-learning model with regularization
model, semantic_model, cluster_means, task_dictionary, task_train_losses, task_test_accuracies = meta_train(meta_model, semantic_model, task_datasets_euc, meta_lr, weight_decays, context_dictionary_list, semantic_vectors)

# Find the episode number and corresponding accuracy with the highest accuracy
best_episode = max(task_dictionary, key=task_dictionary.get)
best_accuracy = task_dictionary[best_episode]

# Print the result
print(f"The best accuracy is {best_accuracy:.2f} at episode number {best_episode}.")

# Save the trained model
torch.save(model.state_dict(), 'meta_model.pth')
torch.save(semantic_model.state_dict(), 'semantic_model.pth')

# Record the end time
end_time = time.time()

# Calculate and print the execution time
execution_time = end_time - start_time
print(f'Total execution time: {execution_time} seconds')
# Out:
# GATConv init.
# task = 0, loss = 17.10, loss_semantic = 6.12, test acc = 50.41%
# task = 1, loss = 13.24, loss_semantic = 5.60, test acc = 27.82%
# task = 2, loss = 11.84, loss_semantic = 5.44, test acc = 49.49%
# task = 3, loss = 11.29, loss_semantic = 5.36, test acc = 53.58%
# task = 4, loss = 10.30, loss_semantic = 5.29, test acc = 55.29%
# task = 5, loss = 10.20, loss_semantic = 5.22, test acc = 44.47%
# task = 6, loss = 9.88, loss_semantic = 5.13, test acc = 48.25%
# task = 7, loss = 9.39, loss_semantic = 5.04, test acc = 34.10%
# task = 8, loss = 9.45, loss_semantic = 4.94, test acc = 53.74%
# task = 9, loss = 9.15, loss_semantic = 4.84, test acc = 38.27%
# task = 10, loss = 9.06, loss_semantic = 4.73, test acc = 49.64%
# task = 11, loss = 8.86, loss_semantic = 4.62, test acc = 52.40%
# task = 12, loss = 8.80, loss_semantic = 4.53, test acc = 54.26%
# task = 13, loss = 9.00, loss_semantic = 4.44, test acc = 41.45%
# task = 14, loss = 8.62, loss_semantic = 4.31, test acc = 55.64%
# task = 15, loss = 8.56, loss_semantic = 4.22, test acc = 57.55%
# task = 16, loss = 8.91, loss_semantic = 4.14, test acc = 49.33%
# task = 17, loss = 8.57, loss_semantic = 4.02, test acc = 48.30%
# task = 18, loss = 8.49, loss_semantic = 3.92, test acc = 47.35%
# task = 19, loss = 8.44, loss_semantic = 3.83, test acc = 51.33%
# task = 20, loss = 8.77, loss_semantic = 3.73, test acc = 56.58%
# task = 21, loss = 8.25, loss_semantic = 3.60, test acc = 51.55%
# task = 22, loss = 8.29, loss_semantic = 3.52, test acc = 53.32%
# task = 23, loss = 8.34, loss_semantic = 3.43, test acc = 66.59%
# task = 24, loss = 8.35, loss_semantic = 3.34, test acc = 62.64%
# task = 25, loss = 8.00, loss_semantic = 3.25, test acc = 56.72%
# task = 26, loss = 8.09, loss_semantic = 3.16, test acc = 53.24%
# task = 27, loss = 8.19, loss_semantic = 3.05, test acc = 46.70%
# task = 28, loss = 8.52, loss_semantic = 2.95, test acc = 64.62%
# task = 29, loss = 8.38, loss_semantic = 2.84, test acc = 55.17%
# task = 30, loss = 7.98, loss_semantic = 2.74, test acc = 53.61%
# task = 31, loss = 8.36, loss_semantic = 2.63, test acc = 65.79%
# task = 32, loss = 8.12, loss_semantic = 2.54, test acc = 56.16%
# task = 33, loss = 8.25, loss_semantic = 2.49, test acc = 58.48%
# task = 34, loss = 8.07, loss_semantic = 2.39, test acc = 62.21%
# task = 35, loss = 8.45, loss_semantic = 2.33, test acc = 58.13%
# task = 36, loss = 8.11, loss_semantic = 2.23, test acc = 66.41%
# task = 37, loss = 8.24, loss_semantic = 2.19, test acc = 70.60%
# task = 38, loss = 7.66, loss_semantic = 2.07, test acc = 59.06%
# task = 39, loss = 8.32, loss_semantic = 1.98, test acc = 63.38%
# task = 40, loss = 7.93, loss_semantic = 1.90, test acc = 62.31%
# task = 41, loss = 7.71, loss_semantic = 1.81, test acc = 64.88%
# task = 42, loss = 8.07, loss_semantic = 1.74, test acc = 60.24%
# task = 43, loss = 8.22, loss_semantic = 1.66, test acc = 66.20%
# task = 44, loss = 7.81, loss_semantic = 1.59, test acc = 65.93%
# task = 45, loss = 8.21, loss_semantic = 1.50, test acc = 66.14%
# task = 46, loss = 7.78, loss_semantic = 1.42, test acc = 61.02%
# task = 47, loss = 7.77, loss_semantic = 1.35, test acc = 64.73%
# task = 48, loss = 7.77, loss_semantic = 1.27, test acc = 62.88%
# task = 49, loss = 7.71, loss_semantic = 1.26, test acc = 64.29%
# task = 50, loss = 7.91, loss_semantic = 1.16, test acc = 65.66%
# task = 51, loss = 8.24, loss_semantic = 1.05, test acc = 60.09%
# task = 52, loss = 7.94, loss_semantic = 0.97, test acc = 63.77%
# task = 53, loss = 7.63, loss_semantic = 0.93, test acc = 71.53%
# task = 54, loss = 7.53, loss_semantic = 0.90, test acc = 66.41%
# task = 55, loss = 7.60, loss_semantic = 0.81, test acc = 63.97%
# task = 56, loss = 7.91, loss_semantic = 0.75, test acc = 65.28%
# task = 57, loss = 7.86, loss_semantic = 0.69, test acc = 69.59%
# task = 58, loss = 7.96, loss_semantic = 0.64, test acc = 64.89%
# task = 59, loss = 8.01, loss_semantic = 0.60, test acc = 68.92%
# task = 60, loss = 8.01, loss_semantic = 0.49, test acc = 64.40%
# task = 61, loss = 7.98, loss_semantic = 0.45, test acc = 60.38%
# task = 62, loss = 7.72, loss_semantic = 0.45, test acc = 73.48%
# task = 63, loss = 7.78, loss_semantic = 0.42, test acc = 75.06%
# task = 64, loss = 8.04, loss_semantic = 0.31, test acc = 70.91%
# task = 65, loss = 8.19, loss_semantic = 0.27, test acc = 63.30%
# task = 66, loss = 7.80, loss_semantic = 0.26, test acc = 65.71%
# task = 67, loss = 7.57, loss_semantic = 0.25, test acc = 68.50%
# task = 68, loss = 7.63, loss_semantic = 0.21, test acc = 70.28%
# task = 69, loss = 7.48, loss_semantic = 0.20, test acc = 69.65%
# task = 70, loss = 7.47, loss_semantic = 0.25, test acc = 64.14%
# task = 71, loss = 7.68, loss_semantic = 0.18, test acc = 64.03%
# task = 72, loss = 7.90, loss_semantic = 0.12, test acc = 71.15%
# task = 73, loss = 7.60, loss_semantic = 0.20, test acc = 64.96%
# task = 74, loss = 7.70, loss_semantic = 0.16, test acc = 66.01%
# task = 75, loss = 7.91, loss_semantic = 0.14, test acc = 72.56%
# task = 76, loss = 7.58, loss_semantic = 0.18, test acc = 72.62%
# task = 77, loss = 7.89, loss_semantic = 0.15, test acc = 61.43%
# task = 78, loss = 7.65, loss_semantic = 0.16, test acc = 54.16%
# task = 79, loss = 7.85, loss_semantic = 0.10, test acc = 65.32%
# task = 80, loss = 7.65, loss_semantic = 0.13, test acc = 68.33%
# task = 81, loss = 7.90, loss_semantic = 0.10, test acc = 72.75%
# task = 82, loss = 8.03, loss_semantic = 0.08, test acc = 66.59%
# task = 83, loss = 7.58, loss_semantic = 0.12, test acc = 70.85%
# task = 84, loss = 8.15, loss_semantic = 0.16, test acc = 71.88%
# task = 85, loss = 7.29, loss_semantic = 0.16, test acc = 67.05%
# task = 86, loss = 7.57, loss_semantic = 0.16, test acc = 67.71%
# task = 87, loss = 7.18, loss_semantic = 0.18, test acc = 73.43%
# task = 88, loss = 7.32, loss_semantic = 0.19, test acc = 70.46%
# task = 89, loss = 7.53, loss_semantic = 0.15, test acc = 70.90%
# task = 90, loss = 7.59, loss_semantic = 0.15, test acc = 70.39%
# task = 91, loss = 7.54, loss_semantic = 0.13, test acc = 66.90%
# task = 92, loss = 7.55, loss_semantic = 0.17, test acc = 70.42%
# task = 93, loss = 7.69, loss_semantic = 0.13, test acc = 63.29%
# task = 94, loss = 7.47, loss_semantic = 0.17, test acc = 54.72%
# task = 95, loss = 7.66, loss_semantic = 0.09, test acc = 66.92%
# task = 96, loss = 7.88, loss_semantic = 0.09, test acc = 74.23%
# task = 97, loss = 7.32, loss_semantic = 0.11, test acc = 77.28%
# task = 98, loss = 8.00, loss_semantic = 0.07, test acc = 73.87%
# task = 99, loss = 7.81, loss_semantic = 0.08, test acc = 73.89%
# task = 100, loss = 7.48, loss_semantic = 0.11, test acc = 74.83%
# task = 101, loss = 7.72, loss_semantic = 0.14, test acc = 66.67%
# task = 102, loss = 7.35, loss_semantic = 0.18, test acc = 72.60%
# task = 103, loss = 7.59, loss_semantic = 0.10, test acc = 65.50%
# task = 104, loss = 7.54, loss_semantic = 0.10, test acc = 79.50%
# task = 105, loss = 7.72, loss_semantic = 0.09, test acc = 66.02%
# task = 106, loss = 7.63, loss_semantic = 0.10, test acc = 63.21%
# task = 107, loss = 7.71, loss_semantic = 0.15, test acc = 64.67%
# task = 108, loss = 7.26, loss_semantic = 0.10, test acc = 66.81%
# task = 109, loss = 7.51, loss_semantic = 0.07, test acc = 67.01%
# task = 110, loss = 7.48, loss_semantic = 0.10, test acc = 71.24%
# task = 111, loss = 7.43, loss_semantic = 0.14, test acc = 66.51%
# task = 112, loss = 7.63, loss_semantic = 0.14, test acc = 70.67%
# task = 113, loss = 7.61, loss_semantic = 0.07, test acc = 68.94%
# task = 114, loss = 7.52, loss_semantic = 0.09, test acc = 69.65%
# task = 115, loss = 7.26, loss_semantic = 0.18, test acc = 69.72%
# task = 116, loss = 7.69, loss_semantic = 0.08, test acc = 70.68%
# task = 117, loss = 7.70, loss_semantic = 0.11, test acc = 69.46%
# task = 118, loss = 7.49, loss_semantic = 0.12, test acc = 69.45%
# task = 119, loss = 7.44, loss_semantic = 0.08, test acc = 69.35%
# task = 120, loss = 7.42, loss_semantic = 0.11, test acc = 63.56%
# task = 121, loss = 7.57, loss_semantic = 0.07, test acc = 66.40%
# task = 122, loss = 7.83, loss_semantic = 0.12, test acc = 57.72%
# task = 123, loss = 7.33, loss_semantic = 0.20, test acc = 66.06%
# task = 124, loss = 7.40, loss_semantic = 0.16, test acc = 71.67%
# task = 125, loss = 7.93, loss_semantic = 0.10, test acc = 68.33%
# task = 126, loss = 7.47, loss_semantic = 0.17, test acc = 74.47%
# task = 127, loss = 7.47, loss_semantic = 0.09, test acc = 70.43%
# task = 128, loss = 7.79, loss_semantic = 0.08, test acc = 68.84%
# task = 129, loss = 7.60, loss_semantic = 0.10, test acc = 67.29%
# task = 130, loss = 7.79, loss_semantic = 0.07, test acc = 72.65%
# task = 131, loss = 7.54, loss_semantic = 0.08, test acc = 70.35%
# task = 132, loss = 7.97, loss_semantic = 0.10, test acc = 75.06%
# task = 133, loss = 7.45, loss_semantic = 0.10, test acc = 71.61%
# task = 134, loss = 7.61, loss_semantic = 0.11, test acc = 70.82%
# task = 135, loss = 7.58, loss_semantic = 0.10, test acc = 67.97%
# task = 136, loss = 7.79, loss_semantic = 0.09, test acc = 72.98%
# task = 137, loss = 7.41, loss_semantic = 0.08, test acc = 68.60%
# task = 138, loss = 7.75, loss_semantic = 0.08, test acc = 69.04%
# task = 139, loss = 7.37, loss_semantic = 0.16, test acc = 72.57%
# task = 140, loss = 7.44, loss_semantic = 0.15, test acc = 74.54%
# task = 141, loss = 7.56, loss_semantic = 0.10, test acc = 66.52%
# task = 142, loss = 7.34, loss_semantic = 0.12, test acc = 64.88%
# task = 143, loss = 7.83, loss_semantic = 0.08, test acc = 69.26%
# task = 144, loss = 7.81, loss_semantic = 0.09, test acc = 77.57%
# task = 145, loss = 7.41, loss_semantic = 0.11, test acc = 69.93%
# task = 146, loss = 7.52, loss_semantic = 0.12, test acc = 73.42%
# task = 147, loss = 7.61, loss_semantic = 0.09, test acc = 74.82%
# task = 148, loss = 7.61, loss_semantic = 0.11, test acc = 67.37%
# task = 149, loss = 7.81, loss_semantic = 0.07, test acc = 72.33%
# task = 150, loss = 7.30, loss_semantic = 0.18, test acc = 66.82%
# task = 151, loss = 7.40, loss_semantic = 0.10, test acc = 70.09%
# task = 152, loss = 7.19, loss_semantic = 0.16, test acc = 65.00%
# task = 153, loss = 7.65, loss_semantic = 0.12, test acc = 70.80%
# task = 154, loss = 7.47, loss_semantic = 0.13, test acc = 80.53%
# task = 155, loss = 7.69, loss_semantic = 0.11, test acc = 67.75%
# task = 156, loss = 7.43, loss_semantic = 0.12, test acc = 73.94%
# task = 157, loss = 7.55, loss_semantic = 0.09, test acc = 74.56%
# task = 158, loss = 7.18, loss_semantic = 0.13, test acc = 71.36%
# task = 159, loss = 7.71, loss_semantic = 0.08, test acc = 69.39%
# task = 160, loss = 7.87, loss_semantic = 0.07, test acc = 72.53%
# task = 161, loss = 7.46, loss_semantic = 0.09, test acc = 64.40%
# task = 162, loss = 7.57, loss_semantic = 0.12, test acc = 74.30%
# task = 163, loss = 7.67, loss_semantic = 0.11, test acc = 69.71%
# task = 164, loss = 7.29, loss_semantic = 0.14, test acc = 71.05%
# task = 165, loss = 7.23, loss_semantic = 0.15, test acc = 74.27%
# task = 166, loss = 7.65, loss_semantic = 0.12, test acc = 69.32%
# task = 167, loss = 7.42, loss_semantic = 0.11, test acc = 77.89%
# task = 168, loss = 7.40, loss_semantic = 0.09, test acc = 69.15%
# task = 169, loss = 7.26, loss_semantic = 0.12, test acc = 71.53%
# task = 170, loss = 7.25, loss_semantic = 0.15, test acc = 76.35%
# task = 171, loss = 7.22, loss_semantic = 0.15, test acc = 74.70%
# task = 172, loss = 7.37, loss_semantic = 0.17, test acc = 77.63%
# task = 173, loss = 7.45, loss_semantic = 0.14, test acc = 77.53%
# task = 174, loss = 7.60, loss_semantic = 0.07, test acc = 62.74%
# task = 175, loss = 7.49, loss_semantic = 0.10, test acc = 75.12%
# task = 176, loss = 7.14, loss_semantic = 0.14, test acc = 68.97%
# task = 177, loss = 7.67, loss_semantic = 0.10, test acc = 68.62%
# task = 178, loss = 7.29, loss_semantic = 0.15, test acc = 74.55%
# task = 179, loss = 7.44, loss_semantic = 0.10, test acc = 75.17%
# task = 180, loss = 7.37, loss_semantic = 0.15, test acc = 73.47%
# task = 181, loss = 7.55, loss_semantic = 0.07, test acc = 79.26%
# task = 182, loss = 7.55, loss_semantic = 0.08, test acc = 72.37%
# task = 183, loss = 7.70, loss_semantic = 0.11, test acc = 68.43%
# task = 184, loss = 7.28, loss_semantic = 0.15, test acc = 76.04%
# task = 185, loss = 7.63, loss_semantic = 0.15, test acc = 72.26%
# task = 186, loss = 7.51, loss_semantic = 0.13, test acc = 64.84%
# task = 187, loss = 7.43, loss_semantic = 0.09, test acc = 75.17%
# task = 188, loss = 7.21, loss_semantic = 0.10, test acc = 73.03%
# task = 189, loss = 7.17, loss_semantic = 0.17, test acc = 72.61%
# task = 190, loss = 7.47, loss_semantic = 0.10, test acc = 68.24%
# task = 191, loss = 7.26, loss_semantic = 0.10, test acc = 70.86%
# task = 192, loss = 7.60, loss_semantic = 0.09, test acc = 60.58%
# task = 193, loss = 7.86, loss_semantic = 0.07, test acc = 60.25%
# task = 194, loss = 7.27, loss_semantic = 0.11, test acc = 67.45%
# task = 195, loss = 7.32, loss_semantic = 0.12, test acc = 72.54%
# task = 196, loss = 7.20, loss_semantic = 0.10, test acc = 72.13%
# task = 197, loss = 7.62, loss_semantic = 0.10, test acc = 69.59%
# task = 198, loss = 7.36, loss_semantic = 0.13, test acc = 76.29%
# task = 199, loss = 7.62, loss_semantic = 0.05, test acc = 68.97%
# task = 200, loss = 7.19, loss_semantic = 0.13, test acc = 81.86%
# task = 201, loss = 7.58, loss_semantic = 0.07, test acc = 70.50%
# task = 202, loss = 7.51, loss_semantic = 0.10, test acc = 77.31%
# task = 203, loss = 7.54, loss_semantic = 0.07, test acc = 78.45%
# task = 204, loss = 7.41, loss_semantic = 0.11, test acc = 78.88%
# task = 205, loss = 7.51, loss_semantic = 0.10, test acc = 73.20%
# task = 206, loss = 7.39, loss_semantic = 0.06, test acc = 72.95%
# task = 207, loss = 7.36, loss_semantic = 0.10, test acc = 76.80%
# task = 208, loss = 7.36, loss_semantic = 0.09, test acc = 64.52%
# task = 209, loss = 7.49, loss_semantic = 0.06, test acc = 70.82%
# task = 210, loss = 7.65, loss_semantic = 0.07, test acc = 72.95%
# task = 211, loss = 7.29, loss_semantic = 0.12, test acc = 73.46%
# task = 212, loss = 7.82, loss_semantic = 0.09, test acc = 72.76%
# task = 213, loss = 7.65, loss_semantic = 0.10, test acc = 75.00%
# task = 214, loss = 7.27, loss_semantic = 0.11, test acc = 76.71%
# task = 215, loss = 7.54, loss_semantic = 0.09, test acc = 76.85%
# task = 216, loss = 7.47, loss_semantic = 0.12, test acc = 74.90%
# task = 217, loss = 7.36, loss_semantic = 0.11, test acc = 75.00%
# task = 218, loss = 7.79, loss_semantic = 0.08, test acc = 73.17%
# task = 219, loss = 7.68, loss_semantic = 0.10, test acc = 71.32%
# task = 220, loss = 7.61, loss_semantic = 0.09, test acc = 72.76%
# task = 221, loss = 7.24, loss_semantic = 0.16, test acc = 73.39%
# task = 222, loss = 7.68, loss_semantic = 0.10, test acc = 74.20%
# task = 223, loss = 7.87, loss_semantic = 0.09, test acc = 73.95%
# task = 224, loss = 7.37, loss_semantic = 0.11, test acc = 73.12%
# task = 225, loss = 7.53, loss_semantic = 0.11, test acc = 65.06%
# task = 226, loss = 7.42, loss_semantic = 0.05, test acc = 78.29%
# task = 227, loss = 7.64, loss_semantic = 0.08, test acc = 73.67%
# task = 228, loss = 7.44, loss_semantic = 0.11, test acc = 73.85%
# task = 229, loss = 7.41, loss_semantic = 0.08, test acc = 73.00%
# task = 230, loss = 7.54, loss_semantic = 0.06, test acc = 76.18%
# task = 231, loss = 7.29, loss_semantic = 0.08, test acc = 71.43%
# task = 232, loss = 7.47, loss_semantic = 0.08, test acc = 72.62%
# task = 233, loss = 7.59, loss_semantic = 0.09, test acc = 67.14%
# task = 234, loss = 7.23, loss_semantic = 0.06, test acc = 67.49%
# task = 235, loss = 7.32, loss_semantic = 0.10, test acc = 64.53%
# task = 236, loss = 7.41, loss_semantic = 0.15, test acc = 59.72%
# task = 237, loss = 7.56, loss_semantic = 0.10, test acc = 65.39%
# task = 238, loss = 7.35, loss_semantic = 0.09, test acc = 73.81%
# task = 239, loss = 7.31, loss_semantic = 0.10, test acc = 69.18%
# task = 240, loss = 7.52, loss_semantic = 0.15, test acc = 71.67%
# task = 241, loss = 7.31, loss_semantic = 0.13, test acc = 70.24%
# task = 242, loss = 7.52, loss_semantic = 0.14, test acc = 71.40%
# task = 243, loss = 7.22, loss_semantic = 0.13, test acc = 73.16%
# task = 244, loss = 7.39, loss_semantic = 0.08, test acc = 67.06%
# task = 245, loss = 7.42, loss_semantic = 0.11, test acc = 70.94%
# task = 246, loss = 7.39, loss_semantic = 0.14, test acc = 71.36%
# task = 247, loss = 7.48, loss_semantic = 0.06, test acc = 66.74%
# task = 248, loss = 7.66, loss_semantic = 0.10, test acc = 69.32%
# task = 249, loss = 7.87, loss_semantic = 0.07, test acc = 73.04%
# task = 250, loss = 7.26, loss_semantic = 0.11, test acc = 74.76%
# task = 251, loss = 7.32, loss_semantic = 0.12, test acc = 72.20%
# task = 252, loss = 7.51, loss_semantic = 0.10, test acc = 72.06%
# task = 253, loss = 7.20, loss_semantic = 0.16, test acc = 65.47%
# task = 254, loss = 7.29, loss_semantic = 0.12, test acc = 64.71%
# task = 255, loss = 7.31, loss_semantic = 0.11, test acc = 63.08%
# task = 256, loss = 7.19, loss_semantic = 0.11, test acc = 78.98%
# task = 257, loss = 7.29, loss_semantic = 0.11, test acc = 69.92%
# task = 258, loss = 7.23, loss_semantic = 0.12, test acc = 84.29%
# task = 259, loss = 7.30, loss_semantic = 0.10, test acc = 74.94%
# task = 260, loss = 7.35, loss_semantic = 0.12, test acc = 76.83%
# task = 261, loss = 7.46, loss_semantic = 0.13, test acc = 69.56%
# task = 262, loss = 7.89, loss_semantic = 0.11, test acc = 74.42%
# task = 263, loss = 7.38, loss_semantic = 0.09, test acc = 77.59%
# task = 264, loss = 7.36, loss_semantic = 0.10, test acc = 73.90%
# task = 265, loss = 7.59, loss_semantic = 0.07, test acc = 72.65%
# task = 266, loss = 7.55, loss_semantic = 0.08, test acc = 72.27%
# task = 267, loss = 7.53, loss_semantic = 0.09, test acc = 62.88%
# task = 268, loss = 7.52, loss_semantic = 0.08, test acc = 73.36%
# task = 269, loss = 7.87, loss_semantic = 0.06, test acc = 73.67%
# task = 270, loss = 7.63, loss_semantic = 0.05, test acc = 66.81%
# task = 271, loss = 7.09, loss_semantic = 0.14, test acc = 70.27%
# task = 272, loss = 7.27, loss_semantic = 0.13, test acc = 73.41%
# task = 273, loss = 7.27, loss_semantic = 0.10, test acc = 77.53%
# task = 274, loss = 7.46, loss_semantic = 0.11, test acc = 70.32%
# task = 275, loss = 7.81, loss_semantic = 0.06, test acc = 67.33%
# task = 276, loss = 7.59, loss_semantic = 0.10, test acc = 77.95%
# task = 277, loss = 7.35, loss_semantic = 0.13, test acc = 76.49%
# task = 278, loss = 7.33, loss_semantic = 0.09, test acc = 68.76%
# task = 279, loss = 7.11, loss_semantic = 0.15, test acc = 81.12%
# task = 280, loss = 7.31, loss_semantic = 0.05, test acc = 80.05%
# task = 281, loss = 7.43, loss_semantic = 0.08, test acc = 78.24%
# task = 282, loss = 7.48, loss_semantic = 0.11, test acc = 72.98%
# task = 283, loss = 7.35, loss_semantic = 0.09, test acc = 79.53%
# task = 284, loss = 7.69, loss_semantic = 0.11, test acc = 75.89%
# task = 285, loss = 7.27, loss_semantic = 0.14, test acc = 73.11%
# task = 286, loss = 7.50, loss_semantic = 0.11, test acc = 76.80%
# task = 287, loss = 7.43, loss_semantic = 0.08, test acc = 68.15%
# task = 288, loss = 7.61, loss_semantic = 0.10, test acc = 72.60%
# task = 289, loss = 7.30, loss_semantic = 0.11, test acc = 75.93%
# task = 290, loss = 7.60, loss_semantic = 0.07, test acc = 81.30%
# task = 291, loss = 7.46, loss_semantic = 0.07, test acc = 66.67%
# task = 292, loss = 7.36, loss_semantic = 0.08, test acc = 74.31%
# task = 293, loss = 7.52, loss_semantic = 0.09, test acc = 73.91%
# task = 294, loss = 7.44, loss_semantic = 0.09, test acc = 67.66%
# task = 295, loss = 7.39, loss_semantic = 0.16, test acc = 70.06%
# task = 296, loss = 7.50, loss_semantic = 0.08, test acc = 80.65%
# task = 297, loss = 7.47, loss_semantic = 0.13, test acc = 75.94%
# task = 298, loss = 7.16, loss_semantic = 0.12, test acc = 70.90%
# task = 299, loss = 7.43, loss_semantic = 0.09, test acc = 74.27%
# The best accuracy is 84.29 at episode number 258.
# Total execution time: 206.79000782966614 seconds

# %%
import matplotlib.pyplot as plt

def plot_performance(task_train_losses, task_test_accuracies, name=None):
    """
    Plots the training losses and test accuracies for a given task.

    Parameters:
    - task_train_losses (list): List of training losses for each epoch.
    - task_test_accuracies (list): List of test accuracies for each epoch.
    - name (str): Name to save the plot with. If None, the plot won't be saved.
    """
    epochs = range(1, len(task_train_losses) + 1)

    # Plotting training losses
    plt.figure(figsize=(5, 5))
    plt.subplot(2, 1, 1)
    plt.plot(epochs, task_train_losses, 'b', label='Training Loss')
    plt.title('Training Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    # Plotting test accuracies
    plt.subplot(2, 1, 2)
    plt.plot(epochs, task_test_accuracies, 'r', label='Test Accuracy')
    plt.title('Test Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.tight_layout()
    
    # Save the plot with the specified name if provided
    if name:
        plt.savefig(f"{name}.png")
    
    plt.show()


plot_performance(task_train_losses, task_test_accuracies, name = 'base training')

# %%
# Print the result
print(f"The best accuracy is {best_accuracy:.2f}% at episode number: {best_episode}.")
# Out:
# The best accuracy is 84.29% at episode number: 258.

# %%
def consolidate_cluster_means(cluster_means, best_episode):
    if best_episode < 0 or best_episode >= len(cluster_means):
        raise ValueError("best_episode index is out of range")

    # Access the dictionary corresponding to the best episode
    best_episode_dict = cluster_means[best_episode][0]

    return best_episode_dict

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch

def plot_cluster_means_tsne(coordinates, figsize=(2, 2), name=None):
    # Convert coordinates to numpy array
    coordinates_array = np.array([coord.detach().numpy() if isinstance(coord, torch.Tensor) else coord for coord in coordinates.values()])

    # Plotting
    fig, ax = plt.subplots(figsize=figsize)  # Specify the figure size
    for i, (label, coord) in enumerate(coordinates.items()):
        if isinstance(coord, torch.Tensor):
            coord = coord.detach().numpy()
        ax.scatter(coord[0], coord[1], label=f'Class {label}', marker='o',s= 50)
        #ax.annotate(f'{label}', (coord[0], coord[1]), textcoords="offset points", xytext=(0.1,0.1), ha='center')

    # Add labels and legend
    ax.set_xlabel('Dimension 1')
    ax.set_ylabel('Dimension 2')
    ax.set_title('Class Prototypes')

    # Remove ticks and labels from the x and y axes
#     ax.set_xticks([])
#     ax.set_yticks([])
#     ax.xaxis.set_visible(True)
#     ax.yaxis.set_visible(True)
    
    # Add grid lines
    ax.grid(True)

    # Save the plot with the specified name if provided
    if name:
        plt.savefig(f"{name}.png")

    # Show the plot
    plt.show()


plot_cluster_means_tsne(consolidate_cluster_means(cluster_means, best_episode), figsize=(2, 2), name = 'base clusters')

# %%
# break

# %% [markdown]
# ### Finetuning

# %%
meta_model = GATmodel(in_channels, hidden_channels, out_channels)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
meta_model = meta_model.to(device)
# Out:
# GATConv init.

# %%
# Load the saved model
loaded_model = GATmodel(in_channels, hidden_channels, out_channels)
loaded_model.load_state_dict(torch.load('/kaggle/working/meta_model.pth'))
loaded_model = loaded_model.to(device)
print(loaded_model)
# Out:
# GATConv init.
# GATmodel(
#   (gat_layer_1): GATConv(128, 512, heads=3)
#   (gat_layer_2): GATConv(512, 512, heads=3)
# )

# %%
# Instantiate a new semantic_model
semantic_model_loaded = NeuralNetwork(input_size, hidden_size)
# Load the saved parameters
semantic_model_loaded.load_state_dict(torch.load('semantic_model.pth'))
# Out:
# <All keys matched successfully>

# %%
import dgl
import numpy as np

def process_incremental_graphs(graph, num_classes_to_keep, random_seed=None, remaining_classes=None):
    # Fix the random seed
    if random_seed is not None:
        np.random.seed(random_seed)

    # Step 1: Identify the number of classes in the graph
    num_classes = len(np.unique(graph.ndata['label'].numpy()))

    # Step 2: Validate the given number of classes to keep
    if not 0 < num_classes_to_keep <= num_classes:
        raise ValueError("Invalid number of classes to keep.")

    # Step 3: Initialize remaining classes if not provided
    if remaining_classes is None:
        remaining_classes = set(range(num_classes))

    # Step 4: Sample classes without replacement until all classes are exhausted
    if len(remaining_classes) < num_classes_to_keep:
        raise ValueError("Not enough remaining classes to sample.")

    p_classes = np.random.choice(list(remaining_classes), size=num_classes_to_keep, replace=False)


    #print(f"Sampled Classes: {p_classes}")

    # Step 5: Sample nodes corresponding to the specified classes without replacement
    p_nodes = [i for i in range(graph.number_of_nodes()) if graph.ndata['label'][i].item() in p_classes]
    sampled_graph = dgl.node_subgraph(graph, p_nodes)

    # Step 6: Extract node labels and features corresponding to sampled nodes
    sampled_labels = sampled_graph.ndata['label']
    sampled_features = graph.ndata['feat'][p_nodes]  # Replace 'feat' with the actual feature name

    # Step 7: Set the features for the sampled graph
    sampled_graph.ndata['feat'] = sampled_features

    # Step 8: Create a new DGL graph object with sampled features and labels
    new_graph = dgl.graph((sampled_graph.edges()[0], sampled_graph.edges()[1]), num_nodes=sampled_graph.number_of_nodes())
    new_graph.ndata['label'] = sampled_labels
    new_graph.ndata['feat'] = sampled_features  # Replace 'feat' with the actual feature name

    return new_graph, remaining_classes

# %%
import random
import numpy as np
import torch
import dgl.data
from collections import OrderedDict

class FineTune_DataGenerator:
    def __init__(self, dataset, num_tasks, num_classes, num_support, num_query, base_classes, novel_classes_list, task_random_seeds, random_seeds, num_walks, walk_length, stream_seed):
        self.dataset = dataset
        self.num_tasks = num_tasks
        self.num_classes = num_classes
        self.num_support = num_support
        self.num_query = num_query
        self.task_random_seeds = task_random_seeds
        self.random_seeds = random_seeds
        self.num_walks = num_walks
        self.walk_length = walk_length
        self.base_classes = base_classes
        self.novel_classes_list = novel_classes_list
        self.stream_seed = stream_seed
        self.task_data = []


    def set_random_seed(self, seed):
        random.seed(seed)
        np.random.seed(seed)
        torch.manual_seed(seed)

    def create_task(self, seed, task_random_seeds, base_classes, novel_classes_list):
        tasks_base_unique_classes = []
        tasks_last_k_classes = []
        edge_indices_train_list_base_unique_classes = []
        edge_indices_train_list_last_k_classes = []
        edge_indices_test_list_base_unique_classes = []
        edge_indices_test_list_last_k_classes = []
        support_random_walks_list_base_unique_classes = []
        support_random_walks_list_last_k_classes = []
        query_random_walks_list_base_unique_classes = []
        query_random_walks_list_last_k_classes = []

        for task_seed in task_random_seeds:
            self.set_random_seed(task_seed)
            task_base_unique_classes = {}
            task_last_k_classes = {}
            support_set_last_k_classes = []
            support_set_base_unique_classes = []
            query_set_last_k_classes = []
            query_set_base_unique_classes = []




            for c in base_classes:

                indices = np.where(self.dataset.ndata['label'].numpy() == c)[0]
                support_indices = np.random.choice(indices, size=self.num_support, replace= False)
                query_indices = np.random.choice(indices, size=self.num_query, replace= False)

                support_set_base_unique_classes.extend(support_indices)
                query_set_base_unique_classes.extend(query_indices)

            support_random_walks = self.generate_random_walks(support_set_base_unique_classes)
            support_random_walks_list_base_unique_classes.append(support_random_walks)

            query_random_walks = self.generate_random_walks(query_set_base_unique_classes)
            query_random_walks_list_base_unique_classes.append(query_random_walks)

            # Include query nodes and nodes from query random walks in the 'test' set
            test_set = list(set(query_set_base_unique_classes + [node for walk in query_random_walks for node in walk]))
            task_base_unique_classes['test'] = test_set

            train_set = list(set(support_set_base_unique_classes + [node for walk in support_random_walks for node in walk]))
            task_base_unique_classes['train'] = train_set
            task_base_unique_classes['query_set'] = query_set_base_unique_classes
            task_base_unique_classes['support_set'] = support_set_base_unique_classes
            task_base_unique_classes['seed'] = task_seed

            tasks_base_unique_classes.append(task_base_unique_classes)

            # Generate edge indices for the combined set of query nodes and nodes from query random walks
            edge_indices_test = self.get_edges_from_nodes(test_set)
            edge_indices_train = self.get_edges_from_nodes(train_set)

            edge_indices_test_list_base_unique_classes.append(edge_indices_test)
            edge_indices_train_list_base_unique_classes.append(edge_indices_train)



            for c in novel_classes_list:
                np.random.seed(self.stream_seed)

                indices = np.where(self.dataset.ndata['label'].numpy() == c)[0]
                support_indices = np.random.choice(indices, size=self.num_support, replace= False)
                query_indices = np.random.choice(indices, size=self.num_query, replace= False)

                support_set_last_k_classes.extend(support_indices)
                query_set_last_k_classes.extend(query_indices)

            support_random_walks = self.generate_random_walks(support_set_last_k_classes)
            support_random_walks_list_last_k_classes.append(support_random_walks)

            query_random_walks = self.generate_random_walks(query_set_last_k_classes)
            query_random_walks_list_last_k_classes.append(query_random_walks)

            # Include query nodes and nodes from query random walks in the 'test' set
            test_set = list(set(query_set_last_k_classes + [node for walk in query_random_walks for node in walk]))
            task_last_k_classes['test'] = test_set

            train_set = list(set(support_set_last_k_classes + [node for walk in support_random_walks for node in walk]))
            task_last_k_classes['train'] = train_set
            task_last_k_classes['query_set'] = query_set_last_k_classes
            task_last_k_classes['support_set'] = support_set_last_k_classes
            task_last_k_classes['seed'] = task_seed

            tasks_last_k_classes.append(task_last_k_classes)

            # Generate edge indices for the combined set of query nodes and nodes from query random walks
            edge_indices_test = self.get_edges_from_nodes(test_set)
            edge_indices_train = self.get_edges_from_nodes(train_set)

            edge_indices_test_list_last_k_classes.append(edge_indices_test)
            edge_indices_train_list_last_k_classes.append(edge_indices_train)

        return tasks_last_k_classes, edge_indices_train_list_last_k_classes, edge_indices_test_list_last_k_classes, support_random_walks_list_last_k_classes, query_random_walks_list_last_k_classes, tasks_base_unique_classes, edge_indices_train_list_base_unique_classes, edge_indices_test_list_base_unique_classes, support_random_walks_list_base_unique_classes, query_random_walks_list_base_unique_classes



    def generate_random_walks(self, nodes):
        random_walks = []

        for node in nodes:
            for _ in range(self.num_walks):
                current_node = node
                walk = [current_node]
                for _ in range(self.walk_length - 1):
                    neighbors = list(self.dataset.successors(current_node).numpy())
                    if len(neighbors) > 0:
                        current_node = random.choice(neighbors)
                        walk.append(current_node)
                    else:
                        break
                random_walks.append(walk)

        return random_walks

    def get_edges_from_nodes(self, nodes):
        src, dst = [], []
        for node in nodes:
            successors = list(self.dataset.successors(node).numpy())
            for successor in successors:
                src.append(node)
                dst.append(successor)

        edge_index = torch.stack([torch.tensor(src), torch.tensor(dst)], dim=0).long()
        return edge_index

    def generate_tasks(self):
        tasks_base_unique_classes = []
        tasks_last_k_classes = []
        edge_indices_train_list_base_unique_classes = []
        edge_indices_train_list_last_k_classes = []
        edge_indices_test_list_base_unique_classes = []
        edge_indices_test_list_last_k_classes = []
        support_random_walks_list_base_unique_classes = []
        support_random_walks_list_last_k_classes = []
        query_random_walks_list_base_unique_classes = []
        query_random_walks_list_last_k_classes = []


        for seed in self.random_seeds:
            tasks_data_last_k_classes, edges_train_last_k_classes, edges_test_last_k_classes, support_walks_last_k_classes, query_walks_last_k_classes, tasks_data_base_unique_classes, edges_train_base_unique_classes, edges_test_base_unique_classes, support_walks_base_unique_classes, query_walks_base_unique_classes = self.create_task(seed, self.task_random_seeds, self.base_classes, self.novel_classes_list)
            tasks_base_unique_classes.extend(tasks_data_base_unique_classes)
            tasks_last_k_classes.extend(tasks_data_last_k_classes)
            edge_indices_train_list_base_unique_classes.extend(edges_train_base_unique_classes)
            edge_indices_train_list_last_k_classes.extend(edges_train_last_k_classes)
            edge_indices_test_list_base_unique_classes.extend(edges_test_base_unique_classes)
            edge_indices_test_list_last_k_classes.extend(edges_test_last_k_classes)
            support_random_walks_list_base_unique_classes.extend(support_walks_base_unique_classes)
            support_random_walks_list_last_k_classes.extend(support_walks_last_k_classes)
            query_random_walks_list_base_unique_classes.extend(query_walks_base_unique_classes)
            query_random_walks_list_last_k_classes.extend(query_walks_last_k_classes)


        return tasks_base_unique_classes, tasks_last_k_classes , edge_indices_train_list_base_unique_classes, edge_indices_train_list_last_k_classes, edge_indices_test_list_base_unique_classes, edge_indices_test_list_last_k_classes, support_random_walks_list_base_unique_classes, support_random_walks_list_last_k_classes, query_random_walks_list_base_unique_classes, query_random_walks_list_last_k_classes

# %%
import torch
from torch_geometric.data import Data
import numpy as np

def create_context_and_datasets(graph, num_classes, num_support, num_query, base_classes, novel_classes_list, stream_seed, start_seed, spacing, num_seeds):
    # Your existing code for generating random seeds
    task_random_seeds = [start_seed + i * spacing for i in range(num_seeds)]
    random_seeds = [42]
    num_tasks = num_seeds

    # Your existing code for generating tasks and extracting features
    metadata_generator = FineTune_DataGenerator(graph, num_tasks, num_classes, num_support, num_query, base_classes, novel_classes_list, task_random_seeds, random_seeds, 10, 3,  stream_seed)
    tasks_base_unique_classes, tasks_last_k_classes, edge_indices_train_list_base_unique_classes, edge_indices_train_list_last_k_classes, edge_indices_test_list_base_unique_classes, edge_indices_test_list_last_k_classes, support_random_walks_list_base_unique_classes, support_random_walks_list_last_k_classes, query_random_walks_list_base_unique_classes, query_random_walks_list_last_k_classes = metadata_generator.generate_tasks()

    # Your existing code for combining tasks
    combined_query_random_walks_list = [
        query_base + query_last_k
        for query_base, query_last_k in zip(query_random_walks_list_base_unique_classes, query_random_walks_list_last_k_classes)
    ]

    # Your existing code for combining edge indices
    combined_edge_indices_train_list = [
        torch.cat([edge_base, edge_last_k], dim=1)
        for edge_base, edge_last_k in zip(edge_indices_train_list_base_unique_classes, edge_indices_train_list_last_k_classes)
    ]

    combined_edge_indices_test_list = [
        torch.cat([edge_base, edge_last_k], dim=1)
        for edge_base, edge_last_k in zip(edge_indices_test_list_base_unique_classes, edge_indices_test_list_last_k_classes)
    ]

    # Your existing code for combining support random walks
    combined_support_random_walks_list = [
        support_base + support_last_k
        for support_base, support_last_k in zip(support_random_walks_list_base_unique_classes, support_random_walks_list_last_k_classes)
    ]

    combined_tasks = []
    for base_task, last_k_task in zip(tasks_base_unique_classes, tasks_last_k_classes):
        combined_task = {
            'test': base_task['test'] + last_k_task['test'],
            'train': base_task['train'] + last_k_task['train'],
            'query_set': base_task['query_set'] + last_k_task['query_set'],
            'support_set': base_task['support_set'] + last_k_task['support_set'],
            'seed': base_task['seed'],  # You may want to choose which seed to use
        }
        combined_tasks.append(combined_task)

    train_set_list = []
    test_set_list = []
    context_dictionary_list = []
    task_datasets_euc = []

    for i, task in enumerate(combined_tasks):
        #print(f"Episodes: {i} - Seed: {task['seed']}, streaming seed = {stream_seed}")
        seed = tasks_last_k_classes[i]['seed']
        extractor = create_feature_label_extractor(graph, combined_tasks)
        train_features, train_labels, test_features, test_labels, support_features, support_labels, query_features, query_labels, train_degrees, test_degrees, support_degrees, query_degrees = extractor(i, seed)

        train_set_list.append(task['train'])
        test_set_list.append(task['test'])

        reindexed_train_set, reindexed_edge_indices_train, reindexed_random_walks_train, old_to_new_mapping_train = reindex_nodes(i, train_set_list, combined_edge_indices_train_list, combined_support_random_walks_list)
        reindexed_test_set, reindexed_edge_indices_test, reindexed_random_walks_test, old_to_new_mapping_test = reindex_nodes(i, test_set_list, combined_edge_indices_test_list, combined_query_random_walks_list)

        data_train_euc = Data(x=train_features, edge_index=reindexed_edge_indices_train, y=train_labels)
        data_test_euc = Data(x=test_features, edge_index=reindexed_edge_indices_test, y=test_labels)
        task_datasets_euc.append((data_train_euc, data_test_euc))

        labels_for_nodes, remaining_nodes, original_first_node_list, all_firsts = dict_for_custom_loss_function(reindexed_random_walks_train, old_to_new_mapping_train, graph)

        result_label_dict = create_label_dict(labels_for_nodes, remaining_nodes, all_firsts)

        unique_elements_result = get_unique_elements_in_order(all_firsts)

        unique_elements_result = np.array(unique_elements_result).reshape(num_classes, num_support)
        # Add elements to the reformulated dictionary
        add_elements_to_dictionary_list(result_label_dict, unique_elements_result)
        # Print the reformulated dictionary after adding elements
        context_dictionary_list.append(result_label_dict)

    return context_dictionary_list, task_datasets_euc

# %%
def get_unique_classes(graph):
    """
    Extracts unique class labels from the 'label' attribute of a graph's node data.

    Parameters:
    - graph: The input graph.

    Returns:
    - list_of_classes: A list of unique class labels.
    """
    try:
        # Assuming 'label' is a tensor or NumPy array
        class_labels = graph.ndata['label'].numpy()
    except KeyError:
        # Adjust the key if the attribute name is different
        print("Error: 'label' attribute not found in node data.")
        return []

    # Extract unique class labels
    unique_classes = set(class_labels)

    # Convert the set to a list (order not guaranteed)
    list_of_classes = list(unique_classes)

    return list_of_classes

# %%
base_remaining_classes = set(range(len(np.unique(Original_graph.ndata['label'].numpy()))))  # Start with all classes

sampled_graph_base, _ = process_incremental_graphs(
    Original_graph,
    num_classes_to_keep= 13,
    random_seed= n_seed,
    remaining_classes=base_remaining_classes
)
get_unique_classes(sampled_graph_base)
# Out:
# [4, 37, 6, 39, 9, 12, 13, 15, 16, 19, 25, 26, 27]

# %% [markdown]
# knowledge distillation

# %%
import torch

def KDloss(teacher_train_output, semantic_output_teacher, train_output, semantic_output, novel_classes, train_label):
    # Convert novel_classes to a tensor for comparison
    novel_classes_tensor = torch.tensor(novel_classes)

    # Find indices of rows in train_label corresponding to novel_classes
    novel_indices = torch.where(torch.isin(train_label, novel_classes_tensor))[0]

    # Create a boolean mask for filtering
    mask = torch.ones(len(train_label), dtype=torch.bool)
    mask[novel_indices] = False

    # Filter out the corresponding rows from teacher_train_output and train_output
    teacher_train_output_filtered = teacher_train_output[mask]
    train_output_filtered = train_output[mask]

    # Remove key-value pairs from semantic_output_teacher and semantic_output for novel classes
    for label in novel_classes:
        if label in semantic_output_teacher:
            del semantic_output_teacher[label]
        if label in semantic_output:
            del semantic_output[label]

    # Match and update semantic embeddings for common classes
    teacher_sem = []
    student_sem = []

    for label in semantic_output_teacher.keys():
        if label in semantic_output:
            # Concatenate semantic embeddings for the same class label
            teacher_sem.append(semantic_output_teacher[label])
            student_sem.append(semantic_output[label])

    # Stack the lists of embeddings along a new axis to create tensors
    teacher_sem = torch.stack(teacher_sem)
    student_sem = torch.stack(student_sem)

    # Now both the teacher and student for both node alignment and semantic alignment contain only those labels
    # from the previous stream

    # Node alignment loss
    squared_distance = torch.sum((torch.exp(teacher_train_output_filtered) - torch.exp(train_output_filtered)) ** 1, dim=1)
    # Average over samples
    N = teacher_train_output_filtered.size(0)
    node_loss = torch.mean(squared_distance) / N

    # Semantic alignment loss
    dot_product = torch.sum(teacher_sem * student_sem, dim=1)
    # Calculate norms
    teacher_norm = torch.norm(teacher_sem, dim=1)
    student_norm = torch.norm(student_sem, dim=1)
    # Calculate loss term
    loss_term = 1 - dot_product / (teacher_norm * student_norm)
    # Average over classes
    C = teacher_sem.size(0)
    semantic_alignment_loss = torch.mean(loss_term) / C

    return node_loss, semantic_alignment_loss

# %%
from collections import Counter

def fine_tune(teacher_model, teacher_model_semantic, novel_classes, meta_model, semantic_model, task_datasets, ft_lr, weight_decays, context_dictionary_list, semantic_vectors):
    optimizer_meta = optim.Adam(meta_model.parameters(), lr=meta_lr, weight_decay=weight_decays)
    optimizer_semantic = optim.Adam(semantic_model.parameters(), lr=0.01, weight_decay=weight_decays)

    total_losses = []  # List to store total losses over meta-epochs
    task_train_losses = []  # List to store task train losses over meta-epochs
    task_test_losses = [[] for _ in range(len(task_datasets))]  # List to store task test losses over meta-epochs
    task_train_accuracies = [[] for _ in range(len(task_datasets))]  # List to store task train accuracies over meta-epochs
    task_test_accuracies = []  # List to store task test accuracies 
    task_cluster_means = [[] for _ in range(len(task_datasets))]  # List to store task means over episodes
    all_train_data = []
    task_dictionary = {}

     

    # Inner loop (tasks)
    for i, task_data in enumerate(task_datasets):
        task_train_data, task_test_data = task_data

        all_train_data.append(task_train_data)
        
        # teacher model will be in evaluation mode
        teacher_model.eval()
        teacher_model_semantic.eval()
        semantic_output_teacher = {}
        for label, embed in semantic_vectors.items():
            output_teacher = teacher_model_semantic(embed).squeeze()
            semantic_output_teacher[label] = output_teacher
        
        #print(f'teacher: {semantic_output_teacher}')
        
        teacher_train_output = teacher_model(task_train_data.x, task_train_data.edge_index)
        #print(f'teacher train: {teacher_train_output}')
 
        
        # Training phase
        meta_model.train()
        semantic_model.train()  # Set the semantic model to training mode
        optimizer_meta.zero_grad()
        optimizer_semantic.zero_grad()
        
        # meta_model is the student model, student model will be in training phase
        train_output = meta_model(task_train_data.x, task_train_data.edge_index)  # Embeddings (train)
        #print(f'student train: {train_output}')
        
        train_label = task_train_data.y
        loss_intra, _ = Lintra_loss(train_output, context_dictionary_list[i], 0.01, semantic_vectors)
        loss_inter, mean_vectors = Linter_loss(train_output, context_dictionary_list[i], semantic_vectors)

        # Semantic model forward pass
        semantic_output = {}
        for label, embed in semantic_vectors.items():
            output = semantic_model(embed).squeeze()
            semantic_output[label] = output

            


        # Calculate semantic loss
        semantic_loss_proto, semantic_output, semantic_embeddings_dict = L_proto(mean_vectors, semantic_output)
        
        #print(f'student: {semantic_embeddings_dict}')
             
        
        # Calculate the knowledge distillation loss
        node_loss, semantic_alignment_loss = KDloss(teacher_train_output, semantic_output_teacher, train_output, semantic_embeddings_dict, novel_classes, train_label)
        

        # Backpropagate through semantic model
        
        semantic_loss = semantic_loss_proto + semantic_alignment_loss
        #print(f'node loss: {node_loss} and semantic loss: {semantic_alignment_loss}')
        #semantic_loss = semantic_loss_proto 
        semantic_loss.backward(retain_graph=True)  # Specify retain_graph=True
        optimizer_semantic.step()
        
        loss = 1 * loss_intra + 0.25 * loss_inter + node_loss
        
        #loss = 1 * loss_intra + 0.25 * loss_inter 
        loss.backward()
        optimizer_meta.step()
        

        # Validation phase
        meta_model.eval()  # Set the model to evaluation mode
        test_output = meta_model(task_test_data.x, task_test_data.edge_index)
        test_acc = accuracy_cosine(test_output, task_test_data.y, mean_vectors) * 100
        task_dictionary[i] = test_acc
        # Append metrics to lists
        task_cluster_means[i].append(mean_vectors)
        task_train_losses.append(loss.item())
        task_test_accuracies.append(test_acc)

        print(f'task = {i}, loss = {loss.item():.2f}, loss_semantic = {semantic_loss.item():.2f}, test acc = {test_acc:.2f}%')


    # Return  meta-model, task cluster means and task dictionary
    return  meta_model, semantic_model, task_cluster_means, task_dictionary, task_train_losses, task_test_accuracies

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import time

streaming_seeds = fixed_list
starting_seeds = starting_seeds
semantic_vectors = semantic_embeddings

previous_classes = set()  # Initialize an empty set outside the loop
base_classes_list = []    # Initialize an empty list for base classes
novel_classes_list = []   # Initialize an empty list for novel classes
p = 0

start_time = time.time()  # Record start time
for i in range(10, 43, 3):

    sampled_graph_base, _ = process_incremental_graphs(
        Original_graph,
        num_classes_to_keep = i,
        random_seed = n_seed,
        remaining_classes=base_remaining_classes
    )

    all_classes = get_unique_classes(sampled_graph_base)

    if i == 10 :
        base_classes = list(set(all_classes))
        base_classes_list.extend(all_classes)  # Append base classes to the list
        print(f'Number of Classes (Base) = {i}, Base classes are: {base_classes}')
    else:
        print(f"========================== Streaming session: {p+1} ==========================")
        print(f'Number of Classes (Base + Novel) = {i}')
        novel_classes = list(set(all_classes) - previous_classes)
        novel_classes_list.extend(novel_classes)  # Append novel classes to the list
        print(f'Novel classes are: {novel_classes}')
        stream_seed = streaming_seeds[p]
        start_seed = starting_seeds[p]
        p += 1

        # Print the total novel classes list at each step only for i > 20
        print(f'Base Classes: {base_classes}')
        print(f'Total Novel Classes List: {novel_classes_list}')

        num_classes = i
        num_support = 10
        num_query = 10
        spacing = 50
        num_seeds = 200   #number of episodes in each stream
        ft_lr = 0.001

        context_dictionary_list, task_datasets_eucledian = create_context_and_datasets(sampled_graph_base, num_classes, num_support, num_query, base_classes, novel_classes_list, stream_seed, start_seed, spacing, num_seeds)
        # Train the meta-learning model with regularization
        teacher_model = loaded_model
        teacher_model_semantic = semantic_model_loaded
        current_model, semantic_model_current, cluster_means, task_dictionary, task_train_losses, task_test_accuracies = fine_tune(teacher_model, teacher_model_semantic, novel_classes, loaded_model, semantic_model_loaded, task_datasets_eucledian, ft_lr, weight_decays, context_dictionary_list, semantic_vectors)
        loaded_model = current_model
        loaded_model_semantic = semantic_model_current
        # Find the episode number and corresponding accuracy with the highest accuracy
        best_episode = max(task_dictionary, key=task_dictionary.get)
        best_accuracy = task_dictionary[best_episode]
        
        # Save the model after each streaming session
        model_name = f'streaming_model_{p}.pt'
        torch.save(model.state_dict(), model_name)
        print(f'Model saved as: {model_name}')
        
        
        
        # Print the result
        name = f'streaming_{p}_training_plot'
        plot_performance(task_train_losses, task_test_accuracies,name = name )
        print(f"The best accuracy is {best_accuracy:.2f}% at episode number {best_episode}.")
        name = f'streaming_{p}_cluster_means'
        plot_cluster_means_tsne(consolidate_cluster_means(cluster_means, best_episode), name = name)
       
        plt.close()  # Close the current plot to avoid overlapping with the next iteration
        
        
        
        


    previous_classes = set(all_classes)
    
end_time = time.time()  # Record end time
execution_time = end_time - start_time
print(f"Total execution time: {execution_time} seconds.")
# Out:
# Number of Classes (Base) = 10, Base classes are: [4, 37, 6, 39, 12, 15, 16, 19, 26, 27]
# ========================== Streaming session: 1 ==========================
# Number of Classes (Base + Novel) = 13
# Novel classes are: [9, 13, 25]
# Base Classes: [4, 37, 6, 39, 12, 15, 16, 19, 26, 27]
# Total Novel Classes List: [9, 13, 25]
# task = 0, loss = 10.54, loss_semantic = 0.14, test acc = 37.38%
# task = 1, loss = 10.12, loss_semantic = 3.13, test acc = 48.73%
# task = 2, loss = 10.29, loss_semantic = 1.71, test acc = 54.96%
# task = 3, loss = 10.13, loss_semantic = 1.34, test acc = 53.40%
# task = 4, loss = 10.11, loss_semantic = 1.60, test acc = 57.94%
# task = 5, loss = 10.42, loss_semantic = 1.31, test acc = 50.31%
# task = 6, loss = 10.01, loss_semantic = 0.91, test acc = 48.14%
# task = 7, loss = 10.45, loss_semantic = 0.86, test acc = 40.06%
# task = 8, loss = 10.23, loss_semantic = 0.85, test acc = 49.83%
# task = 9, loss = 10.12, loss_semantic = 0.74, test acc = 52.85%
# task = 10, loss = 10.14, loss_semantic = 0.69, test acc = 55.16%
# task = 11, loss = 10.11, loss_semantic = 0.57, test acc = 56.34%
# task = 12, loss = 10.29, loss_semantic = 0.53, test acc = 55.24%
# task = 13, loss = 10.11, loss_semantic = 0.50, test acc = 55.82%
# task = 14, loss = 10.32, loss_semantic = 0.38, test acc = 52.91%
# task = 15, loss = 10.23, loss_semantic = 0.40, test acc = 55.19%
# task = 16, loss = 10.08, loss_semantic = 0.39, test acc = 60.85%
# task = 17, loss = 10.25, loss_semantic = 0.32, test acc = 55.42%
# task = 18, loss = 9.82, loss_semantic = 0.39, test acc = 61.02%
# task = 19, loss = 9.95, loss_semantic = 0.35, test acc = 62.78%
# task = 20, loss = 10.07, loss_semantic = 0.29, test acc = 60.00%
# task = 21, loss = 10.14, loss_semantic = 0.30, test acc = 58.31%
# task = 22, loss = 9.96, loss_semantic = 0.30, test acc = 64.00%
# task = 23, loss = 10.20, loss_semantic = 0.25, test acc = 64.11%
# task = 24, loss = 10.27, loss_semantic = 0.25, test acc = 68.58%
# task = 25, loss = 9.86, loss_semantic = 0.27, test acc = 65.38%
# task = 26, loss = 10.16, loss_semantic = 0.28, test acc = 62.46%
# task = 27, loss = 9.65, loss_semantic = 0.28, test acc = 62.52%
# task = 28, loss = 10.24, loss_semantic = 0.24, test acc = 66.88%
# task = 29, loss = 10.27, loss_semantic = 0.21, test acc = 61.35%
# task = 30, loss = 9.86, loss_semantic = 0.23, test acc = 59.51%
# task = 31, loss = 9.70, loss_semantic = 0.23, test acc = 65.25%
# task = 32, loss = 10.18, loss_semantic = 0.19, test acc = 60.84%
# task = 33, loss = 9.97, loss_semantic = 0.18, test acc = 61.34%
# task = 34, loss = 10.27, loss_semantic = 0.23, test acc = 63.30%
# task = 35, loss = 10.01, loss_semantic = 0.19, test acc = 63.33%
# task = 36, loss = 9.77, loss_semantic = 0.23, test acc = 63.74%
# task = 37, loss = 9.94, loss_semantic = 0.30, test acc = 54.43%
# task = 38, loss = 9.83, loss_semantic = 0.22, test acc = 60.30%
# task = 39, loss = 9.71, loss_semantic = 0.25, test acc = 63.95%
# task = 40, loss = 10.22, loss_semantic = 0.17, test acc = 63.55%
# task = 41, loss = 10.31, loss_semantic = 0.19, test acc = 58.66%
# task = 42, loss = 9.75, loss_semantic = 0.19, test acc = 58.52%
# task = 43, loss = 10.08, loss_semantic = 0.20, test acc = 53.67%
# task = 44, loss = 9.83, loss_semantic = 0.25, test acc = 58.29%
# task = 45, loss = 10.27, loss_semantic = 0.20, test acc = 55.15%
# task = 46, loss = 9.88, loss_semantic = 0.27, test acc = 63.27%
# task = 47, loss = 9.64, loss_semantic = 0.30, test acc = 66.08%
# task = 48, loss = 10.06, loss_semantic = 0.21, test acc = 58.78%
# task = 49, loss = 10.05, loss_semantic = 0.24, test acc = 59.20%
# task = 50, loss = 10.03, loss_semantic = 0.20, test acc = 61.29%
# task = 51, loss = 10.32, loss_semantic = 0.21, test acc = 60.47%
# task = 52, loss = 10.26, loss_semantic = 0.19, test acc = 62.25%
# task = 53, loss = 9.76, loss_semantic = 0.22, test acc = 59.57%
# task = 54, loss = 9.58, loss_semantic = 0.24, test acc = 55.45%
# task = 55, loss = 9.74, loss_semantic = 0.21, test acc = 57.26%
# task = 56, loss = 10.41, loss_semantic = 0.19, test acc = 58.10%
# task = 57, loss = 9.76, loss_semantic = 0.22, test acc = 64.72%
# task = 58, loss = 9.76, loss_semantic = 0.18, test acc = 59.21%
# task = 59, loss = 9.78, loss_semantic = 0.25, test acc = 63.86%
# task = 60, loss = 10.06, loss_semantic = 0.18, test acc = 61.07%
# task = 61, loss = 9.87, loss_semantic = 0.23, test acc = 64.62%
# task = 62, loss = 9.51, loss_semantic = 0.22, test acc = 59.19%
# task = 63, loss = 9.63, loss_semantic = 0.24, test acc = 60.62%
# task = 64, loss = 9.81, loss_semantic = 0.21, test acc = 60.67%
# task = 65, loss = 9.84, loss_semantic = 0.29, test acc = 59.39%
# task = 66, loss = 9.81, loss_semantic = 0.26, test acc = 60.57%
# task = 67, loss = 10.02, loss_semantic = 0.24, test acc = 60.20%
# task = 68, loss = 9.70, loss_semantic = 0.26, test acc = 60.78%
# task = 69, loss = 9.83, loss_semantic = 0.26, test acc = 61.49%
# task = 70, loss = 9.62, loss_semantic = 0.25, test acc = 51.02%
# task = 71, loss = 10.19, loss_semantic = 0.16, test acc = 61.71%
# task = 72, loss = 10.09, loss_semantic = 0.19, test acc = 56.79%
# task = 73, loss = 9.87, loss_semantic = 0.22, test acc = 63.94%
# task = 74, loss = 10.10, loss_semantic = 0.21, test acc = 59.00%
# task = 75, loss = 9.58, loss_semantic = 0.29, test acc = 53.38%
# task = 76, loss = 9.95, loss_semantic = 0.19, test acc = 62.75%
# task = 77, loss = 10.27, loss_semantic = 0.20, test acc = 64.58%
# task = 78, loss = 9.69, loss_semantic = 0.24, test acc = 57.37%
# task = 79, loss = 9.72, loss_semantic = 0.20, test acc = 59.60%
# task = 80, loss = 9.53, loss_semantic = 0.20, test acc = 61.29%
# task = 81, loss = 9.63, loss_semantic = 0.21, test acc = 57.89%
# task = 82, loss = 9.75, loss_semantic = 0.20, test acc = 55.71%
# task = 83, loss = 9.68, loss_semantic = 0.23, test acc = 57.92%
# task = 84, loss = 9.80, loss_semantic = 0.21, test acc = 55.37%
# task = 85, loss = 9.69, loss_semantic = 0.26, test acc = 54.29%
# task = 86, loss = 9.59, loss_semantic = 0.21, test acc = 57.37%
# task = 87, loss = 9.69, loss_semantic = 0.23, test acc = 58.30%
# task = 88, loss = 10.22, loss_semantic = 0.17, test acc = 63.36%
# task = 89, loss = 10.12, loss_semantic = 0.21, test acc = 64.72%
# task = 90, loss = 9.62, loss_semantic = 0.20, test acc = 63.93%
# task = 91, loss = 9.70, loss_semantic = 0.25, test acc = 63.89%
# task = 92, loss = 9.79, loss_semantic = 0.21, test acc = 61.65%
# task = 93, loss = 9.78, loss_semantic = 0.28, test acc = 59.90%
# task = 94, loss = 9.69, loss_semantic = 0.23, test acc = 59.14%
# task = 95, loss = 10.08, loss_semantic = 0.25, test acc = 54.26%
# task = 96, loss = 9.83, loss_semantic = 0.21, test acc = 59.01%
# task = 97, loss = 9.52, loss_semantic = 0.31, test acc = 63.75%
# task = 98, loss = 9.85, loss_semantic = 0.24, test acc = 61.15%
# task = 99, loss = 9.78, loss_semantic = 0.31, test acc = 55.65%
# task = 100, loss = 9.72, loss_semantic = 0.27, test acc = 60.38%
# task = 101, loss = 9.53, loss_semantic = 0.26, test acc = 51.57%
# task = 102, loss = 9.86, loss_semantic = 0.24, test acc = 56.94%
# task = 103, loss = 10.00, loss_semantic = 0.23, test acc = 56.36%
# task = 104, loss = 9.59, loss_semantic = 0.25, test acc = 58.74%
# task = 105, loss = 9.59, loss_semantic = 0.20, test acc = 59.61%
# task = 106, loss = 9.57, loss_semantic = 0.23, test acc = 61.36%
# task = 107, loss = 9.99, loss_semantic = 0.17, test acc = 62.57%
# task = 108, loss = 9.77, loss_semantic = 0.22, test acc = 62.50%
# task = 109, loss = 10.06, loss_semantic = 0.20, test acc = 59.64%
# task = 110, loss = 10.06, loss_semantic = 0.24, test acc = 63.88%
# task = 111, loss = 9.91, loss_semantic = 0.23, test acc = 60.67%
# task = 112, loss = 9.55, loss_semantic = 0.26, test acc = 58.36%
# task = 113, loss = 9.80, loss_semantic = 0.21, test acc = 58.28%
# task = 114, loss = 9.91, loss_semantic = 0.19, test acc = 58.52%
# task = 115, loss = 9.79, loss_semantic = 0.21, test acc = 59.00%
# task = 116, loss = 9.71, loss_semantic = 0.24, test acc = 62.64%
# task = 117, loss = 9.72, loss_semantic = 0.25, test acc = 61.84%
# task = 118, loss = 10.03, loss_semantic = 0.16, test acc = 56.45%
# task = 119, loss = 9.72, loss_semantic = 0.29, test acc = 55.84%
# task = 120, loss = 9.61, loss_semantic = 0.20, test acc = 61.63%
# task = 121, loss = 9.90, loss_semantic = 0.25, test acc = 61.80%
# task = 122, loss = 9.97, loss_semantic = 0.18, test acc = 57.19%
# task = 123, loss = 9.91, loss_semantic = 0.28, test acc = 58.78%
# task = 124, loss = 9.81, loss_semantic = 0.27, test acc = 56.98%
# task = 125, loss = 9.87, loss_semantic = 0.25, test acc = 57.47%
# task = 126, loss = 9.77, loss_semantic = 0.25, test acc = 59.35%
# task = 127, loss = 9.78, loss_semantic = 0.26, test acc = 60.99%
# task = 128, loss = 9.70, loss_semantic = 0.24, test acc = 58.99%
# task = 129, loss = 10.00, loss_semantic = 0.20, test acc = 58.35%
# task = 130, loss = 9.81, loss_semantic = 0.24, test acc = 61.12%
# task = 131, loss = 10.06, loss_semantic = 0.19, test acc = 60.53%
# task = 132, loss = 9.48, loss_semantic = 0.32, test acc = 59.63%
# task = 133, loss = 9.70, loss_semantic = 0.23, test acc = 63.23%
# task = 134, loss = 10.10, loss_semantic = 0.27, test acc = 65.02%
# task = 135, loss = 9.71, loss_semantic = 0.24, test acc = 60.00%
# task = 136, loss = 9.78, loss_semantic = 0.28, test acc = 61.68%
# task = 137, loss = 9.81, loss_semantic = 0.26, test acc = 63.01%
# task = 138, loss = 9.95, loss_semantic = 0.28, test acc = 63.04%
# task = 139, loss = 9.83, loss_semantic = 0.20, test acc = 61.93%
# task = 140, loss = 9.96, loss_semantic = 0.27, test acc = 62.12%
# task = 141, loss = 10.01, loss_semantic = 0.19, test acc = 58.84%
# task = 142, loss = 10.10, loss_semantic = 0.21, test acc = 54.91%
# task = 143, loss = 10.10, loss_semantic = 0.20, test acc = 58.25%
# task = 144, loss = 9.75, loss_semantic = 0.21, test acc = 53.61%
# task = 145, loss = 9.59, loss_semantic = 0.29, test acc = 59.94%
# task = 146, loss = 10.14, loss_semantic = 0.20, test acc = 61.38%
# task = 147, loss = 9.91, loss_semantic = 0.25, test acc = 60.56%
# task = 148, loss = 10.26, loss_semantic = 0.19, test acc = 57.94%
# task = 149, loss = 9.65, loss_semantic = 0.26, test acc = 59.11%
# task = 150, loss = 10.01, loss_semantic = 0.24, test acc = 59.34%
# task = 151, loss = 9.99, loss_semantic = 0.25, test acc = 66.35%
# task = 152, loss = 9.99, loss_semantic = 0.19, test acc = 65.39%
# task = 153, loss = 9.91, loss_semantic = 0.23, test acc = 62.66%
# task = 154, loss = 9.96, loss_semantic = 0.26, test acc = 63.82%
# task = 155, loss = 9.63, loss_semantic = 0.27, test acc = 59.57%
# task = 156, loss = 9.56, loss_semantic = 0.26, test acc = 65.66%
# task = 157, loss = 9.65, loss_semantic = 0.27, test acc = 60.09%
# task = 158, loss = 9.96, loss_semantic = 0.22, test acc = 58.71%
# task = 159, loss = 9.67, loss_semantic = 0.22, test acc = 63.40%
# task = 160, loss = 9.66, loss_semantic = 0.23, test acc = 58.80%
# task = 161, loss = 9.70, loss_semantic = 0.24, test acc = 62.19%
# task = 162, loss = 9.81, loss_semantic = 0.21, test acc = 61.59%
# task = 163, loss = 9.93, loss_semantic = 0.18, test acc = 63.24%
# task = 164, loss = 9.77, loss_semantic = 0.19, test acc = 62.40%
# task = 165, loss = 10.02, loss_semantic = 0.18, test acc = 63.48%
# task = 166, loss = 9.50, loss_semantic = 0.24, test acc = 56.81%
# task = 167, loss = 9.82, loss_semantic = 0.22, test acc = 60.69%
# task = 168, loss = 10.06, loss_semantic = 0.21, test acc = 61.43%
# task = 169, loss = 9.54, loss_semantic = 0.26, test acc = 56.18%
# task = 170, loss = 10.14, loss_semantic = 0.20, test acc = 63.14%
# task = 171, loss = 10.10, loss_semantic = 0.22, test acc = 60.11%
# task = 172, loss = 9.78, loss_semantic = 0.24, test acc = 61.55%
# task = 173, loss = 9.46, loss_semantic = 0.23, test acc = 66.82%
# task = 174, loss = 10.20, loss_semantic = 0.17, test acc = 63.75%
# task = 175, loss = 9.81, loss_semantic = 0.21, test acc = 62.12%
# task = 176, loss = 9.72, loss_semantic = 0.23, test acc = 62.56%
# task = 177, loss = 9.92, loss_semantic = 0.19, test acc = 61.38%
# task = 178, loss = 10.03, loss_semantic = 0.22, test acc = 56.55%
# task = 179, loss = 9.86, loss_semantic = 0.24, test acc = 59.76%
# task = 180, loss = 9.87, loss_semantic = 0.19, test acc = 58.43%
# task = 181, loss = 9.80, loss_semantic = 0.21, test acc = 65.52%
# task = 182, loss = 9.79, loss_semantic = 0.22, test acc = 56.27%
# task = 183, loss = 9.88, loss_semantic = 0.23, test acc = 59.77%
# task = 184, loss = 10.03, loss_semantic = 0.17, test acc = 63.06%
# task = 185, loss = 10.01, loss_semantic = 0.26, test acc = 61.05%
# task = 186, loss = 9.98, loss_semantic = 0.19, test acc = 58.68%
# task = 187, loss = 9.57, loss_semantic = 0.30, test acc = 59.75%
# task = 188, loss = 9.66, loss_semantic = 0.25, test acc = 59.14%
# task = 189, loss = 9.66, loss_semantic = 0.30, test acc = 62.56%
# task = 190, loss = 10.20, loss_semantic = 0.21, test acc = 61.38%
# task = 191, loss = 9.68, loss_semantic = 0.24, test acc = 61.15%
# task = 192, loss = 9.59, loss_semantic = 0.29, test acc = 58.75%
# task = 193, loss = 9.96, loss_semantic = 0.19, test acc = 64.22%
# task = 194, loss = 9.66, loss_semantic = 0.26, test acc = 60.81%
# task = 195, loss = 9.71, loss_semantic = 0.27, test acc = 62.56%
# task = 196, loss = 9.93, loss_semantic = 0.23, test acc = 54.82%
# task = 197, loss = 9.40, loss_semantic = 0.29, test acc = 57.83%
# task = 198, loss = 9.66, loss_semantic = 0.24, test acc = 55.77%
# task = 199, loss = 9.72, loss_semantic = 0.23, test acc = 56.91%
# Model saved as: streaming_model_1.pt
# The best accuracy is 68.58% at episode number 24.
# ========================== Streaming session: 2 ==========================
# Number of Classes (Base + Novel) = 16
# Novel classes are: [8, 34, 31]
# Base Classes: [4, 37, 6, 39, 12, 15, 16, 19, 26, 27]
# Total Novel Classes List: [9, 13, 25, 8, 34, 31]
# task = 0, loss = 12.86, loss_semantic = 0.33, test acc = 50.42%
# task = 1, loss = 12.86, loss_semantic = 3.83, test acc = 47.16%
# task = 2, loss = 12.57, loss_semantic = 2.49, test acc = 35.82%
# task = 3, loss = 12.83, loss_semantic = 1.62, test acc = 39.73%
# task = 4, loss = 12.78, loss_semantic = 1.73, test acc = 41.85%
# task = 5, loss = 12.56, loss_semantic = 1.48, test acc = 44.71%
# task = 6, loss = 12.39, loss_semantic = 1.25, test acc = 48.48%
# task = 7, loss = 12.85, loss_semantic = 1.13, test acc = 49.61%
# task = 8, loss = 12.79, loss_semantic = 0.84, test acc = 35.02%
# task = 9, loss = 12.58, loss_semantic = 0.74, test acc = 50.00%
# task = 10, loss = 12.73, loss_semantic = 0.62, test acc = 51.22%
# task = 11, loss = 12.45, loss_semantic = 0.52, test acc = 53.33%
# task = 12, loss = 12.51, loss_semantic = 0.43, test acc = 51.22%
# task = 13, loss = 12.48, loss_semantic = 0.44, test acc = 50.06%
# task = 14, loss = 12.27, loss_semantic = 0.44, test acc = 51.89%
# task = 15, loss = 12.41, loss_semantic = 0.33, test acc = 48.44%
# task = 16, loss = 12.57, loss_semantic = 0.35, test acc = 49.04%
# task = 17, loss = 12.40, loss_semantic = 0.35, test acc = 50.79%
# task = 18, loss = 12.64, loss_semantic = 0.31, test acc = 46.00%
# task = 19, loss = 12.36, loss_semantic = 0.32, test acc = 50.95%
# task = 20, loss = 12.96, loss_semantic = 0.28, test acc = 43.79%
# task = 21, loss = 12.57, loss_semantic = 0.30, test acc = 52.09%
# task = 22, loss = 12.40, loss_semantic = 0.30, test acc = 51.12%
# task = 23, loss = 12.59, loss_semantic = 0.33, test acc = 49.03%
# task = 24, loss = 12.48, loss_semantic = 0.31, test acc = 55.82%
# task = 25, loss = 12.14, loss_semantic = 0.31, test acc = 55.03%
# task = 26, loss = 12.14, loss_semantic = 0.26, test acc = 52.89%
# task = 27, loss = 12.18, loss_semantic = 0.25, test acc = 49.77%
# task = 28, loss = 12.06, loss_semantic = 0.36, test acc = 52.40%
# task = 29, loss = 11.95, loss_semantic = 0.33, test acc = 50.69%
# task = 30, loss = 12.33, loss_semantic = 0.27, test acc = 49.88%
# task = 31, loss = 12.06, loss_semantic = 0.33, test acc = 49.15%
# task = 32, loss = 12.68, loss_semantic = 0.22, test acc = 49.16%
# task = 33, loss = 12.58, loss_semantic = 0.29, test acc = 42.31%
# task = 34, loss = 12.31, loss_semantic = 0.27, test acc = 46.77%
# task = 35, loss = 12.22, loss_semantic = 0.28, test acc = 51.45%
# task = 36, loss = 11.92, loss_semantic = 0.30, test acc = 46.96%
# task = 37, loss = 12.41, loss_semantic = 0.24, test acc = 47.44%
# task = 38, loss = 12.32, loss_semantic = 0.23, test acc = 54.52%
# task = 39, loss = 12.48, loss_semantic = 0.26, test acc = 50.91%
# task = 40, loss = 12.21, loss_semantic = 0.26, test acc = 47.26%
# task = 41, loss = 12.49, loss_semantic = 0.27, test acc = 54.22%
# task = 42, loss = 11.88, loss_semantic = 0.29, test acc = 49.48%
# task = 43, loss = 12.32, loss_semantic = 0.27, test acc = 55.63%
# task = 44, loss = 12.42, loss_semantic = 0.28, test acc = 50.71%
# task = 45, loss = 11.91, loss_semantic = 0.28, test acc = 52.18%
# task = 46, loss = 12.49, loss_semantic = 0.26, test acc = 49.39%
# task = 47, loss = 12.24, loss_semantic = 0.28, test acc = 51.72%
# task = 48, loss = 11.79, loss_semantic = 0.32, test acc = 50.97%
# task = 49, loss = 12.47, loss_semantic = 0.27, test acc = 48.09%
# task = 50, loss = 11.72, loss_semantic = 0.32, test acc = 53.26%
# task = 51, loss = 12.16, loss_semantic = 0.30, test acc = 45.66%
# task = 52, loss = 12.20, loss_semantic = 0.27, test acc = 48.39%
# task = 53, loss = 12.24, loss_semantic = 0.24, test acc = 48.78%
# task = 54, loss = 12.39, loss_semantic = 0.28, test acc = 51.20%
# task = 55, loss = 12.20, loss_semantic = 0.23, test acc = 47.64%
# task = 56, loss = 12.53, loss_semantic = 0.23, test acc = 54.87%
# task = 57, loss = 12.08, loss_semantic = 0.25, test acc = 54.92%
# task = 58, loss = 12.07, loss_semantic = 0.31, test acc = 52.22%
# task = 59, loss = 12.00, loss_semantic = 0.31, test acc = 50.62%
# task = 60, loss = 12.18, loss_semantic = 0.26, test acc = 50.98%
# task = 61, loss = 12.21, loss_semantic = 0.28, test acc = 55.50%
# task = 62, loss = 11.70, loss_semantic = 0.35, test acc = 50.92%
# task = 63, loss = 12.11, loss_semantic = 0.26, test acc = 51.79%
# task = 64, loss = 12.15, loss_semantic = 0.31, test acc = 47.94%
# task = 65, loss = 12.12, loss_semantic = 0.22, test acc = 53.06%
# task = 66, loss = 12.12, loss_semantic = 0.31, test acc = 54.29%
# task = 67, loss = 12.36, loss_semantic = 0.23, test acc = 52.12%
# task = 68, loss = 11.83, loss_semantic = 0.34, test acc = 54.64%
# task = 69, loss = 12.14, loss_semantic = 0.24, test acc = 47.42%
# task = 70, loss = 12.13, loss_semantic = 0.33, test acc = 44.83%
# task = 71, loss = 12.14, loss_semantic = 0.30, test acc = 50.00%
# task = 72, loss = 11.77, loss_semantic = 0.35, test acc = 51.78%
# task = 73, loss = 12.15, loss_semantic = 0.32, test acc = 47.17%
# task = 74, loss = 11.89, loss_semantic = 0.29, test acc = 55.26%
# task = 75, loss = 12.32, loss_semantic = 0.25, test acc = 52.57%
# task = 76, loss = 11.83, loss_semantic = 0.29, test acc = 54.29%
# task = 77, loss = 12.16, loss_semantic = 0.26, test acc = 53.69%
# task = 78, loss = 11.95, loss_semantic = 0.31, test acc = 51.53%
# task = 79, loss = 11.87, loss_semantic = 0.36, test acc = 55.57%
# task = 80, loss = 11.79, loss_semantic = 0.32, test acc = 55.08%
# task = 81, loss = 11.79, loss_semantic = 0.31, test acc = 52.65%
# task = 82, loss = 12.20, loss_semantic = 0.24, test acc = 54.53%
# task = 83, loss = 12.01, loss_semantic = 0.23, test acc = 46.52%
# task = 84, loss = 12.02, loss_semantic = 0.26, test acc = 50.00%
# task = 85, loss = 11.63, loss_semantic = 0.27, test acc = 50.62%
# task = 86, loss = 12.23, loss_semantic = 0.26, test acc = 51.93%
# task = 87, loss = 11.81, loss_semantic = 0.30, test acc = 48.56%
# task = 88, loss = 12.12, loss_semantic = 0.23, test acc = 52.76%
# task = 89, loss = 12.17, loss_semantic = 0.27, test acc = 54.56%
# task = 90, loss = 12.21, loss_semantic = 0.18, test acc = 49.60%
# task = 91, loss = 12.05, loss_semantic = 0.27, test acc = 51.49%
# task = 92, loss = 12.15, loss_semantic = 0.22, test acc = 48.52%
# task = 93, loss = 11.98, loss_semantic = 0.31, test acc = 50.18%
# task = 94, loss = 11.87, loss_semantic = 0.31, test acc = 51.29%
# task = 95, loss = 11.90, loss_semantic = 0.30, test acc = 54.35%
# task = 96, loss = 12.03, loss_semantic = 0.25, test acc = 50.54%
# task = 97, loss = 11.91, loss_semantic = 0.27, test acc = 45.95%
# task = 98, loss = 11.90, loss_semantic = 0.30, test acc = 49.65%
# task = 99, loss = 12.02, loss_semantic = 0.23, test acc = 49.35%
# task = 100, loss = 12.20, loss_semantic = 0.24, test acc = 46.50%
# task = 101, loss = 11.82, loss_semantic = 0.32, test acc = 53.65%
# task = 102, loss = 12.15, loss_semantic = 0.27, test acc = 55.50%
# task = 103, loss = 11.64, loss_semantic = 0.30, test acc = 57.85%
# task = 104, loss = 11.87, loss_semantic = 0.26, test acc = 58.98%
# task = 105, loss = 11.69, loss_semantic = 0.31, test acc = 55.32%
# task = 106, loss = 12.13, loss_semantic = 0.21, test acc = 52.56%
# task = 107, loss = 11.71, loss_semantic = 0.32, test acc = 55.80%
# task = 108, loss = 12.35, loss_semantic = 0.23, test acc = 50.35%
# task = 109, loss = 11.94, loss_semantic = 0.30, test acc = 50.90%
# task = 110, loss = 11.85, loss_semantic = 0.25, test acc = 52.47%
# task = 111, loss = 11.79, loss_semantic = 0.34, test acc = 49.69%
# task = 112, loss = 11.44, loss_semantic = 0.31, test acc = 54.86%
# task = 113, loss = 11.98, loss_semantic = 0.29, test acc = 52.63%
# task = 114, loss = 11.93, loss_semantic = 0.28, test acc = 54.19%
# task = 115, loss = 11.76, loss_semantic = 0.31, test acc = 51.81%
# task = 116, loss = 11.85, loss_semantic = 0.38, test acc = 53.23%
# task = 117, loss = 11.79, loss_semantic = 0.30, test acc = 50.12%
# task = 118, loss = 11.79, loss_semantic = 0.35, test acc = 53.13%
# task = 119, loss = 11.95, loss_semantic = 0.32, test acc = 50.90%
# task = 120, loss = 11.85, loss_semantic = 0.31, test acc = 49.63%
# task = 121, loss = 12.17, loss_semantic = 0.24, test acc = 51.84%
# task = 122, loss = 11.88, loss_semantic = 0.26, test acc = 53.81%
# task = 123, loss = 11.72, loss_semantic = 0.26, test acc = 53.65%
# task = 124, loss = 12.13, loss_semantic = 0.23, test acc = 55.56%
# task = 125, loss = 11.80, loss_semantic = 0.26, test acc = 56.73%
# task = 126, loss = 12.05, loss_semantic = 0.27, test acc = 50.37%
# task = 127, loss = 11.79, loss_semantic = 0.30, test acc = 49.46%
# task = 128, loss = 12.02, loss_semantic = 0.28, test acc = 51.05%
# task = 129, loss = 11.72, loss_semantic = 0.33, test acc = 46.78%
# task = 130, loss = 11.90, loss_semantic = 0.30, test acc = 51.87%
# task = 131, loss = 11.71, loss_semantic = 0.32, test acc = 52.58%
# task = 132, loss = 11.71, loss_semantic = 0.32, test acc = 52.39%
# task = 133, loss = 11.84, loss_semantic = 0.30, test acc = 49.81%
# task = 134, loss = 11.70, loss_semantic = 0.29, test acc = 54.24%
# task = 135, loss = 11.90, loss_semantic = 0.23, test acc = 59.33%
# task = 136, loss = 11.91, loss_semantic = 0.26, test acc = 55.72%
# task = 137, loss = 11.98, loss_semantic = 0.23, test acc = 50.00%
# task = 138, loss = 11.82, loss_semantic = 0.21, test acc = 55.09%
# task = 139, loss = 11.99, loss_semantic = 0.22, test acc = 47.86%
# task = 140, loss = 11.90, loss_semantic = 0.21, test acc = 53.64%
# task = 141, loss = 11.56, loss_semantic = 0.35, test acc = 52.69%
# task = 142, loss = 12.06, loss_semantic = 0.26, test acc = 54.23%
# task = 143, loss = 11.68, loss_semantic = 0.36, test acc = 48.25%
# task = 144, loss = 12.06, loss_semantic = 0.23, test acc = 54.87%
# task = 145, loss = 11.93, loss_semantic = 0.37, test acc = 53.07%
# task = 146, loss = 11.61, loss_semantic = 0.26, test acc = 59.33%
# task = 147, loss = 11.84, loss_semantic = 0.32, test acc = 53.50%
# task = 148, loss = 12.00, loss_semantic = 0.22, test acc = 54.09%
# task = 149, loss = 11.70, loss_semantic = 0.36, test acc = 53.87%
# task = 150, loss = 11.63, loss_semantic = 0.33, test acc = 51.93%
# task = 151, loss = 11.86, loss_semantic = 0.32, test acc = 53.90%
# task = 152, loss = 11.51, loss_semantic = 0.32, test acc = 50.52%
# task = 153, loss = 11.68, loss_semantic = 0.33, test acc = 53.79%
# task = 154, loss = 11.83, loss_semantic = 0.32, test acc = 52.02%
# task = 155, loss = 11.92, loss_semantic = 0.31, test acc = 52.54%
# task = 156, loss = 11.97, loss_semantic = 0.26, test acc = 50.51%
# task = 157, loss = 11.77, loss_semantic = 0.30, test acc = 54.89%
# task = 158, loss = 11.78, loss_semantic = 0.29, test acc = 56.15%
# task = 159, loss = 11.92, loss_semantic = 0.28, test acc = 50.43%
# task = 160, loss = 11.46, loss_semantic = 0.32, test acc = 52.69%
# task = 161, loss = 12.12, loss_semantic = 0.26, test acc = 55.24%
# task = 162, loss = 11.99, loss_semantic = 0.24, test acc = 57.49%
# task = 163, loss = 11.63, loss_semantic = 0.30, test acc = 51.73%
# task = 164, loss = 12.11, loss_semantic = 0.23, test acc = 58.52%
# task = 165, loss = 11.90, loss_semantic = 0.33, test acc = 51.50%
# task = 166, loss = 11.96, loss_semantic = 0.28, test acc = 56.62%
# task = 167, loss = 11.74, loss_semantic = 0.34, test acc = 54.87%
# task = 168, loss = 11.68, loss_semantic = 0.28, test acc = 53.88%
# task = 169, loss = 11.63, loss_semantic = 0.34, test acc = 52.36%
# task = 170, loss = 11.72, loss_semantic = 0.25, test acc = 56.21%
# task = 171, loss = 11.86, loss_semantic = 0.30, test acc = 56.42%
# task = 172, loss = 11.67, loss_semantic = 0.34, test acc = 54.79%
# task = 173, loss = 11.64, loss_semantic = 0.27, test acc = 53.08%
# task = 174, loss = 11.65, loss_semantic = 0.31, test acc = 51.32%
# task = 175, loss = 11.86, loss_semantic = 0.24, test acc = 49.58%
# task = 176, loss = 11.88, loss_semantic = 0.27, test acc = 52.81%
# task = 177, loss = 11.83, loss_semantic = 0.26, test acc = 56.43%
# task = 178, loss = 11.64, loss_semantic = 0.32, test acc = 54.76%
# task = 179, loss = 12.09, loss_semantic = 0.21, test acc = 54.69%
# task = 180, loss = 11.98, loss_semantic = 0.27, test acc = 54.17%
# task = 181, loss = 11.72, loss_semantic = 0.30, test acc = 57.09%
# task = 182, loss = 12.10, loss_semantic = 0.26, test acc = 57.43%
# task = 183, loss = 11.42, loss_semantic = 0.32, test acc = 54.45%
# task = 184, loss = 11.85, loss_semantic = 0.25, test acc = 51.25%
# task = 185, loss = 11.39, loss_semantic = 0.34, test acc = 54.33%
# task = 186, loss = 11.97, loss_semantic = 0.23, test acc = 52.21%
# task = 187, loss = 11.68, loss_semantic = 0.33, test acc = 51.01%
# task = 188, loss = 11.86, loss_semantic = 0.24, test acc = 57.54%
# task = 189, loss = 11.72, loss_semantic = 0.25, test acc = 51.59%
# task = 190, loss = 11.63, loss_semantic = 0.29, test acc = 54.09%
# task = 191, loss = 11.85, loss_semantic = 0.25, test acc = 49.61%
# task = 192, loss = 11.92, loss_semantic = 0.31, test acc = 49.45%
# task = 193, loss = 11.64, loss_semantic = 0.31, test acc = 53.65%
# task = 194, loss = 11.60, loss_semantic = 0.29, test acc = 54.65%
# task = 195, loss = 11.97, loss_semantic = 0.23, test acc = 52.28%
# task = 196, loss = 12.24, loss_semantic = 0.22, test acc = 54.76%
# task = 197, loss = 11.96, loss_semantic = 0.23, test acc = 51.80%
# task = 198, loss = 11.75, loss_semantic = 0.25, test acc = 57.54%
# task = 199, loss = 11.63, loss_semantic = 0.31, test acc = 55.53%
# Model saved as: streaming_model_2.pt
# The best accuracy is 59.33% at episode number 135.
# ========================== Streaming session: 3 ==========================
# Number of Classes (Base + Novel) = 19
# Novel classes are: [0, 17, 24]
# Base Classes: [4, 37, 6, 39, 12, 15, 16, 19, 26, 27]
# Total Novel Classes List: [9, 13, 25, 8, 34, 31, 0, 17, 24]
# task = 0, loss = 15.54, loss_semantic = 0.42, test acc = 35.75%
# task = 1, loss = 15.45, loss_semantic = 4.55, test acc = 42.00%
# task = 2, loss = 15.23, loss_semantic = 2.71, test acc = 44.34%
# task = 3, loss = 15.19, loss_semantic = 1.79, test acc = 45.70%
# task = 4, loss = 15.16, loss_semantic = 2.15, test acc = 41.89%
# task = 5, loss = 15.49, loss_semantic = 1.92, test acc = 45.18%
# task = 6, loss = 15.35, loss_semantic = 1.48, test acc = 37.52%
# task = 7, loss = 15.04, loss_semantic = 1.28, test acc = 41.19%
# task = 8, loss = 15.02, loss_semantic = 0.94, test acc = 44.98%
# task = 9, loss = 14.80, loss_semantic = 0.87, test acc = 44.10%
# task = 10, loss = 15.36, loss_semantic = 0.71, test acc = 41.61%
# task = 11, loss = 14.58, loss_semantic = 0.59, test acc = 42.67%
# task = 12, loss = 15.09, loss_semantic = 0.50, test acc = 44.78%
# task = 13, loss = 14.86, loss_semantic = 0.47, test acc = 44.61%
# task = 14, loss = 15.01, loss_semantic = 0.52, test acc = 42.98%
# task = 15, loss = 14.97, loss_semantic = 0.43, test acc = 42.03%
# task = 16, loss = 14.62, loss_semantic = 0.47, test acc = 43.42%
# task = 17, loss = 14.95, loss_semantic = 0.38, test acc = 43.75%
# task = 18, loss = 14.77, loss_semantic = 0.45, test acc = 45.84%
# task = 19, loss = 14.58, loss_semantic = 0.37, test acc = 48.09%
# task = 20, loss = 14.63, loss_semantic = 0.40, test acc = 46.29%
# task = 21, loss = 14.74, loss_semantic = 0.42, test acc = 42.91%
# task = 22, loss = 14.50, loss_semantic = 0.37, test acc = 49.68%
# task = 23, loss = 14.72, loss_semantic = 0.35, test acc = 46.22%
# task = 24, loss = 14.52, loss_semantic = 0.37, test acc = 47.26%
# task = 25, loss = 14.83, loss_semantic = 0.32, test acc = 47.72%
# task = 26, loss = 14.77, loss_semantic = 0.31, test acc = 43.88%
# task = 27, loss = 14.53, loss_semantic = 0.36, test acc = 42.36%
# task = 28, loss = 14.82, loss_semantic = 0.34, test acc = 45.95%
# task = 29, loss = 14.62, loss_semantic = 0.33, test acc = 44.27%
# task = 30, loss = 14.70, loss_semantic = 0.38, test acc = 45.14%
# task = 31, loss = 14.49, loss_semantic = 0.35, test acc = 37.05%
# task = 32, loss = 14.55, loss_semantic = 0.32, test acc = 39.93%
# task = 33, loss = 14.55, loss_semantic = 0.28, test acc = 37.49%
# task = 34, loss = 14.41, loss_semantic = 0.34, test acc = 42.35%
# task = 35, loss = 14.69, loss_semantic = 0.26, test acc = 42.05%
# task = 36, loss = 14.58, loss_semantic = 0.33, test acc = 43.73%
# task = 37, loss = 14.26, loss_semantic = 0.28, test acc = 44.82%
# task = 38, loss = 14.39, loss_semantic = 0.32, test acc = 42.99%
# task = 39, loss = 14.38, loss_semantic = 0.26, test acc = 40.33%
# task = 40, loss = 14.56, loss_semantic = 0.31, test acc = 46.35%
# task = 41, loss = 14.53, loss_semantic = 0.32, test acc = 44.17%
# task = 42, loss = 14.42, loss_semantic = 0.41, test acc = 42.40%
# task = 43, loss = 14.69, loss_semantic = 0.33, test acc = 44.44%
# task = 44, loss = 14.41, loss_semantic = 0.39, test acc = 44.56%
# task = 45, loss = 14.40, loss_semantic = 0.39, test acc = 44.05%
# task = 46, loss = 14.29, loss_semantic = 0.44, test acc = 45.34%
# task = 47, loss = 14.41, loss_semantic = 0.36, test acc = 44.56%
# task = 48, loss = 14.46, loss_semantic = 0.35, test acc = 46.15%
# task = 49, loss = 14.46, loss_semantic = 0.31, test acc = 49.15%
# task = 50, loss = 14.45, loss_semantic = 0.32, test acc = 44.91%
# task = 51, loss = 14.33, loss_semantic = 0.36, test acc = 44.24%
# task = 52, loss = 14.36, loss_semantic = 0.34, test acc = 44.44%
# task = 53, loss = 14.55, loss_semantic = 0.35, test acc = 48.68%
# task = 54, loss = 14.67, loss_semantic = 0.35, test acc = 37.17%
# task = 55, loss = 14.70, loss_semantic = 0.30, test acc = 45.00%
# task = 56, loss = 14.45, loss_semantic = 0.29, test acc = 44.15%
# task = 57, loss = 14.23, loss_semantic = 0.32, test acc = 44.76%
# task = 58, loss = 14.28, loss_semantic = 0.30, test acc = 45.28%
# task = 59, loss = 14.33, loss_semantic = 0.28, test acc = 42.65%
# task = 60, loss = 14.36, loss_semantic = 0.27, test acc = 44.77%
# task = 61, loss = 14.89, loss_semantic = 0.32, test acc = 40.66%
# task = 62, loss = 14.05, loss_semantic = 0.38, test acc = 42.27%
# task = 63, loss = 14.82, loss_semantic = 0.30, test acc = 43.14%
# task = 64, loss = 14.16, loss_semantic = 0.39, test acc = 44.22%
# task = 65, loss = 14.03, loss_semantic = 0.36, test acc = 44.04%
# task = 66, loss = 14.28, loss_semantic = 0.37, test acc = 45.07%
# task = 67, loss = 14.34, loss_semantic = 0.32, test acc = 45.19%
# task = 68, loss = 14.50, loss_semantic = 0.29, test acc = 47.52%
# task = 69, loss = 14.25, loss_semantic = 0.32, test acc = 46.50%
# task = 70, loss = 14.45, loss_semantic = 0.27, test acc = 41.89%
# task = 71, loss = 14.51, loss_semantic = 0.32, test acc = 44.54%
# task = 72, loss = 14.32, loss_semantic = 0.28, test acc = 40.34%
# task = 73, loss = 14.31, loss_semantic = 0.26, test acc = 46.33%
# task = 74, loss = 14.24, loss_semantic = 0.26, test acc = 44.78%
# task = 75, loss = 14.51, loss_semantic = 0.26, test acc = 42.39%
# task = 76, loss = 14.08, loss_semantic = 0.34, test acc = 46.91%
# task = 77, loss = 14.20, loss_semantic = 0.36, test acc = 44.72%
# task = 78, loss = 14.43, loss_semantic = 0.34, test acc = 45.92%
# task = 79, loss = 14.54, loss_semantic = 0.30, test acc = 46.70%
# task = 80, loss = 14.41, loss_semantic = 0.30, test acc = 42.07%
# task = 81, loss = 14.14, loss_semantic = 0.34, test acc = 42.54%
# task = 82, loss = 14.42, loss_semantic = 0.28, test acc = 43.74%
# task = 83, loss = 13.99, loss_semantic = 0.31, test acc = 43.49%
# task = 84, loss = 14.44, loss_semantic = 0.25, test acc = 43.04%
# task = 85, loss = 14.54, loss_semantic = 0.29, test acc = 47.54%
# task = 86, loss = 14.20, loss_semantic = 0.27, test acc = 41.46%
# task = 87, loss = 14.33, loss_semantic = 0.25, test acc = 44.76%
# task = 88, loss = 14.63, loss_semantic = 0.27, test acc = 39.82%
# task = 89, loss = 14.36, loss_semantic = 0.27, test acc = 43.70%
# task = 90, loss = 14.22, loss_semantic = 0.34, test acc = 41.71%
# task = 91, loss = 14.32, loss_semantic = 0.28, test acc = 42.59%
# task = 92, loss = 13.93, loss_semantic = 0.33, test acc = 46.36%
# task = 93, loss = 14.28, loss_semantic = 0.30, test acc = 40.74%
# task = 94, loss = 14.31, loss_semantic = 0.33, test acc = 43.77%
# task = 95, loss = 14.62, loss_semantic = 0.31, test acc = 43.51%
# task = 96, loss = 13.98, loss_semantic = 0.31, test acc = 47.06%
# task = 97, loss = 14.02, loss_semantic = 0.37, test acc = 43.41%
# task = 98, loss = 14.48, loss_semantic = 0.24, test acc = 47.12%
# task = 99, loss = 14.22, loss_semantic = 0.33, test acc = 42.28%
# task = 100, loss = 14.29, loss_semantic = 0.29, test acc = 42.96%
# task = 101, loss = 14.20, loss_semantic = 0.36, test acc = 45.04%
# task = 102, loss = 14.52, loss_semantic = 0.28, test acc = 42.84%
# task = 103, loss = 14.53, loss_semantic = 0.33, test acc = 46.67%
# task = 104, loss = 14.30, loss_semantic = 0.33, test acc = 44.82%
# task = 105, loss = 14.48, loss_semantic = 0.32, test acc = 45.34%
# task = 106, loss = 14.17, loss_semantic = 0.28, test acc = 44.56%
# task = 107, loss = 14.31, loss_semantic = 0.33, test acc = 43.49%
# task = 108, loss = 14.47, loss_semantic = 0.31, test acc = 42.99%
# task = 109, loss = 14.02, loss_semantic = 0.28, test acc = 45.14%
# task = 110, loss = 14.67, loss_semantic = 0.32, test acc = 42.36%
# task = 111, loss = 14.06, loss_semantic = 0.32, test acc = 45.70%
# task = 112, loss = 13.85, loss_semantic = 0.36, test acc = 46.56%
# task = 113, loss = 14.20, loss_semantic = 0.33, test acc = 44.71%
# task = 114, loss = 14.36, loss_semantic = 0.32, test acc = 45.47%
# task = 115, loss = 14.10, loss_semantic = 0.31, test acc = 46.26%
# task = 116, loss = 13.85, loss_semantic = 0.34, test acc = 45.63%
# task = 117, loss = 14.45, loss_semantic = 0.27, test acc = 43.46%
# task = 118, loss = 14.35, loss_semantic = 0.32, test acc = 41.12%
# task = 119, loss = 13.74, loss_semantic = 0.43, test acc = 41.96%
# task = 120, loss = 13.93, loss_semantic = 0.37, test acc = 43.76%
# task = 121, loss = 14.44, loss_semantic = 0.29, test acc = 39.48%
# task = 122, loss = 14.15, loss_semantic = 0.38, test acc = 45.47%
# task = 123, loss = 14.18, loss_semantic = 0.27, test acc = 43.63%
# task = 124, loss = 14.33, loss_semantic = 0.41, test acc = 42.10%
# task = 125, loss = 14.31, loss_semantic = 0.33, test acc = 46.14%
# task = 126, loss = 13.85, loss_semantic = 0.31, test acc = 45.30%
# task = 127, loss = 14.25, loss_semantic = 0.31, test acc = 41.46%
# task = 128, loss = 14.31, loss_semantic = 0.29, test acc = 46.14%
# task = 129, loss = 13.99, loss_semantic = 0.36, test acc = 46.27%
# task = 130, loss = 14.26, loss_semantic = 0.29, test acc = 42.04%
# task = 131, loss = 14.04, loss_semantic = 0.33, test acc = 43.86%
# task = 132, loss = 13.90, loss_semantic = 0.31, test acc = 41.92%
# task = 133, loss = 14.51, loss_semantic = 0.26, test acc = 42.02%
# task = 134, loss = 14.57, loss_semantic = 0.30, test acc = 42.75%
# task = 135, loss = 14.31, loss_semantic = 0.30, test acc = 45.11%
# task = 136, loss = 14.50, loss_semantic = 0.35, test acc = 42.92%
# task = 137, loss = 14.15, loss_semantic = 0.30, test acc = 43.83%
# task = 138, loss = 14.37, loss_semantic = 0.30, test acc = 40.96%
# task = 139, loss = 14.04, loss_semantic = 0.31, test acc = 42.98%
# task = 140, loss = 14.11, loss_semantic = 0.28, test acc = 43.06%
# task = 141, loss = 14.16, loss_semantic = 0.34, test acc = 46.16%
# task = 142, loss = 14.14, loss_semantic = 0.30, test acc = 41.48%
# task = 143, loss = 14.13, loss_semantic = 0.36, test acc = 42.05%
# task = 144, loss = 14.39, loss_semantic = 0.31, test acc = 44.47%
# task = 145, loss = 14.11, loss_semantic = 0.31, test acc = 43.24%
# task = 146, loss = 14.09, loss_semantic = 0.33, test acc = 41.96%
# task = 147, loss = 14.13, loss_semantic = 0.27, test acc = 46.59%
# task = 148, loss = 14.11, loss_semantic = 0.32, test acc = 41.82%
# task = 149, loss = 13.96, loss_semantic = 0.35, test acc = 43.19%
# task = 150, loss = 14.17, loss_semantic = 0.33, test acc = 45.60%
# task = 151, loss = 13.94, loss_semantic = 0.34, test acc = 44.90%
# task = 152, loss = 14.32, loss_semantic = 0.31, test acc = 40.02%
# task = 153, loss = 14.24, loss_semantic = 0.29, test acc = 44.92%
# task = 154, loss = 14.38, loss_semantic = 0.25, test acc = 45.23%
# task = 155, loss = 14.06, loss_semantic = 0.30, test acc = 43.80%
# task = 156, loss = 14.21, loss_semantic = 0.25, test acc = 42.04%
# task = 157, loss = 14.19, loss_semantic = 0.33, test acc = 45.60%
# task = 158, loss = 14.12, loss_semantic = 0.31, test acc = 45.73%
# task = 159, loss = 14.32, loss_semantic = 0.34, test acc = 42.19%
# task = 160, loss = 13.84, loss_semantic = 0.36, test acc = 44.16%
# task = 161, loss = 14.29, loss_semantic = 0.35, test acc = 40.47%
# task = 162, loss = 14.02, loss_semantic = 0.33, test acc = 42.55%
# task = 163, loss = 14.10, loss_semantic = 0.34, test acc = 44.75%
# task = 164, loss = 14.02, loss_semantic = 0.28, test acc = 44.76%
# task = 165, loss = 13.80, loss_semantic = 0.39, test acc = 44.86%
# task = 166, loss = 14.17, loss_semantic = 0.28, test acc = 41.98%
# task = 167, loss = 13.94, loss_semantic = 0.42, test acc = 43.36%
# task = 168, loss = 14.04, loss_semantic = 0.36, test acc = 44.75%
# task = 169, loss = 14.31, loss_semantic = 0.40, test acc = 40.56%
# task = 170, loss = 14.36, loss_semantic = 0.35, test acc = 41.79%
# task = 171, loss = 14.42, loss_semantic = 0.35, test acc = 46.60%
# task = 172, loss = 13.91, loss_semantic = 0.37, test acc = 42.39%
# task = 173, loss = 14.21, loss_semantic = 0.34, test acc = 48.05%
# task = 174, loss = 13.93, loss_semantic = 0.38, test acc = 43.28%
# task = 175, loss = 13.95, loss_semantic = 0.35, test acc = 47.53%
# task = 176, loss = 14.11, loss_semantic = 0.37, test acc = 43.62%
# task = 177, loss = 14.16, loss_semantic = 0.31, test acc = 44.33%
# task = 178, loss = 13.96, loss_semantic = 0.36, test acc = 45.17%
# task = 179, loss = 14.29, loss_semantic = 0.31, test acc = 45.13%
# task = 180, loss = 13.68, loss_semantic = 0.41, test acc = 41.87%
# task = 181, loss = 14.16, loss_semantic = 0.36, test acc = 42.38%
# task = 182, loss = 14.02, loss_semantic = 0.31, test acc = 42.58%
# task = 183, loss = 14.07, loss_semantic = 0.34, test acc = 45.93%
# task = 184, loss = 14.18, loss_semantic = 0.29, test acc = 39.59%
# task = 185, loss = 14.23, loss_semantic = 0.30, test acc = 44.44%
# task = 186, loss = 14.00, loss_semantic = 0.29, test acc = 43.39%
# task = 187, loss = 14.11, loss_semantic = 0.31, test acc = 46.32%
# task = 188, loss = 13.97, loss_semantic = 0.36, test acc = 43.36%
# task = 189, loss = 14.36, loss_semantic = 0.31, test acc = 40.94%
# task = 190, loss = 14.19, loss_semantic = 0.34, test acc = 42.46%
# task = 191, loss = 14.39, loss_semantic = 0.28, test acc = 39.28%
# task = 192, loss = 14.31, loss_semantic = 0.27, test acc = 43.80%
# task = 193, loss = 14.26, loss_semantic = 0.29, test acc = 42.53%
# task = 194, loss = 13.92, loss_semantic = 0.38, test acc = 43.99%
# task = 195, loss = 14.00, loss_semantic = 0.31, test acc = 43.58%
# task = 196, loss = 14.54, loss_semantic = 0.28, test acc = 46.81%
# task = 197, loss = 14.07, loss_semantic = 0.30, test acc = 43.59%
# task = 198, loss = 14.09, loss_semantic = 0.30, test acc = 44.69%
# task = 199, loss = 14.03, loss_semantic = 0.31, test acc = 45.82%
# Model saved as: streaming_model_3.pt
# The best accuracy is 49.68% at episode number 22.
# ========================== Streaming session: 4 ==========================
# Number of Classes (Base + Novel) = 22
# Novel classes are: [33, 11, 5]
# Base Classes: [4, 37, 6, 39, 12, 15, 16, 19, 26, 27]
# Total Novel Classes List: [9, 13, 25, 8, 34, 31, 0, 17, 24, 33, 11, 5]
# task = 0, loss = 17.74, loss_semantic = 0.52, test acc = 34.79%
# task = 1, loss = 18.00, loss_semantic = 5.20, test acc = 31.81%
# task = 2, loss = 17.74, loss_semantic = 3.25, test acc = 28.98%
# task = 3, loss = 17.50, loss_semantic = 2.08, test acc = 34.74%
# task = 4, loss = 17.43, loss_semantic = 2.36, test acc = 35.80%
# task = 5, loss = 17.14, loss_semantic = 2.16, test acc = 39.48%
# task = 6, loss = 17.80, loss_semantic = 1.70, test acc = 38.29%
# task = 7, loss = 17.40, loss_semantic = 1.41, test acc = 36.17%
# task = 8, loss = 17.67, loss_semantic = 1.11, test acc = 35.25%
# task = 9, loss = 17.21, loss_semantic = 0.98, test acc = 33.71%
# task = 10, loss = 17.09, loss_semantic = 0.81, test acc = 36.19%
# task = 11, loss = 16.68, loss_semantic = 0.76, test acc = 37.70%
# task = 12, loss = 17.07, loss_semantic = 0.69, test acc = 37.37%
# task = 13, loss = 16.54, loss_semantic = 0.66, test acc = 36.36%
# task = 14, loss = 16.77, loss_semantic = 0.52, test acc = 37.46%
# task = 15, loss = 16.34, loss_semantic = 0.51, test acc = 39.12%
# task = 16, loss = 16.60, loss_semantic = 0.48, test acc = 40.20%
# task = 17, loss = 17.03, loss_semantic = 0.46, test acc = 34.89%
# task = 18, loss = 16.74, loss_semantic = 0.42, test acc = 36.97%
# task = 19, loss = 16.79, loss_semantic = 0.45, test acc = 39.03%
# task = 20, loss = 16.88, loss_semantic = 0.41, test acc = 39.46%
# task = 21, loss = 16.64, loss_semantic = 0.43, test acc = 41.23%
# task = 22, loss = 16.65, loss_semantic = 0.41, test acc = 38.77%
# task = 23, loss = 16.47, loss_semantic = 0.48, test acc = 37.74%
# task = 24, loss = 16.78, loss_semantic = 0.39, test acc = 39.15%
# task = 25, loss = 16.46, loss_semantic = 0.43, test acc = 35.73%
# task = 26, loss = 16.39, loss_semantic = 0.44, test acc = 36.03%
# task = 27, loss = 16.75, loss_semantic = 0.37, test acc = 37.82%
# task = 28, loss = 16.56, loss_semantic = 0.38, test acc = 41.88%
# task = 29, loss = 16.43, loss_semantic = 0.41, test acc = 36.17%
# task = 30, loss = 16.35, loss_semantic = 0.39, test acc = 37.37%
# task = 31, loss = 16.18, loss_semantic = 0.41, test acc = 38.37%
# task = 32, loss = 16.82, loss_semantic = 0.35, test acc = 39.28%
# task = 33, loss = 16.23, loss_semantic = 0.45, test acc = 35.05%
# task = 34, loss = 16.37, loss_semantic = 0.40, test acc = 36.91%
# task = 35, loss = 16.57, loss_semantic = 0.37, test acc = 37.53%
# task = 36, loss = 16.83, loss_semantic = 0.30, test acc = 37.85%
# task = 37, loss = 15.94, loss_semantic = 0.49, test acc = 37.09%
# task = 38, loss = 16.12, loss_semantic = 0.40, test acc = 38.77%
# task = 39, loss = 16.40, loss_semantic = 0.44, test acc = 36.32%
# task = 40, loss = 16.29, loss_semantic = 0.42, test acc = 38.27%
# task = 41, loss = 16.28, loss_semantic = 0.42, test acc = 37.18%
# task = 42, loss = 16.28, loss_semantic = 0.38, test acc = 35.60%
# task = 43, loss = 16.46, loss_semantic = 0.37, test acc = 40.44%
# task = 44, loss = 16.35, loss_semantic = 0.39, test acc = 35.19%
# task = 45, loss = 15.93, loss_semantic = 0.44, test acc = 37.69%
# task = 46, loss = 16.69, loss_semantic = 0.34, test acc = 40.32%
# task = 47, loss = 16.23, loss_semantic = 0.43, test acc = 36.40%
# task = 48, loss = 16.26, loss_semantic = 0.41, test acc = 35.89%
# task = 49, loss = 16.28, loss_semantic = 0.38, test acc = 35.55%
# task = 50, loss = 16.06, loss_semantic = 0.39, test acc = 41.05%
# task = 51, loss = 15.87, loss_semantic = 0.46, test acc = 34.49%
# task = 52, loss = 15.85, loss_semantic = 0.43, test acc = 39.39%
# task = 53, loss = 16.41, loss_semantic = 0.35, test acc = 38.32%
# task = 54, loss = 16.34, loss_semantic = 0.37, test acc = 41.15%
# task = 55, loss = 16.23, loss_semantic = 0.38, test acc = 37.92%
# task = 56, loss = 16.06, loss_semantic = 0.41, test acc = 34.30%
# task = 57, loss = 16.40, loss_semantic = 0.37, test acc = 40.08%
# task = 58, loss = 16.10, loss_semantic = 0.37, test acc = 37.23%
# task = 59, loss = 15.82, loss_semantic = 0.40, test acc = 35.03%
# task = 60, loss = 16.02, loss_semantic = 0.37, test acc = 39.60%
# task = 61, loss = 16.29, loss_semantic = 0.38, test acc = 36.22%
# task = 62, loss = 16.22, loss_semantic = 0.37, test acc = 38.55%
# task = 63, loss = 15.65, loss_semantic = 0.42, test acc = 37.20%
# task = 64, loss = 15.87, loss_semantic = 0.41, test acc = 41.10%
# task = 65, loss = 15.53, loss_semantic = 0.51, test acc = 40.53%
# task = 66, loss = 15.86, loss_semantic = 0.38, test acc = 39.37%
# task = 67, loss = 16.08, loss_semantic = 0.45, test acc = 40.00%
# task = 68, loss = 15.90, loss_semantic = 0.41, test acc = 40.48%
# task = 69, loss = 15.89, loss_semantic = 0.47, test acc = 34.65%
# task = 70, loss = 15.79, loss_semantic = 0.46, test acc = 37.11%
# task = 71, loss = 16.05, loss_semantic = 0.47, test acc = 39.92%
# task = 72, loss = 16.21, loss_semantic = 0.35, test acc = 40.67%
# task = 73, loss = 16.16, loss_semantic = 0.41, test acc = 39.93%
# task = 74, loss = 15.95, loss_semantic = 0.35, test acc = 38.63%
# task = 75, loss = 16.18, loss_semantic = 0.37, test acc = 41.56%
# task = 76, loss = 15.77, loss_semantic = 0.39, test acc = 39.83%
# task = 77, loss = 15.94, loss_semantic = 0.39, test acc = 37.94%
# task = 78, loss = 15.71, loss_semantic = 0.39, test acc = 40.75%
# task = 79, loss = 16.09, loss_semantic = 0.37, test acc = 38.65%
# task = 80, loss = 15.95, loss_semantic = 0.39, test acc = 38.19%
# task = 81, loss = 16.33, loss_semantic = 0.37, test acc = 41.37%
# task = 82, loss = 15.69, loss_semantic = 0.45, test acc = 38.54%
# task = 83, loss = 16.11, loss_semantic = 0.34, test acc = 40.06%
# task = 84, loss = 15.85, loss_semantic = 0.37, test acc = 42.12%
# task = 85, loss = 15.76, loss_semantic = 0.42, test acc = 41.14%
# task = 86, loss = 16.06, loss_semantic = 0.37, test acc = 38.85%
# task = 87, loss = 15.98, loss_semantic = 0.39, test acc = 40.77%
# task = 88, loss = 15.98, loss_semantic = 0.42, test acc = 38.18%
# task = 89, loss = 15.79, loss_semantic = 0.44, test acc = 39.10%
# task = 90, loss = 15.76, loss_semantic = 0.37, test acc = 37.83%
# task = 91, loss = 15.82, loss_semantic = 0.39, test acc = 40.51%
# task = 92, loss = 16.28, loss_semantic = 0.34, test acc = 38.40%
# task = 93, loss = 15.71, loss_semantic = 0.39, test acc = 39.61%
# task = 94, loss = 15.86, loss_semantic = 0.36, test acc = 38.63%
# task = 95, loss = 15.92, loss_semantic = 0.42, test acc = 42.38%
# task = 96, loss = 15.69, loss_semantic = 0.39, test acc = 38.15%
# task = 97, loss = 15.83, loss_semantic = 0.45, test acc = 38.52%
# task = 98, loss = 15.86, loss_semantic = 0.38, test acc = 40.13%
# task = 99, loss = 15.98, loss_semantic = 0.34, test acc = 40.86%
# task = 100, loss = 15.95, loss_semantic = 0.34, test acc = 39.18%
# task = 101, loss = 15.95, loss_semantic = 0.37, test acc = 38.57%
# task = 102, loss = 15.79, loss_semantic = 0.42, test acc = 37.25%
# task = 103, loss = 16.05, loss_semantic = 0.37, test acc = 37.44%
# task = 104, loss = 15.81, loss_semantic = 0.40, test acc = 37.97%
# task = 105, loss = 16.09, loss_semantic = 0.35, test acc = 37.32%
# task = 106, loss = 16.10, loss_semantic = 0.38, test acc = 39.13%
# task = 107, loss = 15.59, loss_semantic = 0.35, test acc = 41.09%
# task = 108, loss = 15.65, loss_semantic = 0.41, test acc = 40.25%
# task = 109, loss = 15.47, loss_semantic = 0.40, test acc = 38.82%
# task = 110, loss = 16.04, loss_semantic = 0.32, test acc = 38.20%
# task = 111, loss = 15.91, loss_semantic = 0.39, test acc = 37.50%
# task = 112, loss = 15.97, loss_semantic = 0.36, test acc = 34.75%
# task = 113, loss = 15.79, loss_semantic = 0.45, test acc = 38.91%
# task = 114, loss = 15.66, loss_semantic = 0.44, test acc = 38.91%
# ...
# task = 165, loss = 24.52, loss_semantic = 0.69, test acc = 26.08%
# task = 166, loss = 24.55, loss_semantic = 0.69, test acc = 27.08%
# task = 167, loss = 24.38, loss_semantic = 0.75, test acc = 28.46%
# task = 168, loss = 24.76, loss_semantic = 0.74, test acc = 26.70%
# task = 169, loss = 24.14, loss_semantic = 0.81, test acc = 26.91%
# task = 170, loss = 24.58, loss_semantic = 0.70, test acc = 27.22%
# task = 171, loss = 24.67, loss_semantic = 0.75, test acc = 26.61%
# task = 172, loss = 24.43, loss_semantic = 0.69, test acc = 27.76%
# task = 173, loss = 24.41, loss_semantic = 0.83, test acc = 27.87%
# task = 174, loss = 24.46, loss_semantic = 0.79, test acc = 26.76%
# task = 175, loss = 24.39, loss_semantic = 0.83, test acc = 24.35%
# task = 176, loss = 24.58, loss_semantic = 0.71, test acc = 25.63%
# task = 177, loss = 24.72, loss_semantic = 0.78, test acc = 25.32%
# task = 178, loss = 24.08, loss_semantic = 0.85, test acc = 26.53%
# task = 179, loss = 24.58, loss_semantic = 0.76, test acc = 26.63%
# task = 180, loss = 24.37, loss_semantic = 0.76, test acc = 28.39%
# task = 181, loss = 24.42, loss_semantic = 0.74, test acc = 27.51%
# task = 182, loss = 24.38, loss_semantic = 0.88, test acc = 24.85%
# task = 183, loss = 24.62, loss_semantic = 0.76, test acc = 23.75%
# task = 184, loss = 24.61, loss_semantic = 0.72, test acc = 24.46%
# task = 185, loss = 24.58, loss_semantic = 0.72, test acc = 25.13%
# task = 186, loss = 24.40, loss_semantic = 0.77, test acc = 27.34%
# task = 187, loss = 24.53, loss_semantic = 0.70, test acc = 26.93%
# task = 188, loss = 24.74, loss_semantic = 0.80, test acc = 26.49%
# task = 189, loss = 24.56, loss_semantic = 0.78, test acc = 29.19%
# task = 190, loss = 24.52, loss_semantic = 0.81, test acc = 27.10%
# task = 191, loss = 24.49, loss_semantic = 0.77, test acc = 24.70%
# task = 192, loss = 24.44, loss_semantic = 0.78, test acc = 24.10%
# task = 193, loss = 24.47, loss_semantic = 0.72, test acc = 24.91%
# task = 194, loss = 24.52, loss_semantic = 0.77, test acc = 26.00%
# task = 195, loss = 24.58, loss_semantic = 0.72, test acc = 25.93%
# task = 196, loss = 24.71, loss_semantic = 0.78, test acc = 29.48%
# task = 197, loss = 24.35, loss_semantic = 0.78, test acc = 26.91%
# task = 198, loss = 24.53, loss_semantic = 0.85, test acc = 26.18%
# task = 199, loss = 24.55, loss_semantic = 0.77, test acc = 26.68%
# Model saved as: streaming_model_9.pt
# The best accuracy is 29.49% at episode number 114.
# ========================== Streaming session: 10 ==========================
# Number of Classes (Base + Novel) = 40
# Novel classes are: [38, 28, 14]
# Base Classes: [4, 37, 6, 39, 12, 15, 16, 19, 26, 27]
# Total Novel Classes List: [9, 13, 25, 8, 34, 31, 0, 17, 24, 33, 11, 5, 1, 29, 21, 2, 36, 30, 35, 3, 23, 32, 10, 22, 18, 20, 7, 38, 28, 14]
# task = 0, loss = 32.12, loss_semantic = 1.61, test acc = 25.82%
# task = 1, loss = 31.37, loss_semantic = 9.47, test acc = 22.24%
# task = 2, loss = 31.40, loss_semantic = 4.93, test acc = 19.39%
# task = 3, loss = 31.19, loss_semantic = 4.32, test acc = 20.94%
# task = 4, loss = 30.87, loss_semantic = 5.26, test acc = 22.26%
# task = 5, loss = 30.34, loss_semantic = 4.06, test acc = 23.99%
# task = 6, loss = 30.64, loss_semantic = 2.65, test acc = 23.84%
# task = 7, loss = 30.61, loss_semantic = 2.91, test acc = 23.23%
# task = 8, loss = 30.62, loss_semantic = 3.16, test acc = 23.10%
# task = 9, loss = 30.35, loss_semantic = 2.85, test acc = 26.66%
# task = 10, loss = 30.02, loss_semantic = 2.49, test acc = 25.25%
# task = 11, loss = 30.07, loss_semantic = 2.44, test acc = 24.49%
# task = 12, loss = 29.77, loss_semantic = 2.40, test acc = 27.38%
# task = 13, loss = 30.03, loss_semantic = 2.40, test acc = 27.96%
# task = 14, loss = 29.67, loss_semantic = 2.12, test acc = 26.95%
# task = 15, loss = 30.05, loss_semantic = 1.74, test acc = 26.94%
# task = 16, loss = 29.91, loss_semantic = 1.68, test acc = 26.79%
# task = 17, loss = 29.37, loss_semantic = 1.75, test acc = 26.69%
# task = 18, loss = 29.62, loss_semantic = 1.49, test acc = 29.67%
# task = 19, loss = 29.24, loss_semantic = 1.43, test acc = 26.84%
# task = 20, loss = 29.52, loss_semantic = 1.29, test acc = 23.27%
# task = 21, loss = 29.31, loss_semantic = 1.23, test acc = 24.88%
# task = 22, loss = 29.36, loss_semantic = 1.13, test acc = 26.62%
# task = 23, loss = 29.63, loss_semantic = 1.08, test acc = 25.45%
# task = 24, loss = 29.21, loss_semantic = 1.10, test acc = 23.27%
# task = 25, loss = 29.11, loss_semantic = 1.12, test acc = 25.05%
# task = 26, loss = 29.21, loss_semantic = 1.01, test acc = 28.20%
# task = 27, loss = 28.97, loss_semantic = 0.99, test acc = 28.28%
# task = 28, loss = 29.18, loss_semantic = 0.89, test acc = 26.97%
# task = 29, loss = 28.74, loss_semantic = 1.01, test acc = 27.54%
# task = 30, loss = 29.15, loss_semantic = 0.89, test acc = 28.03%
# task = 31, loss = 28.82, loss_semantic = 0.84, test acc = 28.22%
# task = 32, loss = 28.92, loss_semantic = 0.82, test acc = 27.68%
# task = 33, loss = 28.69, loss_semantic = 0.85, test acc = 27.47%
# task = 34, loss = 28.59, loss_semantic = 0.92, test acc = 23.47%
# task = 35, loss = 28.78, loss_semantic = 0.81, test acc = 29.11%
# task = 36, loss = 28.75, loss_semantic = 0.79, test acc = 28.09%
# task = 37, loss = 28.63, loss_semantic = 0.81, test acc = 26.67%
# task = 38, loss = 28.62, loss_semantic = 0.82, test acc = 24.71%
# task = 39, loss = 28.24, loss_semantic = 0.85, test acc = 25.73%
# task = 40, loss = 28.51, loss_semantic = 0.82, test acc = 27.05%
# task = 41, loss = 28.40, loss_semantic = 0.73, test acc = 25.80%
# task = 42, loss = 28.32, loss_semantic = 0.81, test acc = 23.54%
# task = 43, loss = 28.54, loss_semantic = 0.76, test acc = 25.18%
# task = 44, loss = 28.47, loss_semantic = 0.73, test acc = 23.58%
# task = 45, loss = 28.06, loss_semantic = 0.78, test acc = 26.60%
# task = 46, loss = 28.16, loss_semantic = 0.84, test acc = 25.29%
# task = 47, loss = 28.42, loss_semantic = 0.71, test acc = 24.98%
# task = 48, loss = 28.34, loss_semantic = 0.76, test acc = 25.53%
# task = 49, loss = 28.09, loss_semantic = 0.70, test acc = 25.57%
# task = 50, loss = 28.39, loss_semantic = 0.79, test acc = 24.88%
# task = 51, loss = 28.24, loss_semantic = 0.77, test acc = 23.11%
# task = 52, loss = 28.10, loss_semantic = 0.74, test acc = 25.89%
# task = 53, loss = 28.23, loss_semantic = 0.72, test acc = 23.78%
# task = 54, loss = 28.04, loss_semantic = 0.75, test acc = 26.13%
# task = 55, loss = 27.95, loss_semantic = 0.71, test acc = 27.68%
# task = 56, loss = 28.35, loss_semantic = 0.71, test acc = 24.76%
# task = 57, loss = 27.85, loss_semantic = 0.72, test acc = 25.30%
# task = 58, loss = 28.27, loss_semantic = 0.71, test acc = 24.94%
# task = 59, loss = 28.07, loss_semantic = 0.70, test acc = 27.26%
# task = 60, loss = 28.08, loss_semantic = 0.76, test acc = 25.95%
# task = 61, loss = 28.19, loss_semantic = 0.76, test acc = 25.99%
# task = 62, loss = 28.17, loss_semantic = 0.67, test acc = 24.01%
# task = 63, loss = 27.78, loss_semantic = 0.72, test acc = 26.07%
# task = 64, loss = 27.90, loss_semantic = 0.72, test acc = 25.67%
# task = 65, loss = 27.81, loss_semantic = 0.74, test acc = 22.00%
# task = 66, loss = 27.96, loss_semantic = 0.73, test acc = 23.36%
# task = 67, loss = 27.95, loss_semantic = 0.74, test acc = 23.24%
# task = 68, loss = 27.74, loss_semantic = 0.79, test acc = 23.56%
# task = 69, loss = 27.90, loss_semantic = 0.73, test acc = 23.50%
# task = 70, loss = 27.73, loss_semantic = 0.86, test acc = 23.23%
# task = 71, loss = 27.90, loss_semantic = 0.66, test acc = 26.47%
# task = 72, loss = 28.05, loss_semantic = 0.91, test acc = 25.74%
# task = 73, loss = 27.59, loss_semantic = 0.71, test acc = 28.09%
# task = 74, loss = 27.45, loss_semantic = 0.96, test acc = 25.54%
# task = 75, loss = 27.55, loss_semantic = 0.74, test acc = 26.13%
# task = 76, loss = 27.56, loss_semantic = 0.97, test acc = 25.35%
# task = 77, loss = 27.32, loss_semantic = 0.96, test acc = 23.90%
# task = 78, loss = 27.75, loss_semantic = 0.98, test acc = 25.37%
# task = 79, loss = 27.80, loss_semantic = 0.92, test acc = 24.42%
# task = 80, loss = 27.63, loss_semantic = 0.92, test acc = 25.41%
# task = 81, loss = 28.00, loss_semantic = 0.86, test acc = 26.34%
# task = 82, loss = 27.97, loss_semantic = 0.74, test acc = 27.89%
# task = 83, loss = 27.84, loss_semantic = 0.87, test acc = 24.37%
# task = 84, loss = 27.60, loss_semantic = 0.88, test acc = 24.41%
# task = 85, loss = 27.53, loss_semantic = 0.99, test acc = 22.46%
# task = 86, loss = 27.63, loss_semantic = 0.81, test acc = 27.04%
# task = 87, loss = 27.58, loss_semantic = 0.84, test acc = 24.53%
# task = 88, loss = 27.81, loss_semantic = 0.74, test acc = 24.22%
# task = 89, loss = 27.74, loss_semantic = 0.82, test acc = 25.22%
# task = 90, loss = 27.62, loss_semantic = 0.80, test acc = 27.59%
# task = 91, loss = 27.48, loss_semantic = 0.85, test acc = 25.42%
# task = 92, loss = 27.55, loss_semantic = 0.81, test acc = 26.27%
# task = 93, loss = 27.44, loss_semantic = 0.80, test acc = 24.08%
# task = 94, loss = 27.81, loss_semantic = 0.78, test acc = 25.70%
# task = 95, loss = 27.82, loss_semantic = 0.69, test acc = 25.70%
# task = 96, loss = 27.37, loss_semantic = 0.76, test acc = 26.72%
# task = 97, loss = 27.88, loss_semantic = 0.70, test acc = 25.39%
# task = 98, loss = 27.40, loss_semantic = 0.83, test acc = 26.42%
# task = 99, loss = 27.99, loss_semantic = 0.65, test acc = 24.05%
# task = 100, loss = 27.42, loss_semantic = 0.81, test acc = 25.62%
# task = 101, loss = 27.64, loss_semantic = 0.73, test acc = 26.38%
# task = 102, loss = 27.60, loss_semantic = 0.78, test acc = 24.37%
# task = 103, loss = 27.16, loss_semantic = 0.76, test acc = 24.10%
# task = 104, loss = 27.52, loss_semantic = 0.78, test acc = 28.27%
# task = 105, loss = 27.64, loss_semantic = 0.77, test acc = 23.82%
# task = 106, loss = 27.86, loss_semantic = 0.64, test acc = 27.13%
# task = 107, loss = 27.25, loss_semantic = 0.76, test acc = 26.94%
# task = 108, loss = 27.23, loss_semantic = 0.82, test acc = 24.63%
# task = 109, loss = 27.65, loss_semantic = 0.76, test acc = 25.40%
# task = 110, loss = 27.64, loss_semantic = 0.69, test acc = 28.34%
# task = 111, loss = 27.50, loss_semantic = 0.75, test acc = 24.95%
# task = 112, loss = 27.36, loss_semantic = 0.82, test acc = 26.47%
# task = 113, loss = 27.59, loss_semantic = 0.72, test acc = 24.72%
# task = 114, loss = 27.09, loss_semantic = 0.90, test acc = 25.49%
# task = 115, loss = 27.40, loss_semantic = 0.75, test acc = 26.31%
# task = 116, loss = 27.44, loss_semantic = 0.82, test acc = 25.52%
# task = 117, loss = 27.36, loss_semantic = 0.66, test acc = 25.64%
# task = 118, loss = 27.23, loss_semantic = 0.90, test acc = 24.65%
# task = 119, loss = 27.46, loss_semantic = 0.68, test acc = 25.05%
# task = 120, loss = 27.23, loss_semantic = 0.99, test acc = 24.30%
# task = 121, loss = 27.36, loss_semantic = 0.80, test acc = 22.80%
# task = 122, loss = 27.32, loss_semantic = 0.88, test acc = 24.33%
# task = 123, loss = 27.46, loss_semantic = 0.85, test acc = 25.80%
# task = 124, loss = 27.31, loss_semantic = 0.87, test acc = 28.04%
# task = 125, loss = 27.33, loss_semantic = 0.81, test acc = 26.49%
# task = 126, loss = 26.99, loss_semantic = 0.87, test acc = 25.47%
# task = 127, loss = 27.22, loss_semantic = 0.82, test acc = 25.79%
# task = 128, loss = 27.43, loss_semantic = 0.79, test acc = 26.65%
# task = 129, loss = 27.45, loss_semantic = 0.76, test acc = 25.80%
# task = 130, loss = 27.03, loss_semantic = 0.81, test acc = 25.82%
# task = 131, loss = 27.04, loss_semantic = 0.88, test acc = 25.36%
# task = 132, loss = 27.17, loss_semantic = 0.84, test acc = 25.14%
# task = 133, loss = 27.15, loss_semantic = 0.82, test acc = 24.64%
# task = 134, loss = 27.16, loss_semantic = 0.80, test acc = 25.86%
# task = 135, loss = 27.42, loss_semantic = 0.66, test acc = 24.78%
# task = 136, loss = 27.29, loss_semantic = 0.80, test acc = 23.35%
# task = 137, loss = 27.15, loss_semantic = 0.80, test acc = 25.66%
# task = 138, loss = 27.34, loss_semantic = 0.83, test acc = 27.16%
# task = 139, loss = 27.11, loss_semantic = 0.77, test acc = 23.67%
# task = 140, loss = 27.40, loss_semantic = 0.81, test acc = 25.82%
# task = 141, loss = 27.30, loss_semantic = 0.72, test acc = 26.26%
# task = 142, loss = 27.24, loss_semantic = 0.69, test acc = 25.26%
# task = 143, loss = 27.36, loss_semantic = 0.68, test acc = 24.87%
# task = 144, loss = 27.21, loss_semantic = 0.72, test acc = 25.43%
# task = 145, loss = 26.93, loss_semantic = 0.77, test acc = 25.47%
# task = 146, loss = 27.23, loss_semantic = 0.70, test acc = 28.77%
# task = 147, loss = 27.20, loss_semantic = 0.75, test acc = 26.61%
# task = 148, loss = 27.12, loss_semantic = 0.70, test acc = 24.94%
# task = 149, loss = 27.25, loss_semantic = 0.72, test acc = 25.38%
# task = 150, loss = 27.26, loss_semantic = 0.73, test acc = 27.56%
# task = 151, loss = 26.91, loss_semantic = 0.75, test acc = 26.77%
# task = 152, loss = 27.20, loss_semantic = 0.71, test acc = 25.57%
# task = 153, loss = 27.22, loss_semantic = 0.75, test acc = 23.87%
# task = 154, loss = 26.96, loss_semantic = 0.68, test acc = 23.52%
# task = 155, loss = 27.01, loss_semantic = 0.75, test acc = 25.76%
# task = 156, loss = 26.97, loss_semantic = 0.67, test acc = 26.45%
# task = 157, loss = 27.19, loss_semantic = 0.76, test acc = 24.89%
# task = 158, loss = 27.15, loss_semantic = 0.69, test acc = 24.62%
# task = 159, loss = 27.29, loss_semantic = 0.66, test acc = 27.52%
# task = 160, loss = 27.10, loss_semantic = 0.73, test acc = 25.93%
# task = 161, loss = 27.12, loss_semantic = 0.64, test acc = 27.98%
# task = 162, loss = 27.18, loss_semantic = 0.74, test acc = 26.25%
# task = 163, loss = 27.02, loss_semantic = 0.67, test acc = 26.74%
# task = 164, loss = 26.95, loss_semantic = 0.77, test acc = 26.60%
# task = 165, loss = 26.85, loss_semantic = 0.76, test acc = 23.88%
# task = 166, loss = 27.12, loss_semantic = 0.71, test acc = 24.56%
# task = 167, loss = 26.94, loss_semantic = 0.74, test acc = 25.01%
# task = 168, loss = 27.23, loss_semantic = 0.68, test acc = 25.52%
# task = 169, loss = 26.96, loss_semantic = 0.79, test acc = 26.29%
# task = 170, loss = 27.13, loss_semantic = 0.67, test acc = 27.49%
# task = 171, loss = 27.01, loss_semantic = 0.79, test acc = 25.60%
# task = 172, loss = 27.03, loss_semantic = 0.71, test acc = 25.85%
# task = 173, loss = 27.18, loss_semantic = 0.81, test acc = 26.47%
# task = 174, loss = 26.93, loss_semantic = 0.77, test acc = 26.53%
# task = 175, loss = 27.23, loss_semantic = 0.82, test acc = 26.52%
# task = 176, loss = 26.86, loss_semantic = 0.74, test acc = 25.61%
# task = 177, loss = 26.89, loss_semantic = 0.82, test acc = 26.48%
# task = 178, loss = 26.92, loss_semantic = 0.83, test acc = 25.47%
# task = 179, loss = 27.14, loss_semantic = 0.80, test acc = 26.94%
# task = 180, loss = 27.24, loss_semantic = 0.74, test acc = 24.55%
# task = 181, loss = 27.11, loss_semantic = 0.74, test acc = 28.31%
# task = 182, loss = 27.02, loss_semantic = 0.77, test acc = 25.82%
# task = 183, loss = 26.76, loss_semantic = 0.89, test acc = 26.37%
# task = 184, loss = 26.86, loss_semantic = 0.80, test acc = 26.68%
# task = 185, loss = 27.07, loss_semantic = 0.71, test acc = 25.71%
# task = 186, loss = 27.06, loss_semantic = 0.66, test acc = 26.62%
# task = 187, loss = 27.01, loss_semantic = 0.82, test acc = 24.74%
# task = 188, loss = 26.94, loss_semantic = 0.67, test acc = 27.51%
# task = 189, loss = 26.86, loss_semantic = 0.91, test acc = 25.63%
# task = 190, loss = 26.65, loss_semantic = 0.81, test acc = 24.88%
# task = 191, loss = 26.72, loss_semantic = 0.93, test acc = 26.38%
# task = 192, loss = 26.92, loss_semantic = 0.80, test acc = 26.27%
# task = 193, loss = 26.80, loss_semantic = 0.84, test acc = 22.71%
# task = 194, loss = 26.86, loss_semantic = 0.75, test acc = 25.32%
# task = 195, loss = 26.85, loss_semantic = 0.80, test acc = 24.47%
# task = 196, loss = 26.87, loss_semantic = 0.78, test acc = 26.06%
# task = 197, loss = 27.00, loss_semantic = 0.68, test acc = 27.87%
# task = 198, loss = 26.91, loss_semantic = 0.79, test acc = 26.09%
# task = 199, loss = 26.78, loss_semantic = 0.74, test acc = 26.08%
# Model saved as: streaming_model_10.pt
# The best accuracy is 29.67% at episode number 18.
# Total execution time: 19215.072416305542 seconds.
